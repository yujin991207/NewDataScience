# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 넘파이의 random 함수

# %% [markdown]
# ### 1. numpy.random.rand
#  0~1 사이의 값의 uniform distribution 균일 분포, 균등 분포라고 불리는 값을 return 하는 함수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
DATA_LIMIT = 1000000

# %%
import pandas as pd
import numpy as np

np.random.rand(5)
# Out:
# array([0.02492053, 0.06869282, 0.84969892, 0.62534394, 0.30895466])

# %%
np.random.rand(2,5)
# Out:
# array([[0.05893363, 0.94110088, 0.23920097, 0.86416413, 0.32521825],
#        [0.25040553, 0.23515901, 0.8371595 , 0.99748017, 0.67651155]])

# %%
# 균일하게 생성된다 => 균일분포, 균등분포
rand_data = np.random.rand(DATA_LIMIT)
plt.hist(rand_data)
# Out:
# (array([100234., 100273., 100079., 100086.,  99868., 100219.,  99747.,
#          99779.,  99849.,  99866.]),
#  array([6.13771006e-07, 1.00000446e-01, 2.00000277e-01, 3.00000109e-01,
#         3.99999941e-01, 4.99999773e-01, 5.99999605e-01, 6.99999436e-01,
#         7.99999268e-01, 8.99999100e-01, 9.99998932e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 2. numpy.random.randn

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Normal(Gaussian) Distribution 정규 분포, 가우시안 분포라고 불리는 값을 return 하는 함수입니다.
#  평균 0, 분산이 1인 값을 반환

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
randn_data = np.random.randn(DATA_LIMIT)
plt.hist(randn_data, bins=100)
# Out:
# (array([2.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         5.0000e+00, 4.0000e+00, 6.0000e+00, 5.0000e+00, 8.0000e+00,
#         9.0000e+00, 1.4000e+01, 2.3000e+01, 3.4000e+01, 5.8000e+01,
#         7.0000e+01, 1.0400e+02, 1.4500e+02, 2.1800e+02, 2.8000e+02,
#         3.6500e+02, 4.9200e+02, 6.6100e+02, 9.0600e+02, 1.1420e+03,
#         1.4650e+03, 1.8610e+03, 2.4270e+03, 2.9680e+03, 3.6710e+03,
#         4.5260e+03, 5.5500e+03, 6.7280e+03, 7.9460e+03, 9.4590e+03,
#         1.0944e+04, 1.2899e+04, 1.4796e+04, 1.6578e+04, 1.8880e+04,
#         2.1412e+04, 2.3465e+04, 2.5722e+04, 2.7946e+04, 3.0201e+04,
#         3.1833e+04, 3.3941e+04, 3.5329e+04, 3.6629e+04, 3.7832e+04,
#         3.8821e+04, 3.8798e+04, 3.9051e+04, 3.8400e+04, 3.7243e+04,
#         3.6520e+04, 3.4565e+04, 3.3386e+04, 3.1501e+04, 2.9278e+04,
#         2.7353e+04, 2.4995e+04, 2.2357e+04, 2.0309e+04, 1.8171e+04,
#         1.5912e+04, 1.3940e+04, 1.2078e+04, 1.0377e+04, 8.8400e+03,
#         7.4560e+03, 6.2520e+03, 5.1290e+03, 4.1820e+03, 3.4190e+03,
#         2.7380e+03, 2.1410e+03, 1.7180e+03, 1.3690e+03, 1.0660e+03,
#         8.3200e+02, 6.2100e+02, 4.4200e+02, 3.1900e+02, 2.3400e+02,
#         1.9400e+02, 1.4100e+02, 9.2000e+01, 6.2000e+01, 3.4000e+01,
#         3.4000e+01, 1.9000e+01, 1.9000e+01, 1.3000e+01, 4.0000e+00,
#         5.0000e+00, 2.0000e+00, 3.0000e+00, 1.0000e+00, 4.0000e+00]),
#  array([-5.03490953, -4.93771373, -4.84051793, -4.74332213, -4.64612634,
#         -4.54893054, -4.45173474, -4.35453894, -4.25734315, -4.16014735,
#         -4.06295155, -3.96575575, -3.86855996, -3.77136416, -3.67416836,
#         -3.57697256, -3.47977676, -3.38258097, -3.28538517, -3.18818937,
#         -3.09099357, -2.99379778, -2.89660198, -2.79940618, -2.70221038,
#         -2.60501458, -2.50781879, -2.41062299, -2.31342719, -2.21623139,
#         -2.1190356 , -2.0218398 , -1.924644  , -1.8274482 , -1.73025241,
#         -1.63305661, -1.53586081, -1.43866501, -1.34146921, -1.24427342,
#         -1.14707762, -1.04988182, -0.95268602, -0.85549023, -0.75829443,
#         -0.66109863, -0.56390283, -0.46670704, -0.36951124, -0.27231544,
#         -0.17511964, -0.07792384,  0.01927195,  0.11646775,  0.21366355,
#          0.31085935,  0.40805514,  0.50525094,  0.60244674,  0.69964254,
#          0.79683834,  0.89403413,  0.99122993,  1.08842573,  1.18562153,
#          1.28281732,  1.38001312,  1.47720892,  1.57440472,  1.67160051,
#          1.76879631,  1.86599211,  1.96318791,  2.06038371,  2.1575795 ,
#          2.2547753 ,  2.3519711 ,  2.4491669 ,  2.54636269,  2.64355849,
#          2.74075429,  2.83795009,  2.93514589,  3.03234168,  3.12953748,
#          3.22673328,  3.32392908,  3.42112487,  3.51832067,  3.61551647,
#          3.71271227,  3.80990806,  3.90710386,  4.00429966,  4.10149546,
#          4.19869126,  4.29588705,  4.39308285,  4.49027865,  4.58747445,
#          4.68467024]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# ## 3. numpy.random.randint
# 정수의 숫자를 random

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [이산균등분포(discrete uniform)](https://ko.wikipedia.org/wiki/%EC%9D%B4%EC%82%B0%EA%B7%A0%EB%93%B1%EB%B6%84%ED%8F%AC)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1) low
# 가장 작은 범주가 어디서부터 시작하는 지를 적습니다. 다만 1개의 hyperparameter를 적으면 그 값은 가장 높은 범주의 값으로 인식하고 0에서부터 그 숫자 사이의 int를 1개 반환합니다.
# 만약 high없이 개수를 늘리고 싶다면 다음과 같이 적으면 됩니다.
#
# ex) numpy.random.randint(3, size=10)
#
# 2) high
# 가장 높은 정수를 적은 곳으로 선택사항 optional입니다.
#
# 3) size
#
# 몇 개의 random 값을 리턴하기 바라는지를 적으면 됩니다. 3개 반환을 받고 싶다면 3개를 적으면 됩니다. 만약 array 형태로 shape을 적고싶다면 다음과 같이 적을 수도 있습니다.
#
# ex) numpy.random.randint(3,10,size=(3,2))
#
# 이렇게 적으면 3~10 사이의 정수를 3x2 행렬에 맞게 반환해주세요 라는 뜻이 됩니다.
#
#
#
# 4) dtype
#
# int를 반환하는 함수이기 때문에 굳이 필요한가 싶지만 이 부분은 int 혹은 int64를 반환할 수 있도록 선택하는 parameter입니다. 선택하지 않아도 무방

# %% [markdown]
# ### high만 지정

# %%
# 0~2까지의 random한 10개의 데이터
np.random.randint(3, size=10)
# Out:
# array([0, 0, 2, 0, 2, 0, 0, 0, 0, 0])

# %% [markdown]
# ### low, high 지정

# %%
np.random.randint(1,3, size=10)
# Out:
# array([2, 1, 1, 2, 1, 2, 1, 1, 2, 1])

# %%
np.random.randint(1,3, size=10)
# Out:
# array([1, 2, 1, 2, 2, 1, 1, 1, 1, 2])

# %%
randint_data = np.random.randint(1,1000, size=DATA_LIMIT)
plt.hist(randint_data, bins=20)
# Out:
# (array([49855., 50094., 50260., 50042., 49950., 49916., 50250., 49867.,
#         50235., 49046., 50050., 49739., 49897., 49847., 50177., 50221.,
#         49871., 50041., 50355., 50287.]),
#  array([  1. ,  50.9, 100.8, 150.7, 200.6, 250.5, 300.4, 350.3, 400.2,
#         450.1, 500. , 549.9, 599.8, 649.7, 699.6, 749.5, 799.4, 849.3,
#         899.2, 949.1, 999. ]),
#  <BarContainer object of 20 artists>)

# %%
# 173 평균값, 5 분산값
move_right =  172.5
variance_amplication = 5

# %%
# 전체값에다가 move_rigth(173)을 더한다 .... 
height_data = np.round(
    move_right + 
    (np.random.randn(DATA_LIMIT) * variance_amplication),
    1)

# %%
height_data
# Out:
# array([173.2, 168.3, 169.8, ..., 172.8, 165.9, 171.4])

# %%
plt.xlabel('키')
plt.ylabel('누적개수')
plt.hist(height_data, bins=40)
# Out:
# (array([4.00000e+00, 3.00000e+00, 2.70000e+01, 8.30000e+01, 1.89000e+02,
#         4.94000e+02, 1.08600e+03, 2.18200e+03, 3.96600e+03, 7.74900e+03,
#         1.36080e+04, 2.22830e+04, 3.38560e+04, 4.36470e+04, 6.24690e+04,
#         7.86700e+04, 9.25440e+04, 9.37070e+04, 1.02862e+05, 9.92990e+04,
#         8.95490e+04, 7.47550e+04, 5.52960e+04, 4.52040e+04, 3.09940e+04,
#         1.98880e+04, 1.14200e+04, 7.01100e+03, 3.78200e+03, 1.83600e+03,
#         8.85000e+02, 3.87000e+02, 1.68000e+02, 6.80000e+01, 2.00000e+01,
#         8.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([149.    , 150.2775, 151.555 , 152.8325, 154.11  , 155.3875,
#         156.665 , 157.9425, 159.22  , 160.4975, 161.775 , 163.0525,
#         164.33  , 165.6075, 166.885 , 168.1625, 169.44  , 170.7175,
#         171.995 , 173.2725, 174.55  , 175.8275, 177.105 , 178.3825,
#         179.66  , 180.9375, 182.215 , 183.4925, 184.77  , 186.0475,
#         187.325 , 188.6025, 189.88  , 191.1575, 192.435 , 193.7125,
#         194.99  , 196.2675, 197.545 , 198.8225, 200.1   ]),
#  <BarContainer object of 40 artists>)

# %%
m_move_right =  172.5
w_move_right =  159.6
variance_amplication = 6

# 남자, 여자 data
m_height_data = np.round(m_move_right + (np.random.randn(DATA_LIMIT)*variance_amplication),1)
w_height_data = np.round(w_move_right + (np.random.randn(DATA_LIMIT)*variance_amplication),1)

plt.xlabel('키')
plt.ylabel('누적개수')
plt.hist((m_height_data,w_height_data), bins=100, label=['성인 남자키','성인 여자키'])

plt.title('전국 성인남녀 키 현황 (2022.3 산업통산자원부 통계자료 시뮬레이션)')
plt.legend()

plt.show()
