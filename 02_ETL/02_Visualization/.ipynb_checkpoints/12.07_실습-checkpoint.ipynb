# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

# %matplotlib inline

rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# #### 'flights' 데이터 이용

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_piv = flights.pivot('month','year','passengers')

flights_piv
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
#cmap = plt.get_cmap('PiYG')
#plt.pcolor(flights_piv, cmap = cmap)
sns.heatmap(flights_piv, cmap = 'Greys', annot = True, fmt = "d")

plt.rcParams['figure.figsize'] = (8,4)
plt.rcParams['font.size'] = 10

plt.xticks(np.arange(0.5, len(flights_piv.columns), 1), flights_piv.columns)
plt.yticks(np.arange(0.5, len(flights_piv.index), 1), flights_piv.index)

plt.title('flights data', fontsize = 13)

plt.xlabel('Year', fontsize = 10)
plt.ylabel('Month', fontsize = 10)

#plt.matshow(flights_piv, cmap = cmap)
#plt.colorbar()
plt.show()

# %% [raw]
# 'flights' 데이터 분석 결과 => 전체년도로 따지면 1949년 ~ 1952년까지는
# 평균 승객수가 약 100명대이고, 1954년이후부터 승객수가 점차 증가하는걸 볼 수 있다.

# %% [markdown]
# #### 'exercise' 데이터 이용

# %%
exercise = sns.load_dataset('exercise')

exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
exercise_running = exercise.loc[exercise['kind'] == 'running',:]

exercise_running.head()
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 60          60  21  low fat     93   1 min  running
# 61          61  21  low fat     98  15 min  running
# 62          62  21  low fat    110  30 min  running
# 63          63  22  low fat     98   1 min  running
# 64          64  22  low fat    104  15 min  running

# %%
plt.rcParams['figure.figsize'] = (15,10)
plt.rcParams['font.size'] = 15

plt.subplot(2,1,1)
plt.title('exercise data')
sns.histplot(data = exercise, x = "pulse", hue = "kind", element = "poly")

plt.subplot(2,1,2)
plt.title('exercise-running data')
sns.histplot(data = exercise_running, x = "pulse", hue = "time", element = "poly")

plt.xlim(90,150)
plt.ylim(0,10)

plt.tight_layout()
plt.show()

# %% [raw]
# 'exercise' 데이터 분석 결과 => 휴식을 하거나 걸을때는
# 대부분 맥박이 낮은 걸 확인 할 수 있다
#
# 런닝을 할 땐 맥박수가 다른 kind 데이터보다는 골고루 분산된걸로보아
# exercise - running data(kind 가 'running'인 data)를 확인해보면
# 런닝시간이 길면 맥박이 높아진다는 걸 알 수 있다

# %% [markdown]
# #### 'tips' 데이터 이용

# %%
tips = sns.load_dataset('tips')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['font.size'] = 12
plt.style.use('bmh')

plt.title('tips data')

sns.violinplot(data = tips, x = "day", y = "tip")

plt.show()

# %% [raw]
# tips 데이터 분석 결과 => 목금 보단 토일에 팁을 더 많이 내었고
# 토요일은 최고팁을 찍은 데이터도 보인다. 가장 적게 팁을 낸 요일은 목요일로 보인다.

# %%
taxis = sns.load_dataset('taxis')

taxis.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10,6)
plt.rcParams['font.size'] = 12

#plt.xlim(0,35)
#plt.ylim(0,35)

plt.title('taxis data')

sns.scatterplot(data = taxis, x = "distance", y = "tip", hue = "color")

plt.show()
