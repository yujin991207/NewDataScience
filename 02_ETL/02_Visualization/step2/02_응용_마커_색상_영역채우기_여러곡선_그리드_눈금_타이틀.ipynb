# %% [markdown]
# ## 마커 지정하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 기본사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

# %% [raw]
# plot() 함수에 ‘bo’를 입력해주면 파란색의 원형 마커로 그래프가 표시됩니다.
#
# b’는 blue, ‘o’는 circle을 나타내는 문자입니다.

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### 선/마커 동시에 나타내기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 다양한 조합으로 테스트해 보세요

# %% [markdown]
# ## Matplotlib 색상 지정하기

# %% [markdown]
# ### 포맷 문자열 사용하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### color 키워드 인자 사용하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='darkorange')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### 기본색상

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Tableau 색상

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### css 색상

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![KakaoTalk_20221202_105740174.png](attachment:KakaoTalk_20221202_105740174.png)

# %%
# 다양한 색상을 적용하여 테스트해 보세요

# %% [markdown]
# ### 색상표 코드 이용하기

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
         marker='o', linestyle='--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### 기본 색상

# %% [raw]
# 색상을 지정하지 않으면 기본적으로 아래의 10개의 색상이 반복적으로 표시

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot([1, 2, 3, 4], [10, 10, 10, 10])
plt.plot([1, 2, 3, 4], [9, 9, 9, 9])
plt.plot([1, 2, 3, 4], [8, 8, 8, 8])
plt.plot([1, 2, 3, 4], [7, 7, 7, 7])
plt.plot([1, 2, 3, 4], [6, 6, 6, 6])
plt.plot([1, 2, 3, 4], [5, 5, 5, 5])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# ## 그래프 영역 채우기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 그래프의 특정 영역을 색상으로 채워서 강조
# * fill_between() - 두 수평 방향의 곡선 사이를 채웁니다.
# * fill_betweenx() - 두 수직 방향의 곡선 사이를 채웁니다.
# * fill() - 다각형 영역을 채웁니다.

# %% [markdown]
# ### 기본 사용 - fill_between()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y[1:3], alpha=0.5)

plt.show()

# %% [markdown]
# ### 기본 사용 - fill_betweenx()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)

plt.show()

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)

# x축 영역을 조정하여 공백 제거
plt.xlim([1, 4])

plt.show()

# %% [markdown]
# ### 다각형 영역 채우기 - fill()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='black', alpha=0.5)

plt.show()

# %% [markdown]
# ## 여러 곡선 그리기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'r--', x, x**2, 'bo-', x, x**3, 'g-.')
plt.show()

# %% [markdown]
# ### 스타일 지정하기

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.show()

# %% [markdown]
# ## Matplotlib 그리드 설정하기

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True)

plt.show()

# %% [markdown]
# ### 그리드 축 지정하기

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='y')

plt.show()

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='x')

plt.show()

# %% [markdown]
# ### 스타일 설정하기

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')

plt.show()

# %%
# 세로축의 스타일도 변경해 보세요

# %% [markdown]
# ## 눈금 표시하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 틱 (Tick)은 그래프의 축에 간격을 구분하기 위해 표시하는 눈금
#
# matplotlib.pyplot 모듈의 xticks(), yticks(), tick_params() 함수를 활용

# %% [markdown]
# ### 기본사용

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %% [markdown]
# ## 타이틀 설정하기

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title')

plt.show()

# %% [markdown]
# ### 위치와 오프셋 지정하기

# %% [raw]
# loc 파라미터를 ‘right’로 설정하면, 타이틀이 그래프의 오른쪽 위에 나타나게 됩니다.
#
# {‘left’, ‘center’, ‘right’} 중 선택할 수 있으며 디폴트는 ‘center’입니다.
#
# pad 파라미터는 타이틀과 그래프와의 간격을 포인트 단위로 설정합니다.

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

plt.show()

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

plt.show()

# %% [markdown]
# ### 타이틀 정보 얻기

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
title_right = plt.title('Left Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
title_left = plt.title('Right Graph Title', fontdict=title_font, loc='left', pad=20)

print(f'왼쪽 타이틀 위치: {title_left.get_position()}')
print(f'왼쪽 타이틀 이름: {title_left.get_text()}\n')

print(f'오른쪽 타이틀 위치: {title_right.get_position()}')
print(f'오른쪽 타이틀 위치: {title_right.get_text()}')

plt.show()
# Out:
# 왼쪽 타이틀 위치: (0.0, 1.0)
# 왼쪽 타이틀 이름: Right Graph Title
#
# 오른쪽 타이틀 위치: (1.0, 1.0)
# 오른쪽 타이틀 위치: Left Graph Title

# %% [markdown]
# ## 수평선/수직선 표시하기

# %% [markdown]
# ### 수평선 그리기 - axhline([y위치, x시작점(퍼센트), x종료점(퍼센트)], 기타 스타일 옵션)

# %%
x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

# plt.axhline(위치선정)
plt.axhline(4.0, 0.1, 0.9, color='lightgray', linestyle='--', linewidth=2)

plt.show()

# %%
x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axhline(4.0, 0.5, 1, color='lightgray', linestyle='--', linewidth=2)

plt.show()

# %% [markdown]
# ### 수평선 그리기 - hlines([y위치, x시작점, x종료점], 기타 스타일 옵션)

# %%
x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axhline(4.0, 0.1, 0.9, color='lightgray', linestyle='--', linewidth=2)
plt.hlines(-0.62, 1.0, 2.5, color='gray', linestyle='solid', linewidth=3)

plt.show()

# %%
x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axhline(4.0, 0.1, 0.9, color='lightgray', linestyle='--', linewidth=2)
# x 스케일에 맞추어 수치 입력
plt.hlines(-0.62, 0.5, 3.0, color='gray', linestyle='solid', linewidth=3)

plt.show()
