# %% [markdown]
# ## 컬러맵 설정하기

# %% [markdown]
# ![image.png](attachment:image.png)
# pyplot 모듈은 다양한 컬러뱁을 설정하기 위한 함수 제공

# %% [markdown]
# ### 기본 사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
np.random.seed(0)
arr = np.random.standard_normal((8, 100))
arr.shape
# Out:
# (8, 100)

# %%
arr[0].shape
# Out:
# (100,)

# %%
plt.subplot(2, 2, 1)
# plt.scatter(arr[0], arr[1], c=arr[1], cmap='spring')
plt.scatter(arr[0], arr[1], c=arr[1])
plt.spring()
plt.title('spring')

plt.subplot(2, 2, 2)
plt.scatter(arr[2], arr[3], c=arr[3])
plt.summer()
plt.title('summer')

plt.subplot(2, 2, 3)
plt.scatter(arr[4], arr[5], c=arr[5])
plt.autumn()
plt.title('autumn')

plt.subplot(2, 2, 4)
plt.scatter(arr[6], arr[7], c=arr[7])
plt.winter()
plt.title('winter')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 히트맵

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 히트맵 (Heatmap)은 다양한 값을 갖는 숫자 데이터를 열분포 형태와 같이 색상을 이용해서 시각화한 것입니다.
#
# 지도 이미지 위에 인구의 분포를 표현하거나, 웹사이트 이미지 위에 마우스의 클릭 위치를 표시하는 등의 다양한 정보를 시각화할 수 있습니다.
#
# matplotlib.pyplot 모듈의 matshow() 함수를 이용해서 2차원 어레이 형태의 숫자 데이터를 히트맵을 표시

# %%
arr = np.random.standard_normal((30, 40))
arr
# Out:
# array([[ 1.41117206,  0.78580383, -0.05746952, ..., -0.32566947,
#          0.47043314,  0.31144707],
#        [ 0.23958276, -0.36980117,  0.97253579, ..., -0.85891991,
#          0.05095428, -1.79422927],
#        [ 1.32646164, -0.96460642,  0.05989468, ..., -0.26393735,
#          0.35281661, -0.15277442],
#        ...,
#        [ 0.44721209, -0.61612112,  0.46629004, ..., -2.12389002,
#          0.4595849 ,  0.28005786],
#        [ 1.39053397, -1.64134861, -0.15503581, ..., -1.24021634,
#          0.90005424,  1.80224223],
#        [-0.2082851 ,  1.57437124,  0.19898949, ...,  0.15843385,
#         -1.14190142, -1.31097037]])

# %%
# 넘파이 배열을 1차원으로 변경
arr2 = arr.copy()
arr2 = arr2.reshape(-1,)
arr2
# Out:
# array([ 1.41117206,  0.78580383, -0.05746952, ...,  0.15843385,
#        -1.14190142, -1.31097037])

# %%
arr2.shape
# Out:
# (1200,)

# %%
pd.Series(arr2).describe()
# Out:
# count    1200.000000
# mean        0.022655
# std         0.964137
# min        -2.994613
# 25%        -0.644207
# 50%         0.023625
# 75%         0.628779
# max         3.170975
# dtype: float64

# %%
plt.matshow(arr)
plt.colorbar()
plt.show()

# %% [markdown]
# ### 색상 범위 지정하기

# %%
arr = np.random.standard_normal((30, 40))

plt.matshow(arr)

plt.colorbar()
# 색깔의 범위를 -1에서 1사이로 표현
# -1보다 작은 것은 -1로 표시 1보다 큰것은 1로 표시
plt.clim(-1.0, 1.0)
# plt.clim(-3.0, 3.0)

plt.show()

# %% [markdown]
# ### 컬러맵 지정

# %%
import matplotlib.pyplot as plt
import numpy as np

arr = np.random.standard_normal((30, 40))
# cmap = plt.get_cmap('PiYG')
# cmap = plt.get_cmap('BuGn')
cmap = plt.get_cmap('Greys')
#cmap = plt.get_cmap('bwr')

plt.matshow(arr, cmap=cmap)
plt.colorbar()
plt.show()

# %% [raw]
# cmap 키워드 인자를 통해 표시할 컬러맵의 종류를 지정
#
# matplotlib.pyplot 모듈의 get_cmap() 함수를 이용해서 Matplotlib 컬러맵을 가져와서 matshow()에 입력
#
# 다양한 컬러맵을 적용한 히트맵은 아래 참고

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 샘플예제는 랜덤하게 데이터가 생성되어 빈도가 높은 영역이 식별되지 않았음
# 아래 예제가 빈도가 식별된 다양한 형태의 예

# %% [markdown]
# <center> 월별 년도별 항공사 A노선 승객수 </center>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <center> 도시 별 공기질 </center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center> 시간 경과에 따른 인구 변화 </center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 히트맵

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 히트맵 (Heatmap)은 다양한 값을 갖는 숫자 데이터를 열분포 형태와 같이 색상을 이용해서 시각화한 것입니다.
#
# 지도 이미지 위에 인구의 분포를 표현하거나, 웹사이트 이미지 위에 마우스의 클릭 위치를 표시하는 등의 다양한 정보를 시각화할 수 있습니다.
#
# matplotlib.pyplot 모듈의 matshow() 함수를 이용해서 2차원 어레이 형태의 숫자 데이터를 히트맵을 표시

# %%
arr = np.random.standard_normal((30, 40))
arr
# Out:
# array([[-0.34236804, -0.31030423,  0.81303638, ...,  1.98969308,
#         -0.37316831,  0.14103673],
#        [-0.94181547, -0.7028346 , -1.37883697, ...,  0.96222238,
#          0.47054891, -0.23580421],
#        [ 0.67878929,  1.15361803, -0.55473281, ...,  0.547426  ,
#          0.14376031,  0.13022098],
#        ...,
#        [ 1.53655889,  0.1711569 ,  0.01356322, ..., -0.74586233,
#         -0.29784561, -0.9822353 ],
#        [-1.32182524,  0.16335682, -0.62496724, ...,  0.97851934,
#         -0.57316443, -0.98444607],
#        [-0.99418635,  0.1693081 , -0.93171428, ...,  0.51254148,
#         -1.20111987, -0.59641499]])

# %%
# 넘파이 배열을 1차원으로 변경
arr2 = arr.copy()
arr2 = arr2.reshape(-1,)
arr2
# Out:
# array([-0.34236804, -0.31030423,  0.81303638, ...,  0.51254148,
#        -1.20111987, -0.59641499])

# %%
arr2.shape
# Out:
# (1200,)

# %%
pd.Series(arr2).describe()
# Out:
# count    1200.000000
# mean        0.001498
# std         0.993963
# min        -3.007437
# 25%        -0.669387
# 50%        -0.013569
# 75%         0.673107
# max         2.979976
# dtype: float64

# %%
plt.matshow(arr)
plt.colorbar()
plt.show()

# %% [markdown]
# ### 색상 범위 지정하기

# %%
arr = np.random.standard_normal((30, 40))

plt.matshow(arr)

plt.colorbar()
# 색깔의 범위를 -1에서 1사이로 표현
# -1보다 작은 것은 -1로 표시 1보다 큰것은 1로 표시
plt.clim(-1.0, 1.0)
# plt.clim(-3.0, 3.0)

plt.show()

# %% [markdown]
# ### 컬러맵 지정

# %%
import matplotlib.pyplot as plt
import numpy as np

arr = np.random.standard_normal((30, 40))
# cmap = plt.get_cmap('PiYG')
# cmap = plt.get_cmap('BuGn')
# cmap = plt.get_cmap('Greys')
cmap = plt.get_cmap('bwr')

plt.matshow(arr, cmap=cmap)
plt.colorbar()
plt.show()

# %% [raw]
# cmap 키워드 인자를 통해 표시할 컬러맵의 종류를 지정
#
# matplotlib.pyplot 모듈의 get_cmap() 함수를 이용해서 Matplotlib 컬러맵을 가져와서 matshow()에 입력
#
# 다양한 컬러맵을 적용한 히트맵은 아래 참고

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 샘플예제는 랜덤하게 데이터가 생성되어 빈도가 높은 영역이 식별되지 않았음
# 아래 예제가 빈도가 식별된 다양한 형태의 예

# %% [markdown]
# <center> 월별 년도별 항공사 A노선 승객수 </center>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <center> 도시 별 공기질 </center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center> 시간 경과에 따른 인구 변화 </center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ## 텍스트 삽입하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# matplotlib.pyplot 모듈의 text() 함수는 그래프의 적절한 위치에 텍스트를 삽입

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

# density=True로 설정해주면, 밀도함수가 되어서 막대의 아래 면적이 1이 됩니다.
plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(1.0, 0.35, '2.0*np.random.randn(10000)+1.0')
plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.20, 'np.random.standard_normal(10000)')
plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(5.0, 0.08, 'np.random.rand(5000)-10.0')
plt.show()

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

# density=False (기본설정)이면 y 값이 변경되기 때문에 text의 y값도 변경되어야 한다.
plt.hist(a, bins=100, alpha=0.7, histtype='step')
plt.text(1.0, 600, '2.0*np.random.randn(10000)+1.0')
plt.hist(b, bins=50,alpha=0.5, histtype='stepfilled')
plt.text(2.0, 300, 'np.random.standard_normal(10000)')
plt.hist(c, bins=100, alpha=0.9, histtype='step')
plt.text(5.0, 60, 'np.random.rand(5000)-10.0')
plt.show()

# %% [markdown]
# ### 텍스트 스타일 설정하기

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

font1 = {'family': 'serif',
      'color':  'darkred',
      'weight': 'normal',
      'size': 16}

font2 = {'family': 'Times New Roman',
      'color':  'blue',
      'weight': 'bold',
      'size': 12,
      'alpha': 0.7}

font3 = {'family': 'Arial',
      'color':  'forestgreen',
      'style': 'italic',
      'size': 14}

plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(1.0, 0.35, 'np.random.randn()', fontdict=font1)
plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.20, 'np.random.standard_normal()', fontdict=font2)
plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(5.0, 0.08, 'np.random.rand()', fontdict=font3)

plt.show()

# %% [markdown]
# ### 텍스트 회전하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(-3.0, 0.15, 'np.random.randn()', fontdict=font1, rotation=85)
plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.0, 'np.random.standard_normal()', fontdict=font2, rotation=-60)
plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(-10.0, 0.08, 'np.random.rand()', fontdict=font3)
plt.show()

# %% [markdown]
# ### 텍스트 상자 스타일 설정하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

font1 = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16}

font2 = {'family': 'Times New Roman',
        'color':  'blue',
        'weight': 'bold',
        'size': 12,
        'alpha': 0.7}

font3 = {'family': 'Arial',
        'color':  'forestgreen',
        'style': 'italic',
        'size': 14}

box1 = {'boxstyle': 'round',
        'ec': (1.0, 0.5, 0.5),
        'fc': (1.0, 0.8, 0.8)}

box2 = {'boxstyle': 'square',
        'ec': (0.5, 0.5, 1.0),
        'fc': (0.8, 0.8, 1.0),
        'linestyle': '--'}

box3 = {'boxstyle': 'square',
        'ec': (0.3, 1.0, 0.5),
        'fc': (0.8, 1.0, 0.5),
        'linestyle': '-.',
        'linewidth': 2}

plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(-3.0, 0.15, 'np.random.randn()', fontdict=font1, rotation=85, bbox=box1)
plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.0, 'np.random.standard_normal()', fontdict=font2, rotation=-60, bbox=box2)
plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(-10.0, 0.08, 'np.random.rand()', fontdict=font3, bbox=box3)
plt.show()
