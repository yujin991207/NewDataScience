# %%
from xml.etree.ElementTree import parse
from xml.etree.ElementTree import dump

# %%
tree = parse("students_info.xml")
note = tree.getroot()

for parent in note.iter("student"):
    print("\n*",parent.get("name"))
    print("- 성별:",parent.get("sex"))

    for language in note.iter("language"):
        print(language.get("name"))
        
#     for child in parent:
#         #print(child.text)
#         age = child.find("age")
#         print(age)
# Out:
# * 영호
# - 성별: 남
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
#
# * 민선
# - 성별: 여
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
#
# * 상민
# - 성별: 남
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
#
# * 세중
# - 성별: 남
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
#
# * 규동
# - 성별: 남
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
#
# * 치우
# - 성별: 남
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
#
# * 현기
# - 성별: 남
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
#
# * 정헌
# - 성별: 남
# C
# Java
# C++
# C
# C++
# Java
# Ruby
# sas
# R
# C
# Verilog
