# %% [markdown]
# # 가설
# * 조사구역 : 관악구, 금천구
# * 공원면적이 클수록 공원보유시설(유희시설)이 많이 있을까?
# * 어린이 공원 주변에 어린이 보호구역이 포함되어 있을까?

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc
import requests
import json
from collections import Counter
import seaborn as sns

import folium
from folium.plugins import HeatMap
from folium import Marker
from folium.plugins import MarkerCluster
font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

# %%
# json파일을 읽어온다
def open_json(file_name, encoding):
    with open(file_name, encoding=encoding) as json_file: 
        json_object = json.load(json_file)
        json_string = json.dumps(json_object)
        json_data = json.loads(json_string)
    return json_data

# %%
json_data = open_json('전국도시공원정보표준데이터.json',encoding = 'utf-8')
#json_data

# %% [markdown]
# ### => json 데이터를 불러온다

# %% [markdown]
# # 데이터 원본 분석

# %%
# 열과 데이터의 값을 가져온다
def get_df_info(json_data, records_root_name):
    column_list=[]
    all_data=[]
    is_first=True
    for record in json_data[records_root_name]:
        row_data_list=[]
        for key, value in record.items():
            if is_first:
                column_list.append(key)
            row_data_list.append(value)
        all_data.append(row_data_list)
        is_first=False
        
    return column_list, all_data

# %%
column_list, all_data = get_df_info(json_data,'records')

# %%
df = pd.DataFrame(all_data, columns=column_list)
df.head()
# Out:
#           관리번호     공원명   공원구분 소재지도로명주소              소재지지번주소             위도  \
# 0  47190-00127  백현체육공원   체육공원           경상북도 구미시 산동면 백현리 79  36.1864293331
# 1  47190-00128   둘모아공원  어린이공원            경상북도 구미시 봉곡동 584-2      36.148431
# 2  47190-00129   다붓소공원    소공원           경상북도 구미시 봉곡동 765 일원      36.155883
# 3  47190-00130   다붓1공원  어린이공원            경상북도 구미시 봉곡동 457-1      36.156392
# 4  47190-00131   다붓2공원  어린이공원              경상북도 구미시 봉곡동 767  36.1548081316
#
#                경도   공원면적 공원보유시설(운동시설) 공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설)  \
# 0  128.4784906760  90967
# 1  128.3165938966   4279
# 2      128.311526    805
# 3      128.314372   1585
# 4      128.314372   1637
#
#   공원보유시설(기타시설) 지정고시일 관리기관명 전화번호     데이터기준일자   제공기관코드     제공기관명
# 0                                2022-06-09  5080000  경상북도 구미시
# 1                                2022-06-09  5080000  경상북도 구미시
# 2                                2022-06-09  5080000  경상북도 구미시
# 3                                2022-06-09  5080000  경상북도 구미시
# 4                                2022-06-09  5080000  경상북도 구미시

# %% [markdown]
# ### => json파일을 Df형식으로 만들어 주었다

# %%
df.shape
# Out:
# (16764, 19)

# %%
df= df[['공원명','공원구분','위도','경도','소재지지번주소','공원면적','공원보유시설(유희시설)']]
df.head()
# Out:
#       공원명   공원구분             위도              경도              소재지지번주소   공원면적  \
# 0  백현체육공원   체육공원  36.1864293331  128.4784906760  경상북도 구미시 산동면 백현리 79  90967
# 1   둘모아공원  어린이공원      36.148431  128.3165938966   경상북도 구미시 봉곡동 584-2   4279
# 2   다붓소공원    소공원      36.155883      128.311526  경상북도 구미시 봉곡동 765 일원    805
# 3   다붓1공원  어린이공원      36.156392      128.314372   경상북도 구미시 봉곡동 457-1   1585
# 4   다붓2공원  어린이공원  36.1548081316      128.314372     경상북도 구미시 봉곡동 767   1637
#
#   공원보유시설(유희시설)
# 0
# 1
# 2
# 3
# 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16764 entries, 0 to 16763
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   공원명           16764 non-null  object
#  1   공원구분          16764 non-null  object
#  2   위도            16764 non-null  object
#  3   경도            16764 non-null  object
#  4   소재지지번주소       16764 non-null  object
#  5   공원면적          16764 non-null  object
#  6   공원보유시설(유희시설)  16764 non-null  object
# dtypes: object(7)
# memory usage: 916.9+ KB

# %% [markdown]
# ### => df의 위도와 경도, 면적은 float 타입으로 변환해줘야 한다

# %%
df = df[(df['경도'] != "") & (df['위도'] != "") & (df['공원면적'] != "")]

# %%
df['위도'] = df['위도'].astype('float')
df['경도'] = df['경도'].astype('float')
df['공원면적'] = df['공원면적'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16606 entries, 0 to 16763
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   공원명           16606 non-null  object
#  1   공원구분          16606 non-null  object
#  2   위도            16606 non-null  float64
#  3   경도            16606 non-null  float64
#  4   소재지지번주소       16606 non-null  object
#  5   공원면적          16606 non-null  float64
#  6   공원보유시설(유희시설)  16606 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# ### => 원본데이터 분석 끝

# %% [markdown]
# ## 결측치, 이상치 처리방안 결정

# %%
df.isnull().sum()
# Out:
# 공원명             0
# 공원구분            0
# 위도              0
# 경도              0
# 소재지지번주소         0
# 공원면적            0
# 공원보유시설(유희시설)    0
# dtype: int64

# %%
df[df['소재지지번주소'] == ''].shape
# Out:
# (334, 7)

# %% [markdown]
# #### => 주소가 둘다 결측지인 경우는 없다

# %%
df.drop(index = df[df['소재지지번주소']==''].index, inplace = True)

# %%
df[df['공원명']== '']
# Out:
# Empty DataFrame
# Columns: [공원명, 공원구분, 위도, 경도, 소재지지번주소, 공원면적, 공원보유시설(유희시설)]
# Index: []

# %%
df[df['공원구분']== '']
# Out:
# Empty DataFrame
# Columns: [공원명, 공원구분, 위도, 경도, 소재지지번주소, 공원면적, 공원보유시설(유희시설)]
# Index: []

# %%
len(df[df['공원보유시설(유희시설)']== ''])
# Out:
# 10321

# %%
len(df[df['공원면적']== ''])
# Out:
# 0

# %%
df['공원보유시설(유희시설)'] = df['공원보유시설(유희시설)'].replace('','[시설미보유]')
df.head()
# Out:
#       공원명   공원구분         위도          경도              소재지지번주소     공원면적  \
# 0  백현체육공원   체육공원  36.186429  128.478491  경상북도 구미시 산동면 백현리 79  90967.0
# 1   둘모아공원  어린이공원  36.148431  128.316594   경상북도 구미시 봉곡동 584-2   4279.0
# 2   다붓소공원    소공원  36.155883  128.311526  경상북도 구미시 봉곡동 765 일원    805.0
# 3   다붓1공원  어린이공원  36.156392  128.314372   경상북도 구미시 봉곡동 457-1   1585.0
# 4   다붓2공원  어린이공원  36.154808  128.314372     경상북도 구미시 봉곡동 767   1637.0
#
#   공원보유시설(유희시설)
# 0      [시설미보유]
# 1      [시설미보유]
# 2      [시설미보유]
# 3      [시설미보유]
# 4      [시설미보유]

# %% [raw]
# => 공원보유시설(유희시설)데이터의 상당수가 비어 있지만 공원보유시설
#     미보유라고 판단하여
#     값을 [시설미보유]라고 지정하기로 하였다

# %% [markdown]
# ### => 데이터 원본분석 끝

# %% [markdown]
# ---

# %% [markdown]
# ## Step 1. 전국의 어떤 공원이 가장 많이 존재하는가?

# %%
df['공원구분'].unique()
# Out:
# array(['체육공원', '어린이공원', '소공원', '근린공원', '수변공원', '문화공원', '묘지공원', '역사공원',
#        '기타', '도시자연공원구역', '도시농업공원', '기타공원', '주제공원', '도시자연공원', '마을숲',
#        '마을마당'], dtype=object)

# %%
df['공원구분'].value_counts()
# Out:
# 어린이공원       8689
# 근린공원        3679
# 소공원         2494
# 문화공원         349
# 수변공원         301
# 기타           232
# 체육공원         228
# 역사공원         171
# 마을마당          49
# 묘지공원          35
# 기타공원          30
# 도시농업공원         7
# 도시자연공원         3
# 도시자연공원구역       2
# 주제공원           2
# 마을숲            1
# Name: 공원구분, dtype: int64

# %%
df['공원구분'].replace('기타공원','기타공원', inplace=True)
df['공원구분'].replace('마을마당','기타공원', inplace=True)
df['공원구분'].replace('묘지공원','기타공원', inplace=True)
df['공원구분'].replace('도시농업공원','기타공원', inplace=True)
df['공원구분'].replace('도시자연공원','기타공원', inplace=True)
df['공원구분'].replace('도시자연공원구역','기타공원', inplace=True)
df['공원구분'].replace('주제공원','기타공원', inplace=True)
df['공원구분'].replace('마을숲','기타공원', inplace=True)
df['공원구분'].replace('기타','기타공원', inplace=True)

df['공원구분'].value_counts()
# Out:
# 어린이공원    8689
# 근린공원     3679
# 소공원      2494
# 기타공원      361
# 문화공원      349
# 수변공원      301
# 체육공원      228
# 역사공원      171
# Name: 공원구분, dtype: int64

# %%
df['공원구분'].unique()
# Out:
# array(['체육공원', '어린이공원', '소공원', '근린공원', '수변공원', '문화공원', '기타공원', '역사공원'],
#       dtype=object)

# %% [markdown]
# ### => 공원분류 중 100건이 안되는 데이터는 기타로 묶어서 분류 해 주었다

# %%
park_list=df.groupby('공원구분')['공원구분'].count().tolist()
park_list
# Out:
# [3679, 361, 349, 2494, 301, 8689, 171, 228]

# %%
# 컬러 조절
labels = ['근린공원','기타','문화공원','소공원','수변공원','어린이공원','역사공원','체육공원']
explode = [0, 0,0, 0, 0, 0.2, 0, 0]
wedgeprops={'width': 0.8, 'edgecolor': 'w', 'linewidth': 2}
plt.pie(park_list, autopct='%.1f%%', labels = labels, startangle=180, counterclock=False, shadow = True, wedgeprops=wedgeprops,explode=explode)

plt.show()

# %% [markdown]
# ### => 전국의 공원을 구분하여 파이차트로 시각화 해주었다

# %% [markdown]
# # Step2 서울시 어린이공원의 분포도 확인

# %%
c = folium.Map(location=[37.541, 126.986],
               zoom_start=11, 
               width=750, 
               height=650
              )

# %%
requests = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
content = requests.content
seoul_geo = json.loads(content)

# %%
folium.GeoJson(seoul_geo).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_359886c9e9495bd621098eca0ddf2276 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 650.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_359886c9e9495bd621098eca0ddf2276&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_359886c9e9495bd621098eca0ddf2276 = L.map(
#                 &quot;map_359886c9e9495bd621098eca0ddf2276&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cbd1d2cae2933a9b492b1c9585e30ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_359886c9e9495bd621098eca0ddf2276);
#
#
#
#         function geo_json_912f414403c6c33a6d83c48a3391823e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_912f414403c6c33a6d83c48a3391823e = L.geoJson(null, {
#                 onEachFeature: geo_json_912f414403c6c33a6d83c48a3391823e_onEachFeature,
#
#         });
#
#         function geo_json_912f414403c6c33a6d83c48a3391823e_add (data) {
#             geo_json_912f414403c6c33a6d83c48a3391823e
#                 .addData(data)
#                 .addTo(map_359886c9e9495bd621098eca0ddf2276);
#         }
#             geo_json_912f414403c6c33a6d83c48a3391823e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964, 37.50046502392898], [127.15223804785649, 37.50170492532197], [127.15401160147654, 37.500347919909956], [127.16086308579277, 37.49886565522751], [127.1634944215765, 37.497445406097484], [127.16199885180917, 37.49402577547199], [127.16216448592424, 37.491639601211624], [127.16040295326431, 37.4877818619403], [127.15892216655034, 37.486126922469445], [127.15393282790794, 37.48483891408459], [127.15147990997852,

# %% [markdown]
# #### => 지도 기본셋팅

# %%
childpark = df[df['공원구분'] == '어린이공원']
childpark=childpark[childpark['소재지지번주소'].str.contains('서울')]
childpark
# Out:
#               공원명   공원구분         위도          경도                소재지지번주소  \
# 214       목련어린이공원  어린이공원  37.587380  126.880225      서울특별시 마포구 상암동1742
# 215      산수유어린이공원  어린이공원  37.585485  126.879008      서울특별시 마포구 상암동1744
# 216     산딸나무어린이공원  어린이공원  37.583547  126.877927      서울특별시 마포구 상암동1753
# 217    애오개도담어린이공원  어린이공원  37.553433  126.958529    서울특별시 마포구 아현동 800-6
# 218      쌍룡산어린이공원  어린이공원  37.552173  126.950512      서울특별시 마포구 아현동 769
# ...           ...    ...        ...         ...                    ...
# 15266        한  신  어린이공원  37.588130  127.076900  서울특별시 중랑구 면목3·8 30-38
# 15267        이  화  어린이공원  37.586990  127.100300    서울특별시 중랑구 상봉2 114-1
# 15268     면목1(가칭)  어린이공원  37.580278  127.093056   서울특별시 중랑구 상봉2 122-31
# 15269        봉  황  어린이공원  37.595020  127.084800   서울특별시 중랑구 상봉2 136-35
# 15270        상  봉  어린이공원  37.593090  127.082500   서울특별시 중랑구 중화2 302-57
#
#          공원면적 공원보유시설(유희시설)
# 214    1501.0      [시설미보유]
# 215    2011.0      [시설미보유]
# 216    1499.0      [시설미보유]
# 217    3212.0      [시설미보유]
# 218    5911.0      [시설미보유]
# ...       ...          ...
# 15266   995.0      [시설미보유]
# 15267   215.0      [시설미보유]
# 15268  1578.6      [시설미보유]
# 15269  1014.0      [시설미보유]
# 15270  1058.0      [시설미보유]
#
# [1035 rows x 7 columns]

# %%
childpark_addr=childpark['소재지지번주소'].tolist()
childpark_addr
# Out:
# ['서울특별시 마포구 상암동1742',
#  '서울특별시 마포구 상암동1744',
#  '서울특별시 마포구 상암동1753',
#  '서울특별시 마포구 아현동 800-6',
#  '서울특별시 마포구 아현동 769',
#  '서울특별시 마포구 용강동 63-2',
#  '서울특별시 마포구 아현동 802번지 일대',
#  '서울특별시 마포구 망원동 458-64',
#  '서울특별시 마포구 창전동 26-1',
#  '서울특별시 마포구 신수동 95-5일원',
#  '서울특별시 마포구 서교동 479-1',
#  '서울특별시 마포구 동교동 168-1',
#  '서울특별시 마포구 동교동 197-17',
#  '서울특별시 마포구 서교동 489',
#  '서울특별시 마포구 합정동 394-1',
#  '서울특별시 마포구 망원동 381-1',
#  '서울특별시 마포구 망원동 408-3',
#  '서울특별시 마포구 망원2동 436-1',
#  '서울특별시 마포구 망원2동 509-1',
#  '서울특별시 마포구 연남동 563-5',
#  '서울특별시 마포구 연남동 250-1',
#  '서울특별시 마포구 성산동 113-2',
#  '서울특별시 마포구 성산동 588-8',
#  '서울특별시 마포구 성산동 587-18 일대',
#  '서울특별시 마포구 성산동 667-1',
#  '서울특별시 마포구 성산동 147-5',
#  '서울특별시 마포구 성산동 200-50',
#  '서울특별시 마포구 성산동 200-335',
#  '서울특별시 마포구 성산동 199-11',
#  '서울특별시 마포구 중동 36-27',
#  '서울특별시 마포구 중동 228',
#  '서울특별시 마포구 중동 36-34',
#  '서울특별시 마포구 중동 40-5 일대',
#  '서울특별시 마포구 상암동 1619',
#  '서울특별시 마포구 상암동 14-5',
#  '서울특별시 마포구 상암동 1636',
#  '서울특별시 마포구 상암동 1656',
#  '서울특별시 마포구 상암동 1681',
#  '서울특별시 동작구 상도동 36-1',
#  '서울특별시 동작구 상도1동 558',
#  '서울특별시 마포구 공덕동 470-1',
#  '서울특별시 마포구 공덕동 467-1,2,3',
#  '서울특별시 마포구 마포동 350-5',
#  '서울특별시 마포구 도화동 533',
#  '서울특별시 마포구 도화동 540',
#  '서울특별시 마포구 도화동 555-1',
#  '서울특별시 마포구 대흥동 660-1',
#  '서울특별시 마포구 현석동 1-5',
#  '서울특별시 마포구 창전동 35-28',
#  '서울특별시 마포구 상수동 72-7',
#  '서울특별시 마포구 서교동 391-1',
#  '서울특별시 강동구 암사1동 468-2',
#  '서울특별시 강동구 암사2동 515',
#  '서울특별시 강동구 암사1동 453-8',
#  '서울특별시 강동구 암사3동 449-8',
#  '서울특별시 강동구 암사3동 440',
#  '서울특별시 강동구 천호2동 363-5',
#  '서울특별시 강동구 천호2동 300',
#  '서울특별시 강동구 천호2동 305-11',
#  '서울특별시 강동구 천호2동 338-19',
#  '서울특별시 강동구 천호1동 21-192',
#  '서울특별시 강동구 천호1동 21-194',
#  '서울특별시 강동구 천호1동 21-197',
#  '서울특별시 강동구 천호1동 231-14',
#  '서울특별시 강동구 천호2동 431-2',
#  '서울특별시 강동구 고덕1동 536',
#  '서울특별시 강동구 고덕1동 308',
#  '서울특별시 강동구 고덕2동 253',
#  '서울특별시 강동구 고덕2동 219',
#  '서울특별시 강동구 고덕2동 178',
#  '서울특별시 강동구 상일동 122',
#  '서울특별시 강동구 상일동 132',
#  '서울특별시 동작구 사당동 316-37',
#  '서울특별시 강북구 수유1동 49-7',
#  '서울특별시 강북구 번2동 235',
#  '서울특별시 강북구 번3동 244',
#  '서울특별시 강북구 송중동 92-7',
#  '서울특별시 강북구 삼각산동 811-8',
#  '서울특별시 강북구 삼각산동 811-13',
#  '서울특별시 강북구 송중동 8-73',
#  '서울특별시 강북구 번1동 447-1',
#  '서울특별시 강북구 번1동 417-27',
#  '서울특별시 강북구 번1동 472-44',
#  '서울특별시 강북구 번2동 228',
#  '서울특별시 강북구 번3동 240',
#  '서울특별시 강북구 수유2동 252-19',
#  '서울특별시 강북구 수유3동 194-41',
#  '서울특별시 강북구 수유3동 172-209',
#  '서울특별시 강북구 수유3동 25-1',
#  '서울특별시 양천구 신정7동 326-2',
#  '서울특별시 양천구 신정7동 1306-2',
#  '서울특별시 양천구 목3동 965-1',
#  '서울특별시 강북구 미아동 258-236',
#  '서울특별시 강북구 미아동 258-56',
#  '서울특별시 강북구 미아동 258-148',
#  '서울특별시 강북구 미아동 222-20',
#  '서울특별시 강북구 미아동 165-3',
#  '서울특별시 강북구 송천동 329-15',
#  '서울특별시 강북구 미아동 309-43',
#  '서울특별시 강북구 미아동 159-71',
#  '서울특별시 강북구 삼양동 776-17',
#  '서울특별시 강북구 송천동 707-73',
#  '서울특별시 강북구 삼양동 791-1776',
#  '서울특별시 양천구 신정6동 332-1',
#  '서울특별시 양천구 신정7동 325-2',
#  '서울특별시 강동구 명일1동 315-1',
#  '서울특별시 강동구 명일1동 326-10',
#  '서울특별시 강동구 성내1동 463-4',
#  '서울특별시 광진구 구의동 590-2',
#  '서울특별시 광진구 구의동 227-13',
#  '서울특별시 광진구 구의동 60-8',
#  '서울특별시 광진구 구의동 560-5',
#  '서울특별시 광진구 구의동 546-2',
#  '서울특별시 광진구 구의동 249-25',
#  '서울특별시 광진구 광장동 242-1',
#  '서울특별시 광진구 광장동 387-1',
#  '서울특별시 광진구 자양동 74-21',
#  '서울특별시 광진구 자양동 619-20',
#  '서울특별시 광진구 자양동 630',
#  '서울특별시 광진구 자양동 804-10',
#  '서울특별시 광진구 자양동 686-52',
#  '서울특별시 광진구 자양동 651-50',
#  '서울특별시 광진구 자양동 582-19',
#  '서울특별시 광진구 자양동 5-7',
#  '서울특별시 양천구 목1동 925-1',
#  '서울특별시 양천구 목3동 712-1',
#  '서울특별시 양천구 목3동 611-1',
#  '서울특별시 양천구 목3동 646-23',
#  '서울특별시 양천구 신정4동 888-1',
#  '서울특별시 양천구 신정4동 910-9',
#  '서울특별시 양천구 신정4동 936-13',
#  '서울특별시 양천구 신정4동 876-1',
#  '서울특별시 양천구 신정4동 896-22',
#  '서울특별시 양천구 신정4동 920-3',
#  '서울특별시 양천구 신정6동 314-1',
#  '서울특별시 양천구 신정6동 327-1',
#  '서울특별시 양천구 신정6동 328-1',
#  '서울특별시 양천구 신정6동 329-2',
#  '서울특별시 양천구 신정6동 330-1',
#  '서울특별시 동작구 사당동 300-26',
#  '서울특별시 동작구 사당동 1000',
#  '서울특별시 동작구 사당동 1000-13',
#  '서울특별시 동작구 대방동 414-29 외 5',
#  '서울특별시 동작구 상도동 335-141',
#  '서울특별시 동작구 상도동 299-193',
#  '서울특별시 동작구 사당동 1144',
#  '서울특별시 동작구 사당동 233-12',
#  '서울특별시 동작구 사당동 산32-76',
#  '서울특별시 동작구 본동 483',
#  '서울특별시 동작구 사당동 1138-1',
#  '서울특별시 동작구 신대방동 719-1',
#  '서울특별시 동작구 신대방동 719-3',
#  '서울특별시 동작구 상도동 527-1외 2',
#  '서울특별시 동작구 동작동 333-3',
#  '서울특별시 동작구 상도동 521-1',
#  '서울특별시 동작구 흑석동 335-10',
#  '서울특별시 동작구 사당동 1157-1',
#  '서울특별시 강남구 수서동 712-1',
#  '서울특별시 동작구 대방동 362-11',
#  '서울특별시 동작구 상도동 426',
#  '서울특별시 동작구 상도1동 424',
#  '서울특별시 동작구 상도4동 211-415',
#  '서울특별시 동작구 사당동 1028-1',
#  '서울특별시 동작구 신대방동 492-222외 1',
#  '서울특별시 동작구 상도동 380-2',
#  '서울특별시 동작구 사당동 316-23',
#  '서울특별시 동작구 사당동 316-33',
#  '서울특별시 동대문구 답십리동 1002-1',
#  '서울특별시 강남구 수서동 707-1',
#  '서울특별시 영등포구 신길동 541',
#  '서울특별시 영등포구 당산동5가 4-13',
#  '서울특별시 영등포구 대림동 1127-6',
#  '서울특별시 영등포구 대림동 742',
#  '서울특별시 영등포구 대림동 715',
#  '서울특별시 영등포구 대림동 657',
#  '서울특별시 영등포구 양평동4가 301-7',
#  '서울특별시 영등포구 영등포동 647-3',
#  '서울특별시 영등포구 신길동 4937-1',
#  '서울특별시 영등포구 신길동 455-1',
#  '서울특별시 영등포구 영등포동6가 65-1',
#  '서울특별시 영등포구 여의도동 50-2',
#  '서울특별시 영등포구 여의도동 50-3',
#  '서울특별시 영등포구 당산6가 10-7',
#  '서울특별시 영등포구 양평동1가 205',
#  '서울특별시 영등포구 대림동 752-60',
#  '서울특별시 영등포구 대림동 703-6',
#  '서울특별시 영등포구 도림동 23-1',
#  '서울특별시 영등포구 대림동 870',
#  '서울특별시 영등포구 영등포동8가 28',
#  '서울특별시 영등포구 대림동 690',
#  '서울특별시 강남구 세곡동 369-3',
#  '서울특별시 강남구 자곡동 233-2',
#  '서울특별시 강남구 자곡동 447-23',
#  '서울특별시 강남구 율현동 308-29',
#  '서울특별시 강남구 율현동 194-1',
#  '서울특별시 강남구 역삼동 666-2',
#  '서울특별시 강남구 세곡동 522-1',
#  '서울특별시 강남구 세곡동 526-2',
#  '서울특별시 강남구 세곡동 548',
#  '서울특별시 강남구 세곡동 546',
#  '서울특별시 서대문구 북아현동 210-24',
#  '서울특별시 서대문구 홍제동 277-82',
#  '서울특별시 서대문구 홍제동 287-121',
#  '서울특별시 서대문구 북가좌동 3-39',
#  '서울특별시 서대문구 연희동 109-2',
#  '서울특별시 서대문구 연희동 123-5',
#  '서울특별시 서대문구 남가좌동 383-2',
#  '서울특별시 서대문구 남가좌동 385-2',
#  '서울특별시 서대문구 북아현동 216-59',
#  '서울특별시 서대문구 북아현동 147-48',
#  '서울특별시 서대문구 북아현동 216-37',
#  '서울특별시 서대문구 남가좌동 224-114',
#  '서울특별시 서대문구 연희동 717-50',
#  '서울특별시 서대문구 영천동 263',
#  '서울특별시 서대문구 연희동 519-7',
#  '서울특별시 서대문구 북가좌동 459-1',
#  '서울특별시 서대문구 홍은동 8-158',
#  '서울특별시 서대문구 남가좌동 379-3',
#  '서울특별시 서대문구 북가좌동 475',
#  '서울특별시 서대문구 북가좌동 338-21',
#  '서울특별시 강남구 논현동 263-23',
#  '서울특별시 강남구 수서동 736-1',
#  '서울특별시 강남구 수서동 746-1',
#  '서울특별시 강남구 일원동 716-1',
#  '서울특별시 관악구 신림동 1704-4',
#  '서울특별시 관악구 봉천동 1707-2',
#  '서울특별시 노원구 상계동 1312-5',
#  '서울특별시 관악구 봉천동 1613-19',
#  '서울특별시 관악구 신림동 1542-1',
#  '서울특별시 관악구 신림동 1555-1',
#  '서울특별시 관악구 봉천동 1510-19',
#  '서울특별시 관악구 봉천동 1510',
#  '서울특별시 관악구 봉천동 148-103',
#  '서울특별시 관악구 신림동 750-39',
#  '서울특별시 관악구 신림동 98-402',
#  '서울특별시 관악구 신림동 1678-12',
#  '서울특별시 관악구 신림동 1716-1',
#  '서울특별시 관악구 신림동 746-32',
#  '서울특별시 관악구 봉천동 196-240',
#  '서울특별시 관악구 봉천동 1526-1',
#  '서울특별시 관악구 신림동 321-5',
#  '서울특별시 관악구 봉천동 1555-16',
#  '서울특별시 관악구 신림동 655-104',
#  '서울특별시 관악구 신림동 254-256',
#  '서울특별시 관악구 신림동 1685',
#  '서울특별시 관악구 신림동 395-35',
#  '서울특별시 강남구 논현동 239',
#  '서울특별시 강남구 신사동 609-2',
#  '서울특별시 강남구 신사동 597',
#  '서울특별시 강남구 논현동 162-11',
#  '서울특별시 강남구 논현동 137-18',
#  '서울특별시 강남구 논현동 47-13',
#  '서울특별시 강남구 논현동 150-5',
#  '서울특별시 강남구 논현동 205-7',
#  '서울특별시 강남구 신사동 558',
#  '서울특별시 강남구 신사동 567-37',
#  '서울특별시 강남구 신사동 625-5',
#  '서울특별시 강동구 성내3동 444-6',
#  '서울특별시 강동구 성내3동 512',
#  '서울특별시 강동구 성내1동 566',
#  '서울특별시 강동구 길동 405-21',
#  '서울특별시 강동구 길동 340-17',
#  '서울특별시 강동구 길동 365-6',
#  '서울특별시 강동구 길동 386-1',
#  '서울특별시 강동구 성내3동 424',
#  '서울특별시 동대문구 휘경동 43-275',
#  '서울특별시 강동구 천호1동 221-3',
#  '서울특별시 강동구 천호3동 167-195',
#  '서울특별시 강동구 강일동 333-1',
#  '서울특별시 강동구 강일동 317-1',
#  '서울특별시 강동구 강일동 448-1',
#  '서울특별시 강동구 강일동 429-1',
#  '서울특별시 강동구 천호2동 569-1',
#  '서울특별시 강동구 암사1동 산59-2',
#  '서울특별시 강동구 강일동 378',
#  '서울특별시 강동구 명일1동 312-30',
#  '서울특별시 강동구 명일1동 312-206',
#  '서울특별시 강동구 천호1동 47-23',
#  '서울특별시 강동구 성내3동 405-18',
#  '서울특별시 강동구 명일2동 236',
#  '서울특별시 강동구 둔촌2동 79-4',
#  '서울특별시 중구 충무로5가 21',
#  '서울특별시 중구 광희동 242',
#  '서울특별시 중구 황학동 755',
#  '서울특별시 중구 정동 34-31',
#  '서울특별시 중구 다산동 432-540',
#  '서울특별시 중구 신당5동 123-1',
#  '서울특별시 중구 저동1가 1-14',
#  '서울특별시 중구 신당동 851-9',
#  '서울특별시 중구 신당동 852-4',
#  '서울특별시 중구 순화동 3-12',
#  '서울특별시 강남구 세곡동 99-6',
#  '서울특별시 동대문구 장안동 93-29',
#  '서울특별시 동대문구 장안동 190-62',
#  '서울특별시 동대문구 용두동 696-8',
#  '서울특별시 동대문구 장안동 164-1',
#  '서울특별시 동대문구 휘경동 43-178',
#  '서울특별시 동대문구 답십리동 998-1',
#  '서울특별시 동대문구 용두동 715',
#  '서울특별시 동대문구 제기동 132-1',
#  '서울특별시 동대문구 장안동 348',
#  '서울특별시 동대문구 전농동 675',
#  '서울특별시 동대문구 답십리동 952-5',
#  '서울특별시 동대문구 장안동 449',
#  '서울특별시 동대문구 장안동 386',
#  '서울특별시 동대문구 장안동 379',
#  '서울특별시 동대문구 이문동 264-181',
#  '서울특별시 동대문구 전농동 688-7',
#  '서울특별시 동대문구 휘경동 49-384',
#  '서울특별시 동대문구 전농동 695-1',
#  '서울특별시 동대문구 답십리동 1009-1',
#  '서울특별시 동대문구 휘경동 372-2',
#  '서울특별시 동대문구 용두동 251-13',
#  '서울특별시 종로구 창신동 산6-25',
#  '서울특별시 종로구 신문로2가 160-1',
#  '서울특별시 종로구 평창동 495-4',
#  '서울특별시 종로구 옥인동 187-2',
#  '서울특별시 종로구 명륜1가 23-9',
#  '서울특별시 종로구 평창동 327-1',
#  '서울특별시 종로구 무악동 55-1',
#  '서울특별시 종로구 연지동 136-92',
#  '서울특별시 종로구 명륜3가 53-2',
#  '서울특별시 동대문구 신설동 109-4',
#  '서울특별시 동대문구 용두동 138-61',
#  '서울특별시 동대문구 장안동 402',
#  '서울특별시 동대문구 장안동 325',
#  '서울특별시 동대문구 장안동 303',
#  '서울특별시 동대문구 장안동 343',
#  '서울특별시 종로구 창신동 23-362',
#  '서울특별시 종로구 무악동 산2-83',
#  '서울특별시 종로구 창신동 611-19',
#  '서울특별시 종로구 평창동 470',
#  '서울특별시 강남구 세곡동 129-13',
#  '서울특별시 강남구 수서동 723-1',
#  '서울특별시 관악구 봉천동 877-21',
#  '서울특별시 관악구 신림동 408-10',
#  '서울특별시 관악구 신림동 675-200',
#  '서울특별시 관악구 신림동 645-1',
#  '서울특별시 관악구 신림동 1510-2',
#  '서울특별시 관악구 신림동 1564-68',
#  '서울특별시 관악구 신림동 1563-56',
#  '서울특별시 관악구 신림동 744-1',
#  '서울특별시 관악구 봉천동 647-175',
#  '서울특별시 관악구 봉천동 850-8',
#  '서울특별시 관악구 봉천동 196-2',
#  '서울특별시 관악구 봉천동 196-193',
#  '서울특별시 관악구 봉천동 1557-34',
#  '서울특별시 관악구 신림동 103-141',
#  '서울특별시 관악구 남현동 602-143',
#  '서울특별시 관악구 남현동 602-196',
#  '서울특별시 관악구 남현동 602-333',
#  '서울특별시 관악구 남현동 1083-1',
#  '서울특별시 관악구 신림동 652-160',
#  '서울특별시 관악구 신림동 483-14',
#  '서울특별시 관악구 신림동 1418-1',
#  '서울특별시 관악구 신림동 539-14',
#  '서울특별시 관악구 봉천동 635-309',
#  '서울특별시 관악구 봉천동 635-37',
#  '서울특별시 강남구 일원동 734-1',
#  '서울특별시 강남구 일원동 730-2',
#  '서울특별시 강남구 일원동 718-1',
#  '서울특별시 강남구 일원동 730-3',
#  '서울특별시 강남구 일원동 732-4',
#  '서울특별시 강남구 일원동 735-1',
#  '서울특별시 금천구 시흥동 925-32',
#  '서울특별시 금천구 독산동 883-9',
#  '서울특별시 금천구 독산동 993-29',
#  '서울특별시 금천구 독산동 160-6',
#  '서울특별시 금천구 독산동 964',
#  '서울특별시 금천구 독산동 980-44',
#  '서울특별시 금천구 독산동 925-2',
#  '서울특별시 금천구 독산동 189-1',
#  '서울특별시 금천구 독산동 196-8',
#  '서울특별시 금천구 시흥동 986-2',
#  '서울특별시 금천구 시흥동 855',
#  '서울특별시 금천구 시흥동 871-24',
#  '서울특별시 금천구 시흥동 893',
#  '서울특별시 금천구 시흥동 789',
#  '서울특별시 금천구 시흥동 791',
#  '서울특별시 금천구 시흥동 943-16',
#  '서울특별시 금천구 시흥동 947-4',
#  '서울특별시 금천구 시흥동 959-2',
#  '서울특별시 금천구 시흥동 970-3',
#  '서울특별시 금천구 시흥동 169-21',
#  '서울특별시 금천구 시흥동 3-17',
#  '서울특별시 금천구 시흥동 3-82',
#  '서울특별시 금천구 시흥동 4-128',
#  '서울특별시 금천구 시흥동 4-28',
#  '서울특별시 금천구 시흥동 791-35',
#  '서울특별시 금천구 시흥동 817',
#  '서울특별시 금천구 시흥동 836',
#  '서울특별시 금천구 가산동 148-11',
#  '서울특별시 금천구 가산동 234-29',
#  '서울특별시 금천구 가산동 28-2',
#  '서울특별시 금천구 독산동 1088-2',
#  '서울특별시 금천구 독산동 1095-1',
#  '서울특별시 금천구 독산동 1112',
#  '서울특별시 금천구 독산동 298-1',
#  '서울특별시 금천구 독산동 999-11',
#  '서울특별시 금천구 독산동 1038-9',
#  '서울특별시 금천구 독산동 1063-14',
#  '서울특별시 금천구 독산동 1067-9',
#  '서울특별시 금천구 독산동 378-291',
#  '서울특별시 금천구 독산동 378-4',
#  '서울특별시 금천구 독산동 378-434',
#  '서울특별시 성동구 성수동2가 280-12',
#  '서울특별시 성동구 성수2가1동 327-3',
#  '서울특별시 성동구 응봉동 270',
#  '서울특별시 성동구 마장동 450-67',
#  '서울특별시 성동구 송정동 90-4',
#  '서울특별시 성동구 하왕십리동 1055',
#  '서울특별시 성동구 응봉동 15-1',
#  '서울특별시 성동구 성수동1가 715-1',
#  '서울특별시 성동구 마장동 827',
#  '서울특별시 성동구 성수동2가 844',
#  '서울특별시 성동구 홍익동 370',
#  '서울특별시 성동구 행당동 376-3',
#  '서울특별시 성동구 금호동2가 1218',
#  '서울특별시 성동구 행당동 347-2',
#  '서울특별시 성동구 하왕십리동 1069',
#  '서울특별시 성동구 행당동 90-2',
#  '서울특별시 성동구 성수동1가 13-21',
#  '서울특별시 성동구 마장동 780-1',
#  '서울특별시 성동구 응봉동 228-23',
#  '서울특별시 성동구 사근동 291-10',
#  '서울특별시 성동구 마장동 399-102',
#  '서울특별시 성동구 성수동2가 273-11',
#  '서울특별시 성동구 성수동2가 316-9',
#  '서울특별시 노원구 상계동 1275-4',
#  '서울특별시 은평구 응암동751-22',
#  '서울특별시 은평구 불광 339',
#  '서울특별시 은평구 녹번동 281-4',
#  '서울특별시 은평구 응암동 240-7',
#  '서울특별시 은평구 응암동 767-1',
#  '서울특별시 은평구 응암동764-2',
#  '서울특별시 은평구 역촌 47-1',
#  '서울특별시 은평구 역촌 8-11',
#  '서울특별시 은평구 대조 212',
#  '서울특별시 은평구 갈현 474-1',
#  '서울특별시 은평구 갈현 327-21',
#  '서울특별시 은평구 갈현 416-3',
#  '서울특별시 은평구 갈현 513-1',
#  '서울특별시 은평구 갈현 436-51',
#  '서울특별시 은평구 신사 5-21',
#  '서울특별시 은평구 녹번 95-44',
#  '서울특별시 은평구 증산 163-34',
#  '서울특별시 은평구 갈현 434-38',
#  '서울특별시 은평구 불광 444-1',
#  '서울특별시 은평구 불광 444-15',
#  '서울특별시 은평구 불광 270-11',
#  '서울특별시 은평구 불광 448-51',
#  '서울특별시 은평구 신사 31-2',
#  '서울특별시 은평구 신사 200-27',
#  '서울특별시 은평구 신사 237-177',
#  '서울특별시 은평구 응암 742-9',
#  '서울특별시 은평구 불광 236-5',
#  '서울특별시 은평구 응암동 761-9',
#  '서울특별시 성북구 보문동6가 458-3',
#  '서울특별시 은평구 녹번 158-1',
#  '서울특별시 은평구 응암 85-41',
#  '서울특별시 은평구 녹번 20-6',
#  '서울특별시 은평구 응암 120-22',
#  '서울특별시 은평구 응암 115-25',
#  '서울특별시 은평구 증산 185-1',
#  '서울특별시 은평구 역촌 32-36',
#  '서울특별시 은평구 역촌 39-2',
#  '서울특별시 성북구 하월곡동 96-165',
#  '서울특별시 성북구 하월곡동 산2-140',
#  '서울특별시 성북구 상월곡동 97-37',
#  '서울특별시 성북구 상월곡동 산1-1',
#  '서울특별시 성북구 장위1동 219-223',
#  '서울특별시 성북구 석관동 168-86',
#  '서울특별시 성북구 석관동 산1-77',
#  '서울특별시 성북구 돈암1동 626-2',
#  '서울특별시 성북구 종암동 104-6',
#  '서울특별시 성북구 길음1동 1190',
#  '서울특별시 성북구 길음1동 591-17',
#  '서울특별시 성북구 정릉2동 169-6',
#  '서울특별시 성북구 정릉1동 170-10',
#  '서울특별시 성북구 보문동3가 229-1',
#  '서울특별시 성북구 장위동 317-1',
#  '서울특별시 성북구 석관동 407-6',
#  '서울특별시 성북구 종암동 133-5',
#  '서울특별시 성북구 종암동 135-4',
#  '서울특별시 성북구 길음1동 1284-14',
#  '서울특별시 성북구 길음1동 1284-1',
#  '서울특별시 성북구 종암동 134-3',
#  '서울특별시 성북구 종암동 134-8',
#  '서울특별시 성북구 삼선동1가 303',
#  '서울특별시 성북구 안암동2가 140-3',
#  '서울특별시 성북구 보문동7가 108-2',
#  '서울특별시 송파구 마천동 364-5 일대',
#  '서울특별시 송파구 가락동 479',
#  '서울특별시 송파구 문정동 142 일대',
#  '서울특별시 송파구 신천동 20-4 일원',
#  '서울특별시 송파구 신천동 7 일원',
#  '서울특별시 송파구 신천동 11 일원',
#  '서울특별시 송파구 오금동 123-2',
#  '서울특별시 송파구 풍납동 306-9',
#  '서울특별시 송파구 석촌동 289-3',
#  '서울특별시 송파구 오금동 66-12',
#  '서울특별시 송파구 가락동 152-3',
#  '서울특별시 송파구 송파동 129',
#  '서울특별시 송파구 거여동 16',
#  '서울특별시 송파구 방이동 121',
#  '서울특별시 송파구 오금동 84',
#  '서울특별시 송파구 석촌동 162',
#  '서울특별시 송파구 마천동 45',
#  '서울특별시 송파구 풍납동 295-4',
#  '서울특별시 송파구 방이동 189',
#  '서울특별시 송파구 거여동 135-46',
#  '서울특별시 송파구 송파동 188',
#  '서울특별시 송파구 잠실본동 338',
#  '서울특별시 송파구 마천동 610',
#  '서울특별시 송파구 마천동 360',
#  '서울특별시 송파구 거여동 7',
#  '서울특별시 송파구 가락동 185',
#  '서울특별시 송파구 가락본동 118',
#  '서울특별시 송파구 문정동 66',
#  '서울특별시 송파구 거여동 293-2',
#  '서울특별시 송파구 가락본동 14',
#  '서울특별시 송파구 문정동 47',
#  '서울특별시 송파구 방이동 150',
#  '서울특별시 송파구 가락동 134',
#  '서울특별시 송파구 장지동 838-1',
#  '서울특별시 송파구 방이동 70-1',
#  '서울특별시 송파구 가락본동 28',
#  '서울특별시 송파구 거여동 291-1',
#  '서울특별시 송파구 송파동 178',
#  '서울특별시 송파구 장지동 854-2',
#  '서울특별시 송파구 오금동 132',
#  '서울특별시 송파구 오금동 27',
#  '서울특별시 송파구 가락본동 85',
#  '서울특별시 송파구 잠실본동 296',
#  '서울특별시 송파구 방이동 195',
#  '서울특별시 송파구 가락본동 96-15',
#  '서울특별시 송파구 잠실본동 220',
#  '서울특별시 송파구 삼전동 70',
#  '서울특별시 송파구 삼전동 95',
#  '서울특별시 송파구 삼전동 51',
#  '서울특별시 송파구 삼전동 110-7',
#  '서울특별시 송파구 잠실본동 209-4',
#  '서울특별시 송파구 가락동 145-10',
#  '서울특별시 송파구 송파동 107',
#  '서울특별시 송파구 가락본동 51',
#  '서울특별시 송파구 가락동 170-6',
#  '서울특별시 송파구 석촌동 27',
#  '서울특별시 송파구 마천동 128-2',
#  '서울특별시 송파구 장지동 843-1',
#  '서울특별시 송파구 방이동 214',
#  '서울특별시 송파구 문정동 23-5',
#  '서울특별시 송파구 오금동 21',
#  '서울특별시 송파구 문정동 81',
#  '서울특별시 송파구 거여동 29',
#  '서울특별시 송파구 송파동 243-1',
#  '서울특별시 송파구 거여동 593-1',
#  '서울특별시 송파구 방이동 139',
#  '서울특별시 송파구 문정동 150-6',
#  '서울특별시 송파구 오금동 117-1',
#  '서울특별시 송파구 삼전동 37',
#  '서울특별시 송파구 마천동 344',
#  '서울특별시 송파구 장지동 123-1',
#  '서울특별시 송파구 가락동 198',
#  '서울특별시 송파구 가락동 165-4',
#  '서울특별시 송파구 마천동 583',
#  '서울특별시 송파구 석촌동 258',
#  '서울특별시 송파구 마천동 375',
#  '서울특별시 송파구 송파동 34',
#  '서울특별시 송파구 거여동 28-7',
#  '서울특별시 강남구 압구정동 466',
#  '서울특별시 강남구 압구정동 459',
#  '서울특별시 강남구 삼성동 55-1',
#  '서울특별시 강남구 삼성동 85',
#  '서울특별시 강남구 청담동 94-4',
#  '서울특별시 강남구 청담동 51',
#  '서울특별시 강남구 도곡동 455',
#  '서울특별시 강남구 도곡동 415-3',
#  '서울특별시 강남구 역삼동 780-25',
#  '서울특별시 강남구 역삼동 824-10',
#  '서울특별시 강남구 역삼동 830-23',
#  '서울특별시 강남구 역삼동 739-15',
#  '서울특별시 강남구 역삼동 836-21',
#  '서울특별시 강남구 역삼동 611',
#  '서울특별시 강남구 대치동 929-10',
#  '서울특별시 강남구 대치동 1014-4',
#  '서울특별시 강남구 대치동 899-25',
#  '서울특별시 강남구 개포동 169-3',
#  '서울특별시 강남구 개포동 190',
#  '서울특별시 강남구 개포동 190',
#  '서울특별시 강남구 개포동 1220',
#  '서울특별시 강남구 개포동 1176',
#  '서울특별시 강남구 일원동 615-2',
#  '서울특별시 강남구 일원동 658',
#  '서울특별시 강남구 일원동 712-4',
#  '서울특별시 강남구 수서동 465-15',
#  '서울특별시 강남구 개포동 12-7',
#  '서울특별시 강남구 개포동 12-3',
#  '서울특별시 노원구 상계동 652-3',
#  '서울특별시 노원구 상계동 646',
#  '서울특별시 노원구 상계동 636',
#  '서울특별시 노원구 상계동 663',
#  '서울특별시 노원구 상계동 665',
#  '서울특별시 노원구 상계동 667',
#  '서울특별시 노원구 노원로 532',
#  '서울특별시 노원구 상계동 695-1',
#  '서울특별시 노원구 동일로 1456',
#  '서울특별시 노원구 상계동 692-3',
#  '서울특별시 노원구 상계동 737-1',
#  '서울특별시 노원구 상계동 737-3',
#  '서울특별시 노원구 상계동 720-4',
#  '서울특별시 노원구 상계동 720-1',
#  '서울특별시 노원구 상계동 741-1',
#  '서울특별시 노원구 상계동 742-2',
#  '서울특별시 노원구 동일로214길 2',
#  '서울특별시 노원구 상계동 756',
#  '서울특별시 노원구 상계동 767-2',
#  '서울특별시 노원구 상계동 765-1',
#  '서울특별시 노원구 중계동 501',
#  '서울특별시 노원구 중계동 514-4',
#  '서울특별시 노원구 하계동 277',
#  '서울특별시 노원구 하계동 273-3',
#  '서울특별시 노원구 하계동 272-1',
#  '서울특별시 노원구 하계동 271-1',
#  '서울특별시 노원구 광운로 20',
#  '서울특별시 노원구 광운로1길 24',
#  '서울특별시 노원구 월계동 411-47',
#  '서울특별시 노원구 월계동 411-50',
#  '서울특별시 노원구 월계동 429-44',
#  '서울특별시 노원구 동일로179길 22',
#  '서울특별시 노원구 공릉동 503-17',
#  '서울특별시 노원구 공릉동 270-4',
#  '서울특별시 노원구 공릉동 380-4',
#  '서울특별시 노원구 공릉동 371-1',
#  '서울특별시 노원구 공릉동 589-4',
#  '서울특별시 노원구 공릉동 690-1',
#  '서울특별시 노원구 공릉로58나길 14',
#  '서울특별시 노원구 하계동 167-12',
#  '서울특별시 노원구 중계동 154-9',
#  '서울특별시 노원구 중계동 154-7',
#  '서울특별시 노원구 상계동 135-77',
#  '서울특별시 노원구 상계동 1116-50',
#  '서울특별시 노원구 상계동 622',
#  '서울특별시 노원구 상계동 625',
#  '서울특별시 노원구 상계동 623',
#  '서울특별시 노원구 동일로228길 23',
#  '서울특별시 노원구 상계동 628',
#  '서울특별시 노원구 상계동 656-1',
#  '서울특별시 성동구 하왕십리동 1068',
#  '서울특별시 성동구 금호동4가 235-3',
#  '서울특별시 성동구 상왕십리동 816-3',
#  '서울특별시 성동구 하왕십리동 1070-5',
#  '서울특별시 노원구 공릉동 123-1',
#  '서울특별시 구로구 신도림동 314-2',
#  '서울특별시 구로구 신도림동 646-1',
#  '서울특별시 구로구 구로동 745-74',
#  '서울특별시 구로구 구로동 777-1',
#  '서울특별시 구로구 구로동 139-82',
#  '서울특별시 구로구 구로동 391-1',
#  '서울특별시 강동구 상일동 278',
#  '서울특별시 강동구 상일동 177',
#  '서울특별시 강동구 상일동 175',
#  '서울특별시 강동구 명일2동 258',
#  '서울특별시 강동구 명일2동 55',
#  '서울특별시 강동구 명일2동 43',
#  '서울특별시 용산구 후암동 190-1',
#  '서울특별시 용산구 원효로3가 1-139',
#  '서울특별시 용산구 서계동 226-3',
#  '서울특별시 용산구 동자동 24-11',
#  '서울특별시 용산구 이태원2동 286-1',
#  '서울특별시 용산구 동자동 8',
#  '서울특별시 서대문구 연희동 86-3',
#  '서울특별시 강서구 내발산동 384-2',
#  '서울특별시 도봉구 창동 38-4',
#  '서울특별시 도봉구 창동 307',
#  '서울특별시 도봉구 창동 347-3',
#  '서울특별시 도봉구 창동 354',
#  '서울특별시 도봉구 창동 367',
#  '서울특별시 도봉구 창동 368',
#  '서울특별시 도봉구 창동 381',
#  '서울특별시 도봉구 창동 449-103',
#  '서울특별시 도봉구 창동 458-6',
#  '서울특별시 도봉구 창동 553-8',
#  '서울특별시 도봉구 창동 608-5',
#  '서울특별시 도봉구 창동 624-16',
#  '서울특별시 도봉구 창동 630-4',
#  '서울특별시 도봉구 창동 663-1',
#  '서울특별시 도봉구 창동 715-17',
#  '서울특별시 도봉구 도봉동 653',
#  '서울특별시 도봉구 도봉동 289-5',
#  '서울특별시 도봉구 도봉동 570-13',
#  '서울특별시 도봉구 도봉동 576-13',
#  '서울특별시 도봉구 도봉동 585-2',
#  '서울특별시 도봉구 도봉동 614-37',
#  '서울특별시 도봉구 도봉동 625-123',
#  '서울특별시 도봉구 방학동 304-20',
#  '서울특별시 도봉구 방학동 611-5',
#  '서울특별시 도봉구 방학동 638-12',
#  '서울특별시 도봉구 방학동 644-28',
#  '서울특별시 도봉구 방학동 655-31',
#  '서울특별시 도봉구 방학동 663',
#  '서울특별시 도봉구 방학동 681-13',
#  '서울특별시 도봉구 방학동 694-9',
#  '서울특별시 도봉구 방학동 735-4',
#  '서울특별시 도봉구 방학1동 717-1',
#  '서울특별시 도봉구 쌍문동 709-32',
#  '서울특별시 도봉구 쌍문동 139-101',
#  '서울특별시 도봉구 쌍문동 286-32',
#  '서울특별시 도봉구 쌍문동 315-362',
#  '서울특별시 도봉구 창동 27-2',
#  '서울특별시 도봉구 창동 30-1',
#  '서울특별시 도봉구 창동 33-4',
#  '서울특별시 서대문구 연희동 73-8',
#  '서울특별시 양천구 신정3동 1260',
#  '서울특별시 양천구 신정3동 1283-1',
#  '서울특별시 양천구 신정3동 1284-1',
#  '서울특별시 양천구 신정3동 1293-4',
#  '서울특별시 양천구 신정3동 767',
#  '서울특별시 양천구 신정3동 1316-2',
#  '서울특별시 양천구 신정3동 1322-10',
#  '서울특별시 양천구 신정4동 975-30',
#  '서울특별시 양천구 신정4동 955-1',
#  '서울특별시 양천구 신정4동 949-4',
#  '서울특별시 양천구 신정4동 990-1',
#  '서울특별시 양천구 신월2동 459',
#  '서울특별시 양천구 신월2동 486',
#  '서울특별시 양천구 신월2동 471',
#  '서울특별시 양천구 신월3동 196',
#  '서울특별시 양천구 신월3동 156',
#  '서울특별시 양천구 목4동 772-1',
#  '서울특별시 양천구 신월4동 515',
#  '서울특별시 양천구 신월4동 531',
#  '서울특별시 양천구 신월4동 422-1',
#  '서울특별시 양천구 신월4동 426-4',
#  '서울특별시 양천구 신월4동 542',
#  '서울특별시 양천구 신월5동 73-2',
#  '서울특별시 양천구 신월5동 13-1',
#  '서울특별시 양천구 신월5동 56-1',
#  '서울특별시 양천구 신월5동 65',
#  '서울특별시 양천구 신월6동 1012-2',
#  '서울특별시 양천구 신월6동 1004',
#  '서울특별시 양천구 신월7동 922-1',
#  '서울특별시 양천구 신월7동 985',
#  '서울특별시 양천구 신정1동 1017-5',
#  '서울특별시 양천구 신정1동 1050-3',
#  '서울특별시 양천구 신정1동 313-2',
#  '서울특별시 양천구 신정1동 312-2',
#  '서울특별시 양천구 신정1동 311-1',
#  '서울특별시 양천구 신정1동 1033-18',
#  '서울특별시 양천구 신정2동 119-3',
#  '서울특별시 양천구 신정2동 128-198',
#  '서울특별시 양천구 신정3동 1195',
#  '서울특별시 양천구 목5동 912-1',
#  '서울특별시 양천구 목5동 901-2',
#  '서울특별시 양천구 목5동 902-2',
#  '서울특별시 양천구 목5동 911-5',
#  '서울특별시 양천구 신월1동 240',
#  '서울특별시 양천구 신월1동 234-11외 4',
#  '서울특별시 양천구 신월1동 230-1',
#  '서울특별시 양천구 신월1동 119',
#  '서울특별시 양천구 신월1동 100-1',
#  '서울특별시 양천구 목4동 791-22',
#  '서울특별시 양천구 목4동 767-1',
#  '서울특별시 양천구 목4동 724-1',
#  '서울특별시 양천구 목5동 903-2',
#  '서울특별시 양천구 목5동 904-1',
#  '서울특별시 양천구 목5동 913-1',
#  '서울특별시 서대문구 연희동 446-182',
#  '서울특별시 서대문구 북가좌동 318-1',
#  '서울특별시 서대문구 북가좌동 325-20',
#  '서울특별시 서대문구 연희동 151-49',
#  '서울특별시 서대문구 홍제동 156-363',
#  '서울특별시 서대문구 홍제동 322-72',
#  '서울특별시 서대문구 홍은동 405-3',
#  '서울특별시 서대문구 홍은동 408-4',
#  '서울특별시 서대문구 홍은동 421-1',
#  '서울특별시 서대문구 남가좌동 368',
#  '서울특별시 서대문구 남가좌동 326-8',
#  '서울특별시 서대문구 홍은동 455-4',
#  '서울특별시 서대문구 창천동 4-54',
#  '서울특별시 서대문구 남가좌동 376-4',
#  '서울특별시 서대문구 남가좌동 377-3',
#  '서울특별시 강북구 송중동 128-8',
#  '서울특별시 강서구 공항동 484',
#  '서울특별시 강서구 공항동 4',
#  '서울특별시 강서구 공항동 705',
#  '서울특별시 강서구 마곡동 316-1',
#  '서울특별시 강서구 마곡동 397-1',
#  '서울특별시 강서구 외발산동 69-1',
#  '서울특별시 노원구 우이천로 102',
#  '서울특별시 노원구 상계동 1293-2',
#  '서울특별시 노원구 상계동 1096-16',
#  '서울특별시 노원구 공릉동 89',
#  '서울특별시 노원구 공릉동 110-2',
#  '서울특별시 노원구 공릉동 106-3',
#  '서울특별시 노원구 중계동 358-1',
#  '서울특별시 노원구 중계동 359-2',
#  '서울특별시 노원구 중계동으로 184',
#  '서울특별시 노원구 중계동 360-3',
#  '서울특별시 노원구 중계동 364-11',
#  '서울특별시 노원구 노원로22길 34',
#  '서울특별시 노원구 하계동 256-3',
#  '서울특별시 노원구 하계동 251-13',
#  '서울특별시 노원구 중계동 363-8',
#  '서울특별시 노원구 하계동1동256-6',
#  '서울특별시 노원구 중계동 369-6',
#  '서울특별시 노원구 하계동 252-11',
#  '서울특별시 노원구 월계동로55길 49',
#  '서울특별시 노원구 월계동으로 372',
#  '서울특별시 노원구 월계동 322-4',
#  '서울특별시 노원구 공릉동 708-1',
#  '서울특별시 노원구 월계2동동 555',
#  '서울특별시 노원구 월계동 563',
#  '서울특별시 노원구 월계동 564',
#  '서울특별시 노원구 화랑로 556',
#  '서울특별시 노원구 월계동 775-1',
#  '서울특별시 노원구 월계동 781-1',
#  '서울특별시 노원구 상계동 1257-1',
#  '서울특별시 노원구 상계동 1255-1',
#  '서울특별시 노원구 상계동 1265-1',
#  '서울특별시 노원구 동일로250길 1',
#  '서울특별시 강북구 수유3동 224-4',
#  '서울특별시 강북구 인수동 605-209',
#  '서울특별시 강북구 수유1동 605-389',
#  '서울특별시 강북구 수유3동 134-40',
#  '서울특별시 강북구 인수동 516-44',
#  '서울특별시 강북구 수유동 281-2',
#  '서울특별시 강북구 수유1동 475-115',
#  '서울특별시 강북구 수유2동 276-10',
#  '서울특별시 강북구 수유3동 25-1',
#  '서울특별시 강북구 인수동 605-209',
#  '서울특별시 강북구 송중동 1369-1',
#  '서울특별시 강서구 내발산동 650',
#  '서울특별시 강서구 내발산동 657-2',
#  '서울특별시 강서구 내발산동 657-3',
#  '서울특별시 강서구 공항동1341',
#  '서울특별시 강서구 공항동1361',
#  '서울특별시 강서구 공항동668',
#  '서울특별시 강서구 공항동42-11',
#  '서울특별시 강서구 방화동 266-24',
#  '서울특별시 강서구 방화동 569-14',
#  '서울특별시 강서구 방화동 247-201',
#  '서울특별시 강서구 방화동 608-112',
#  '서울특별시 강서구 방화동 448-5',
#  '서울특별시 강서구 방화동 184-66',
#  '서울특별시 강서구 방화동 890-1',
#  '서울특별시 강서구 방화동 645-13',
#  '서울특별시 강서구 방화동 648-13',
#  '서울특별시 강서구 방화동 551-26',
#  '서울특별시 강서구 방화동 411',
#  '서울특별시 강서구 방화동 616-1',
#  '서울특별시 강서구 방화동 558',
#  '서울특별시 강서구 방화동 583',
#  '서울특별시 강서구 방화동 853',
#  '서울특별시 강서구 방화동 815',
#  '서울특별시 강서구 방화동 826',
#  '서울특별시 강서구 방화동 799',
#  '서울특별시 강서구 방화동 837',
#  '서울특별시 강서구 방화동 840',
#  '서울특별시 강서구 방화동 818',
#  '서울특별시 강서구 공항동 4-36',
#  '서울특별시 광진구 자양동 199-4',
#  '서울특별시 광진구 자양동 689-6',
#  '서울특별시 광진구 자양동 792-1',
#  '서울특별시 광진구 화양동 32-1',
#  '서울특별시 광진구 화양동 12-55',
#  '서울특별시 광진구 화양동 45-3',
#  '서울특별시 광진구 화양동 8-36',
#  '서울특별시 광진구 군자동 159-1',
#  '서울특별시 광진구 군자동 115-1',
#  '서울특별시 광진구 중곡동 232-44',
#  '서울특별시 광진구 중곡동 695',
#  '서울특별시 광진구 중곡동 100-16',
#  '서울특별시 광진구 중곡동 51-6',
#  '서울특별시 광진구 중곡동 68-19',
#  '서울특별시 광진구 구의동 216-5',
#  '서울특별시 광진구 구의동 223-4',
#  '서울특별시 광진구 구의동 206-10',
#  '서울특별시 구로구 궁동 237-6',
#  '서울특별시 구로구 궁동 279-6',
#  '서울특별시 구로구 천왕동 277-14',
#  '서울특별시 구로구 천왕동 2-5',
#  '서울특별시 구로구 구로동 47',
#  '서울특별시 구로구 구로동 797-1',
#  '서울특별시 구로구 구로동 501-22',
#  '서울특별시 구로구 고척동 331-1',
#  '서울특별시 구로구 고척동 224-3',
#  '서울특별시 구로구 고척동 220-3',
#  '서울특별시 구로구 고척동 57-22',
#  '서울특별시 구로구 개봉동 340-8',
#  '서울특별시 구로구 개봉동 271-17',
#  '서울특별시 구로구 개봉동 312-25',
#  '서울특별시 구로구 개봉동 458-4',
#  '서울특별시 구로구 오류동 353-4',
#  '서울특별시 구로구 온수동 73-5',
#  '서울특별시 노원구 공릉2동 230-9',
#  '서울특별시 노원구 상계동 71-4',
#  '서울특별시 노원구 덕릉로 126가길',
#  '서울특별시 노원구 상계동 111-201',
#  '서울특별시 노원구 월계2동 277-22',
#  '서울특별시 용산구 청파동3가 118-102',
#  '서울특별시 용산구 이태원2동 463',
#  '서울특별시 용산구 이촌2동 206-1',
#  '서울특별시 용산구 용산동3가 1-96',
#  '서울특별시 용산구 동자동 50',
#  '서울특별시 용산구 효창동 5-712',
#  '서울특별시 용산구 도원동 21',
#  '서울특별시 용산구 한강로1가 30-3',
#  '서울특별시 용산구 문배동 24-1',
#  '서울특별시 용산구 서계동 276-7',
#  '서울특별시 강서구 가양동 1486-1',
#  '서울특별시 강서구 내발산동 697',
#  '서울특별시 강서구 내발산동 221-1',
#  '서울특별시 강서구 내발산동 741-2',
#  '서울특별시 강서구 내발산동 753-1',
#  '서울특별시 강서구 내발산동 761',
#  '서울특별시 강서구 화곡동1159-3',
#  '서울특별시 강서구 화곡동1061-36',
#  '서울특별시 강서구 화곡동75-3',
#  '서울특별시 강서구 화곡동1165-2',
#  '서울특별시 강서구 화곡동1165-6',
#  '서울특별시 강서구 화곡동978-18',
#  '서울특별시 강서구 화곡동994-5',
#  '서울특별시 강서구 화곡동1109',
#  '서울특별시 강서구 화곡동980-2',
#  '서울특별시 강서구 화곡동379-32',
#  '서울특별시 강서구 화곡동372-26',
#  '서울특별시 강서구 화곡동1088-16',
#  '서울특별시 강서구 화곡동369-11',
#  '서울특별시 강서구 화곡동354-14',
#  '서울특별시 강서구 화곡동341-24',
#  '서울특별시 강서구 화곡동155-1',
#  '서울특별시 강서구 화곡동409-84',
#  '서울특별시 강서구 화곡동892-17',
#  '서울특별시 강서구 화곡동339-19',
#  '서울특별시 강서구 가양동 1459-1',
#  '서울특별시 강서구 가양동 1465',
#  '서울특별시 강서구 가양동 1461-1',
#  '서울특별시 강서구 가양동 1462-2',
#  '서울특별시 강서구 가양동 1474-1',
#  '서울특별시 강서구 가양동 1478-1',
#  '서울특별시 강서구 가양동 1481-1',
#  '서울특별시 강서구 가양동 1482-1',
#  '서울특별시 강서구 가양동 1489-1',
#  '서울특별시 강서구 화곡동 56-3',
#  '서울특별시 강서구 화곡동 922-10',
#  '서울특별시 강서구 화곡동 424-45',
#  '서울특별시 강서구 화곡동 355-12',
#  '서울특별시 강서구 화곡동 346-26',
#  '서울특별시 강서구 화곡동 906-26',
#  '서울특별시 강서구 화곡동 900-46',
#  '서울특별시 강서구 화곡동 865-1',
#  '서울특별시 강서구 화곡동 845-19',
#  '서울특별시 강서구 화곡동 883-3',
#  '서울특별시 강서구 화곡동 1016-34',
#  '서울특별시 강서구 화곡동 1008-32',
#  '서울특별시 강서구 화곡동 1044-31',
#  '서울특별시 강서구 화곡동 1022',
#  '서울특별시 강서구 화곡동 1139-1',
#  '서울특별시 강서구 화곡동 792-9',
#  '서울특별시 강서구 화곡동783-1',
#  '서울특별시 강서구 화곡동806-10',
#  '서울특별시 강서구 화곡동468-1',
#  '서울특별시 강서구 화곡동819-5',
#  '서울특별시 강서구 화곡동1159-2',
#  '서울특별시 강서구 염창동 281-3',
#  '서울특별시 강서구 염창동 267-24',
#  '서울특별시 강서구 염창동 299-3',
#  '서울특별시 강서구 등촌동 639-2',
#  '서울특별시 강서구 등촌동 646-41',
#  '서울특별시 강서구 등촌동 641-5',
#  '서울특별시 강서구 등촌동 635-1',
#  '서울특별시 강서구 등촌동 517-1',
#  '서울특별시 강서구 등촌동 690-3',
#  '서울특별시 강서구 등촌동 707-2',
#  '서울특별시 강서구 등촌동 695-4',
#  '서울특별시 강서구 등촌동 694-1',
#  '서울특별시 강서구 등촌동 705-3',
#  '서울특별시 강서구 등촌동 688-3',
#  '서울특별시 강서구 등촌동 702-1',
#  '서울특별시 강서구 화곡동 98-22',
#  '서울특별시 강서구 화곡동 98-99',
#  '서울특별시 강서구 화곡동 105-194',
#  '서울특별시 강서구 화곡동 102-206',
#  '서울특별시 강서구 화곡동 61-96',
#  '서울특별시 강서구 화곡동 46-41',
#  '서울특별시 강서구 화곡동 24-128',
#  '서울특별시 강서구 화곡동 29-31',
#  '서울특별시 강서구 화곡동 772',
#  '서울특별시 강서구 화곡동 56-25',
#  '서울특별시 강서구 화곡동 56-638',
#  '서울특별시 중랑구 묵1 20-1',
#  '서울특별시 구로구 구로동 478-1',
#  '서울특별시 중랑구 중화1 280-16',
#  '서울특별시 중랑구 중화2 323-14',
#  '서울특별시 중랑구 중화2 332-48',
#  '서울특별시 중랑구 중화2 328-14',
#  '서울특별시 중랑구 중화1 131-20',
#  '서울특별시 중랑구 묵2 240-100',
#  '서울특별시 중랑구 묵1 177-5',
#  '서울특별시 중랑구 망우본 492-6',
#  ...]

# %%
addr_list_childpark = []
for addr in childpark_addr: 
    addr_list_childpark.append(addr.split()[1])
addr_list_childpark
# Out:
# ['마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '동작구',
#  '동작구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '동작구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '양천구',
#  '양천구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '강남구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동대문구',
#  '강남구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '관악구',
#  '관악구',
#  '노원구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '동대문구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '강남구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '강남구',
#  '강남구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '성북구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '노원구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '서대문구',
#  '강서구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '서대문구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '강북구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '중랑구',
#  '구로구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  ...]

# %%
childpark['행정구별'] = addr_list_childpark
childpark = childpark[['공원명','공원구분','행정구별','위도','경도','공원면적','공원보유시설(유희시설)']]
childpark
# Out:
#               공원명   공원구분 행정구별         위도          경도    공원면적 공원보유시설(유희시설)
# 214       목련어린이공원  어린이공원  마포구  37.587380  126.880225  1501.0      [시설미보유]
# 215      산수유어린이공원  어린이공원  마포구  37.585485  126.879008  2011.0      [시설미보유]
# 216     산딸나무어린이공원  어린이공원  마포구  37.583547  126.877927  1499.0      [시설미보유]
# 217    애오개도담어린이공원  어린이공원  마포구  37.553433  126.958529  3212.0      [시설미보유]
# 218      쌍룡산어린이공원  어린이공원  마포구  37.552173  126.950512  5911.0      [시설미보유]
# ...           ...    ...  ...        ...         ...     ...          ...
# 15266        한  신  어린이공원  중랑구  37.588130  127.076900   995.0      [시설미보유]
# 15267        이  화  어린이공원  중랑구  37.586990  127.100300   215.0      [시설미보유]
# 15268     면목1(가칭)  어린이공원  중랑구  37.580278  127.093056  1578.6      [시설미보유]
# 15269        봉  황  어린이공원  중랑구  37.595020  127.084800  1014.0      [시설미보유]
# 15270        상  봉  어린이공원  중랑구  37.593090  127.082500  1058.0      [시설미보유]
#
# [1035 rows x 7 columns]

# %%
marker_cluster_seoul_map = MarkerCluster().add_to(seoul_map)

# %%
for lat, lng in zip(childpark['위도'],childpark['경도']):

    Marker(location =[lat,lng],
          icon = folium.Icon(color="green")).add_to(marker_cluster_seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_359886c9e9495bd621098eca0ddf2276 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 650.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_359886c9e9495bd621098eca0ddf2276&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_359886c9e9495bd621098eca0ddf2276 = L.map(
#                 &quot;map_359886c9e9495bd621098eca0ddf2276&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cbd1d2cae2933a9b492b1c9585e30ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_359886c9e9495bd621098eca0ddf2276);
#
#
#
#         function geo_json_912f414403c6c33a6d83c48a3391823e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_912f414403c6c33a6d83c48a3391823e = L.geoJson(null, {
#                 onEachFeature: geo_json_912f414403c6c33a6d83c48a3391823e_onEachFeature,
#
#         });
#
#         function geo_json_912f414403c6c33a6d83c48a3391823e_add (data) {
#             geo_json_912f414403c6c33a6d83c48a3391823e
#                 .addData(data)
#                 .addTo(map_359886c9e9495bd621098eca0ddf2276);
#         }
#             geo_json_912f414403c6c33a6d83c48a3391823e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069

# %%
childpark['count']=1

# %%
#df_seoul=childpark[(childpark['소재지지번주소'].str.contains('서울특별시')) | (childpark['소재지도로명주소'].str.contains('서울특별시'))]


HeatMap(childpark[['위도','경도','count']]).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_359886c9e9495bd621098eca0ddf2276 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 650.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_359886c9e9495bd621098eca0ddf2276&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_359886c9e9495bd621098eca0ddf2276 = L.map(
#                 &quot;map_359886c9e9495bd621098eca0ddf2276&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cbd1d2cae2933a9b492b1c9585e30ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_359886c9e9495bd621098eca0ddf2276);
#
#
#
#         function geo_json_912f414403c6c33a6d83c48a3391823e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_912f414403c6c33a6d83c48a3391823e = L.geoJson(null, {
#                 onEachFeature: geo_json_912f414403c6c33a6d83c48a3391823e_onEachFeature,
#
#         });
#
#         function geo_json_912f414403c6c33a6d83c48a3391823e_add (data) {
#             geo_json_912f414403c6c33a6d83c48a3391823e
#                 .addData(data)
#                 .addTo(map_359886c9e9495bd621098eca0ddf2276);
#         }
#             geo_json_912f414403c6c33a6d83c48a3391823e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [12

# %% [markdown]
# ## Step3. 어린이보호구역 근처에는 어린이 구역이 있을것이다

# %%
children_json = open_json('전국어린이보호구역표준데이터.json',encoding = 'utf-8')
children_json
# Out:
# {'fields': [{'id': '시설종류'},
#   {'id': '대상시설명'},
#   {'id': '소재지도로명주소'},
#   {'id': '소재지지번주소'},
#   {'id': '위도'},
#   {'id': '경도'},
#   {'id': '관리기관명'},
#   {'id': '관할경찰서명'},
#   {'id': 'CCTV설치여부'},
#   {'id': 'CCTV설치대수'},
#   {'id': '보호구역도로폭'},
#   {'id': '데이터기준일자'},
#   {'id': '제공기관코드'},
#   {'id': '제공기관명'}],
#  'records': [{'시설종류': '초등학교',
#    '대상시설명': '동해중앙초등교',
#    '소재지도로명주소': '강원도 동해시 천곡로 35 (천곡동)',
#    '소재지지번주소': '강원도 동해시 천곡동 793',
#    '위도': '37.52533371',
#    '경도': '129.1084972',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '6',
#    '보호구역도로폭': '11~30',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '천곡초등학교',
#    '소재지도로명주소': '강원도 동해시 동굴로 33 (천곡동)',
#    '소재지지번주소': '강원도 동해시 천곡동 320',
#    '위도': '37.5177521',
#    '경도': '129.1078672',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '20',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '망상초등학교',
#    '소재지도로명주소': '강원도 동해시 동해대로 6251 (망상동)',
#    '소재지지번주소': '강원도 동해시 망상동 360-2',
#    '위도': '37.59086742',
#    '경도': '129.0902466',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '21',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '동호초등학교',
#    '소재지도로명주소': '강원도 동해시 발한로 123 (발한동)',
#    '소재지지번주소': '강원도 동해시 발한동 570-1',
#    '위도': '37.54417872',
#    '경도': '129.1001844',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '6',
#    '보호구역도로폭': '20~28',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '동해초등학교',
#    '소재지도로명주소': '강원도 동해시 봉오주택길 22(용정동)',
#    '소재지지번주소': '강원도 동해시 용정동 475-3',
#    '위도': '37.51222384',
#    '경도': '129.1197999742',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '7~17',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '북평초등학교',
#    '소재지도로명주소': '강원도 동해시 오일장1길 22',
#    '소재지지번주소': '강원도 동해시 북평동 25-6',
#    '위도': '37.48224269',
#    '경도': '129.1242282',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6~15',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '북삼초등학교',
#    '소재지도로명주소': '강원도 동해시 지양길 77(지흥동)',
#    '소재지지번주소': '강원도 동해시 지흥동 504-26',
#    '위도': '37.49565579',
#    '경도': '129.1009681',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '20',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '남호초등학교',
#    '소재지도로명주소': '강원도 동해시 평원로 120',
#    '소재지지번주소': '강원도 동해시 평릉동 443',
#    '위도': '37.53437365',
#    '경도': '129.1131685',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '7~21',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '청운초등학교',
#    '소재지도로명주소': '강원도 동해시 청운로 60 (쇄운동)',
#    '소재지지번주소': '강원도 동해시 쇄운동 75',
#    '위도': '37.48530257',
#    '경도': '129.1041723',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '6',
#    '보호구역도로폭': '5~25',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '삼화초등학교',
#    '소재지도로명주소': '강원도 동해시 파수길 38 (이로동)',
#    '소재지지번주소': '강원도 동해시 이로동 32-12',
#    '위도': '37.48462946',
#    '경도': '129.0677053',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '5~30',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '묵호초등학교',
#    '소재지도로명주소': '강원도 동해시 발한천길 30 (발한동)',
#    '소재지지번주소': '강원도 동해시 발한동 318',
#    '위도': '37.55233526',
#    '경도': '129.1013302',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '7',
#    '보호구역도로폭': '5~25',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '송정초등학교',
#    '소재지도로명주소': '강원도 동해시 동해역길 25 (송정동)',
#    '소재지지번주소': '강원도 동해시 송정동 1058',
#    '위도': '37.49516620',
#    '경도': '129.1228671',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '11~15',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '창호초등학교',
#    '소재지도로명주소': '강원도 동해시 해맞이길 183 (묵호진동)',
#    '소재지지번주소': '강원도 동해시 묵호진동 85-7',
#    '위도': '37.55924192',
#    '경도': '129.1081542',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '8~20',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '동해삼육초교',
#    '소재지도로명주소': '강원도 동해시 동해대로 5367 (천곡동)',
#    '소재지지번주소': '강원도 동해시 천곡동 566-3',
#    '위도': '37.52207256',
#    '경도': '129.0997495',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '26',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '천곡중앙어린이집',
#    '소재지도로명주소': '강원도 동해시 감추2길 7 (천곡동)',
#    '소재지지번주소': '강원도 동해시 천곡동 965-11',
#    '위도': '37.51644310',
#    '경도': '129.1185311',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '8',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '유치원',
#    '대상시설명': '리라유치원',
#    '소재지도로명주소': '강원도 동해시 송이고개길 11 (발한동)',
#    '소재지지번주소': '강원도 동해시 발한동 589-3',
#    '위도': '37.54249910',
#    '경도': '129.0990119',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '유치원',
#    '대상시설명': '무지개유치원',
#    '소재지도로명주소': '강원도 동해시 천곡1길 90',
#    '소재지지번주소': '강원도 동해시 천곡동 487-10',
#    '위도': '37.52786374',
#    '경도': '129.106527',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '14',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '유치원',
#    '대상시설명': '성호유치원',
#    '소재지도로명주소': '강원도 동해시 샘실1길 7 (천곡동)',
#    '소재지지번주소': '강원도 동해시 천곡동 393-5',
#    '위도': '37.52031310',
#    '경도': '129.1047131',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '유치원',
#    '대상시설명': '예쁜유치원',
#    '소재지도로명주소': '강원도 동해시 감추3길 37-1',
#    '소재지지번주소': '강원도 동해시 천곡동 973-17',
#    '위도': '37.51701539',
#    '경도': '129.1222576',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '천곡어린이집',
#    '소재지도로명주소': '강원도 동해시 천곡로 15-1',
#    '소재지지번주소': '강원도 동해시 천곡동 789',
#    '위도': '37.52646010',
#    '경도': '129.1068466',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '14',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '동명어린이집',
#    '소재지도로명주소': '강원도 동해시 평릉길 42 (평릉동)',
#    '소재지지번주소': '강원도 동해시 평릉동 313',
#    '위도': '37.52952160',
#    '경도': '129.1016665',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '지혜어린이집',
#    '소재지도로명주소': '강원도 동해시 봉오동길 37',
#    '소재지지번주소': '강원도 동해시 용정동 265',
#    '위도': '37.51220446',
#    '경도': '129.1215731',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '7~9',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '대동튼튼나라어린이집',
#    '소재지도로명주소': '강원도 동해시 청운2길 17-3 (쇄운동)',
#    '소재지지번주소': '강원도 동해시 쇄운동 67-2',
#    '위도': '37.48499769',
#    '경도': '129.1052865',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '8',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '우주어린이집',
#    '소재지도로명주소': '강원도 동해시 가마골길 19',
#    '소재지지번주소': '강원도 동해시 부곡동 171-9',
#    '위도': '37.53591610',
#    '경도': '129.1015421',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '5',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '미래클어린이집',
#    '소재지도로명주소': '강원도 동해시 발한천윗길 30 (발한동)',
#    '소재지지번주소': '강원도 동해시 발한동 472-5',
#    '위도': '37.55279779',
#    '경도': '129.1011571',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '8',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '근로복지공단동해어린이집',
#    '소재지도로명주소': '강원도 동해시 샘실3길 21 (천곡동)',
#    '소재지지번주소': '강원도 동해시 천곡동 1051-10',
#    '위도': '37.52057747',
#    '경도': '129.1064418',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '한나어린이집',
#    '소재지도로명주소': '강원도 동해시 분토길 70 (지흥동)',
#    '소재지지번주소': '강원도 동해시 지흥동 59-2',
#    '위도': '37.49946102',
#    '경도': '129.1049059',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '유치원',
#    '대상시설명': '해오름유치원',
#    '소재지도로명주소': '강원도 동해시 관사길 11(발한동)',
#    '소재지지번주소': '강원도 동해시 발한동 253-4',
#    '위도': '37.54991915',
#    '경도': '129.1051032',
#    '관리기관명': '강원도 동해시',
#    '관할경찰서명': '동해경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-06',
#    '제공기관코드': '4210000',
#    '제공기관명': '강원도 동해시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '나래어린이집',
#    '소재지도로명주소': '서울특별시 중랑구 봉우재로 94-3',
#    '소재지지번주소': '서울특별시 중랑구 면목2동 133-3',
#    '위도': '37.59172695',
#    '경도': '127.0837119',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '어린이집',
#    '대상시설명': '이화어린이집',
#    '소재지도로명주소': '서울특별시 중랑구 면목로27길 85',
#    '소재지지번주소': '서울특별시 중랑구 면목4동 715-1',
#    '위도': '37.573952',
#    '경도': '127.080811',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '어린이집',
#    '대상시설명': '상봉어린이집',
#    '소재지도로명주소': '서울특별시 중랑구 상봉중앙로6길 57',
#    '소재지지번주소': '서울특별시 중랑구 상봉1동 287-1',
#    '위도': '37.60202594',
#    '경도': '127.0901512',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '어린이집',
#    '대상시설명': '삼성어린이집',
#    '소재지도로명주소': '서울특별시 중랑구 면목로88길 9',
#    '소재지지번주소': '서울특별시 중랑구 상봉2동 107-1',
#    '위도': '37.5941501',
#    '경도': '127.0869214',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '어린이집',
#    '대상시설명': '한내들어린이집',
#    '소재지도로명주소': '서울특별시 중랑구 동일로139라길 24',
#    '소재지지번주소': '서울특별시 중랑구 중화2동 332-48',
#    '위도': '37.604148',
#    '경도': '127.0749772',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '이루니유치원',
#    '소재지도로명주소': '서울특별시 중랑구 신내로7다길 57',
#    '소재지지번주소': '서울특별시 중랑구 상봉1동 63',
#    '위도': '37.60162827',
#    '경도': '127.0917588',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '봄내유치원',
#    '소재지도로명주소': '서울특별시 중랑구 면목로61길 50',
#    '소재지지번주소': '서울특별시 중랑구 면목본동 547-4',
#    '위도': '37.585935',
#    '경도': '127.085535',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '서안유치원',
#    '소재지도로명주소': '서울특별시 중랑구 동일로140길 15',
#    '소재지지번주소': '서울특별시 중랑구 중화1동 282-12',
#    '위도': '37.604325',
#    '경도': '127.079934',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '중곡초등학교병설유치원',
#    '소재지도로명주소': '서울특별시 중랑구 면목로23길 20',
#    '소재지지번주소': '서울특별시 중랑구 면목4동 380',
#    '위도': '37.57489299',
#    '경도': '127.0834395',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '동원초등학교병설유치원',
#    '소재지도로명주소': '서울특별시 중랑구 서울특별시 중랑구 송림길 114',
#    '소재지지번주소': '서울특별시 중랑구 망우본동 216',
#    '위도': '37.594978',
#    '경도': '127.104928',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '수산유치원',
#    '소재지도로명주소': '서울특별시 중랑구 중랑역로 35-1',
#    '소재지지번주소': '서울특별시 중랑구 중화2동 316-30',
#    '위도': '37.59762623',
#    '경도': '127.0759685',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '미림유치원',
#    '소재지도로명주소': '서울특별시 중랑구 공릉로 65',
#    '소재지지번주소': '서울특별시 중랑구 묵1동 162-1',
#    '위도': '37.61646036',
#    '경도': '127.0793223',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울원묵초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 숙선옹주로 109',
#    '소재지지번주소': '서울특별시 중랑구 묵1동 11',
#    '위도': '37.6177489',
#    '경도': '127.0868129',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '동일유치원',
#    '소재지도로명주소': '서울특별시 중랑구 면목로35길 21',
#    '소재지지번주소': '서울특별시 중랑구 면목7동 665-2',
#    '위도': '37.57814651',
#    '경도': '127.084613',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '색동유치원',
#    '소재지도로명주소': '서울특별시 중랑구 동일로109길 31',
#    '소재지지번주소': '서울특별시 중랑구 면목2동 183-120',
#    '위도': '37.591641',
#    '경도': '127.0784011',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '동국유치원',
#    '소재지도로명주소': '서울특별시 중랑구 용마산로45길 36',
#    '소재지지번주소': '서울특별시 중랑구 면목4동 1382',
#    '위도': '37.57385234',
#    '경도': '127.087174',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '예원유치원',
#    '소재지도로명주소': '서울특별시 중랑구 신내로51',
#    '소재지지번주소': '서울특별시 중랑구 신내2동 783',
#    '위도': '37.6059759',
#    '경도': '127.0947267',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '정암유치원',
#    '소재지도로명주소': '서울특별시 중랑구 용마산로118길 55',
#    '소재지지번주소': '서울특별시 중랑구 망우동 342-60',
#    '위도': '37.601161',
#    '경도': '127.1037709',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울새솔초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 신내역로1길 164',
#    '소재지지번주소': '서울특별시 중랑구 신내1동 241',
#    '위도': '37.61795176',
#    '경도': '127.1113289',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울묵현초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 동일로157길 75',
#    '소재지지번주소': '서울특별시 중랑구 묵2동 242-55',
#    '위도': '37.6090795',
#    '경도': '127.073615',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울중흥초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 봉화산로 82',
#    '소재지지번주소': '서울특별시 중랑구 중화1동 119',
#    '위도': '37.601635',
#    '경도': '127.0841443',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울중목초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 동일로 665',
#    '소재지지번주소': '서울특별시 중랑구 면목2동 180-5',
#    '위도': '37.59008654',
#    '경도': '127.079339',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울신현초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 봉화산로 188',
#    '소재지지번주소': '서울특별시 중랑구 신내2동 663',
#    '위도': '37.60581469',
#    '경도': '127.0935215',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울봉화초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 신내로 15길 110',
#    '소재지지번주소': '서울특별시 중랑구 신내2동 655',
#    '위도': '37.61357488',
#    '경도': '127.0924077',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '묵현초등학교병설유치원',
#    '소재지도로명주소': '서울특별시 중랑구 동일로157길 75',
#    '소재지지번주소': '서울특별시 중랑구 묵2동 242-55',
#    '위도': '37.6090795',
#    '경도': '127.073615',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울면목초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 면목로 434',
#    '소재지지번주소': '서울특별시 중랑구 면목본동 221',
#    '위도': '37.59069723',
#    '경도': '127.0872887',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울동원초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 송림길 114',
#    '소재지지번주소': '서울특별시 중랑구 망우본동 216',
#    '위도': '37.60457653',
#    '경도': '127.1044914',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울금성초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 신내로 21길 55',
#    '소재지지번주소': '서울특별시 중랑구 신내2동 651',
#    '위도': '37.61531395',
#    '경도': '127.0898591',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울신묵초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 동일로 149길 46',
#    '소재지지번주소': '서울특별시 중랑구 묵2동 246-12',
#    '위도': '37.60652294',
#    '경도': '127.0758372',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '어린이집',
#    '대상시설명': '근로복지공단어린이집',
#    '소재지도로명주소': '경기도 부천시 수도로206번길 54-14',
#    '소재지지번주소': '경기도 부천시 도당동 46',
#    '위도': '37.518142',
#    '경도': '126.787667',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '숙명키즈어린이집',
#    '소재지도로명주소': '경기도 부천시 지봉로115번길 44',
#    '소재지지번주소': '경기도 부천시 역곡동 103-6',
#    '위도': '37.490423',
#    '경도': '126.811068',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '행복이가득한어린이집',
#    '소재지도로명주소': '경기도 부천시 심곡로 23',
#    '소재지지번주소': '경기도 부천시 심곡본1동 599-16',
#    '위도': '37.4818147389',
#    '경도': '126.775951',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '9',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '예쁜어린이집',
#    '소재지도로명주소': '경기도 부천시 중동로71번길 82',
#    '소재지지번주소': '경기도 부천시 송내1동 363-5',
#    '위도': '37.48699616',
#    '경도': '126.759934',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '재원어린이집',
#    '소재지도로명주소': '경기도 부천시 역곡로26번길 70',
#    '소재지지번주소': '경기도 부천시 역곡동 115-1',
#    '위도': '37.4885188473',
#    '경도': '126.814411',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '새중동어린이집',
#    '소재지도로명주소': '경기도 부천시 중동로 165번길 34',
#    '소재지지번주소': '경기도 부천시 중동 710-4',
#    '위도': '37.494922',
#    '경도': '126.765525',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '새별나라어린이집',
#    '소재지도로명주소': '경기도 부천시 송내대로 30번길 84-7',
#    '소재지지번주소': '경기도 부천시 송내동 335-21',
#    '위도': '37.4856384840',
#    '경도': '126.758178',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '특수학교',
#    '대상시설명': '부천상록학교',
#    '소재지도로명주소': '경기도 부천시 길주로 574',
#    '소재지지번주소': '경기도 부천시 춘의동 258',
#    '위도': '37.5061075191',
#    '경도': '126.805865',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '32',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울묵동초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 동일로 138길 27',
#    '소재지지번주소': '서울특별시 중랑구 중화1동 277-1',
#    '위도': '37.60335895',
#    '경도': '127.0808259',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울면일초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 용마산로100길 13',
#    '소재지지번주소': '서울특별시 중랑구 망우3동 440',
#    '위도': '37.59204241',
#    '경도': '127.0997953',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울중화초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 신내로7가길 22',
#    '소재지지번주소': '서울특별시 중랑구 신내2동 531',
#    '위도': '37.60292027',
#    '경도': '127.094066',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울중랑초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 봉우재로6길26',
#    '소재지지번주소': '서울특별시 중랑구 면목2동 192-1',
#    '위도': '37.58966381',
#    '경도': '127.0755031',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울중곡초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 면목로23길 20',
#    '소재지지번주소': '서울특별시 중랑구 면목4동 380',
#    '위도': '37.57489299',
#    '경도': '127.0834395',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울신내초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 용마산로 125나길 22',
#    '소재지지번주소': '서울특별시 중랑구 신내1동 444',
#    '위도': '37.6049335',
#    '경도': '127.100154',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울면중초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 용마산로 70길 43',
#    '소재지지번주소': '서울특별시 중랑구 면목3.8동 491-1',
#    '위도': '37.582402',
#    '경도': '127.0965491',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울면북초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 용마공원로 5길 32',
#    '소재지지번주소': '서울특별시 중랑구 망우3동 119',
#    '위도': '37.594475',
#    '경도': '127.1035487',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울면동초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 면목로57길 32',
#    '소재지지번주소': '서울특별시 중랑구 면목본동 551',
#    '위도': '37.58535305',
#    '경도': '127.0865941',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울면남초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 면목로 30나길 38',
#    '소재지지번주소': '서울특별시 중랑구 면목7동 583-15',
#    '위도': '37.57726134',
#    '경도': '127.087667',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울망우초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 망우로 72길 49',
#    '소재지지번주소': '서울특별시 중랑구 망우본동 153-1',
#    '위도': '37.59873869',
#    '경도': '127.1038401',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '초등학교',
#    '대상시설명': '서울상봉초등학교',
#    '소재지도로명주소': '서울특별시 중랑구 동일로 126가길 11',
#    '소재지지번주소': '서울특별시 중랑구 상봉1동 312-1',
#    '위도': '37.59798021',
#    '경도': '127.0831709',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '지혜샘유치원',
#    '소재지도로명주소': '경기도 부천시 오정로211번길 64',
#    '소재지지번주소': '경기도 부천시 오정동 718',
#    '위도': '37.5298237429',
#    '경도': '126.781547',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '세화어린이집',
#    '소재지도로명주소': '서울특별시 중랑구 동일로123길 125',
#    '소재지지번주소': '서울특별시 중랑구 중화2동 328-62',
#    '위도': '37.59993259',
#    '경도': '127.073783',
#    '관리기관명': '서울특별시 중랑구청',
#    '관할경찰서명': '중랑경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-04-11',
#    '제공기관코드': '3060000',
#    '제공기관명': '서울특별시 중랑구'},
#   {'시설종류': '유치원',
#    '대상시설명': '민영유치원',
#    '소재지도로명주소': '경기도 부천시 부흥로 100-2',
#    '소재지지번주소': '경기도 부천시 상1동 393',
#    '위도': '37.4953543224',
#    '경도': '126.7534825842',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '동화유치원',
#    '소재지도로명주소': '경기도 부천시 성곡로69번길 48',
#    '소재지지번주소': '경기도 부천시 중3동 1040-6',
#    '위도': '37.5188977559',
#    '경도': '126.7948330014',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '푸른솔유치원',
#    '소재지도로명주소': '경기도 부천시 중동로279번길 22',
#    '소재지지번주소': '경기도 부천시 중4동 1036',
#    '위도': '37.5052493923',
#    '경도': '126.7689824928',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '성가정유치원',
#    '소재지도로명주소': '경기도 부천시 삼작로268번길 65-6',
#    '소재지지번주소': '경기도 부천시 도당동 71-1',
#    '위도': '37.5171133321',
#    '경도': '126.7913415',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '미래유치원',
#    '소재지도로명주소': '경기도 부천시 옥산로 89',
#    '소재지지번주소': '경기도 부천시 중동 1104',
#    '위도': '37.501449',
#    '경도': '126.780358',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '8',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '예원유치원',
#    '소재지도로명주소': '경기도 부천시 안곡로 284',
#    '소재지지번주소': '경기도 부천시 역곡1동 212-2',
#    '위도': '37.492766',
#    '경도': '126.8135346',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '삼오유치원',
#    '소재지도로명주소': '경기도 부천시 안곡로 41',
#    '소재지지번주소': '경기도 부천시 괴안동 90',
#    '위도': '37.4796363528',
#    '경도': '126.807382',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '소림사유치원',
#    '소재지도로명주소': '경기도 부천시 경인로216번길 106',
#    '소재지지번주소': '경기도 부천시 심곡본1동 642-3',
#    '위도': '37.478622',
#    '경도': '126.7785127855',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '혜성유치원',
#    '소재지도로명주소': '경기도 부천시 범안로7번길 53',
#    '소재지지번주소': '경기도 부천시 괴안동 110-25',
#    '위도': '37.4821469282',
#    '경도': '126.8082283288',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '대장유치원',
#    '소재지도로명주소': '경기도 부천시 소사로78번길 81',
#    '소재지지번주소': '경기도 부천시 소사본3동 403',
#    '위도': '37.4670074317',
#    '경도': '126.8012323190',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '11',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '백조유치원',
#    '소재지도로명주소': '경기도 부천시 원종로35번길 16',
#    '소재지지번주소': '경기도 부천시 원종동 228-3',
#    '위도': '37.524738',
#    '경도': '126.804207',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '효성유치원',
#    '소재지도로명주소': '경기도 부천시 삼작로496번길 10-3',
#    '소재지지번주소': '경기도 부천시 작동 48-2',
#    '위도': '37.518013',
#    '경도': '126.816361',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '샤인유치원',
#    '소재지도로명주소': '경기도 부천시 양지남로 69-12',
#    '소재지지번주소': '경기도 부천시 범박동 232-4',
#    '위도': '37.468327',
#    '경도': '126.814221',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '반석유치원',
#    '소재지도로명주소': '경기도 부천시 원미로143번길 6',
#    '소재지지번주소': '경기도 부천시 원미동 54-8',
#    '위도': '37.495432',
#    '경도': '126.7913029287',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '소화유치원',
#    '소재지도로명주소': '경기도 부천시 고강로72번길 51-6',
#    '소재지지번주소': '경기도 부천시 고강동 309-1',
#    '위도': '37.527177',
#    '경도': '126.8125753359',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '엄지유치원',
#    '소재지도로명주소': '경기도 부천시 성곡로33번길 22',
#    '소재지지번주소': '경기도 부천시 여월동 43-1',
#    '위도': '37.517447',
#    '경도': '126.799557',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '예아뜨유치원',
#    '소재지도로명주소': '경기도 부천시 상이로51번길 30',
#    '소재지지번주소': '경기도 부천시 상동 595-1',
#    '위도': '37.493454',
#    '경도': '126.742469',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '예일유치원',
#    '소재지도로명주소': '경기도 부천시 범안로 154',
#    '소재지지번주소': '경기도 부천시 범박동 151-3',
#    '위도': '37.4681192185',
#    '경도': '126.8090648',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '초록나무유치원',
#    '소재지도로명주소': '경기도 부천시 상일로 71',
#    '소재지지번주소': '경기도 부천시 상1동 397',
#    '위도': '37.493091',
#    '경도': '126.751108',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '더크는중앙유치원',
#    '소재지도로명주소': '경기도 부천시 오정로 266번길 15',
#    '소재지지번주소': '경기도 부천시 오정동 112-6',
#    '위도': '37.530766',
#    '경도': '126.788323',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '옥길유치원',
#    '소재지도로명주소': '경기도 부천시 양지로 166번길 56',
#    '소재지지번주소': '경기도 부천시 옥길동 711-3',
#    '위도': '37.468309',
#    '경도': '126.817881',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '새싹유치원+연세유치원',
#    '소재지도로명주소': '경기도 부천시 장말로 329',
#    '소재지지번주소': '경기도 부천시 심곡동 427-10',
#    '위도': '37.490953',
#    '경도': '126.778535',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '샘솔유치원',
#    '소재지도로명주소': '경기도 부천시 은성로19번길 58',
#    '소재지지번주소': '경기도 부천시 소사본동 142-2',
#    '위도': '37.477747',
#    '경도': '126.7936059',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '예능영재유치원',
#    '소재지도로명주소': '경기도 부천시 삼작로 416번길 14',
#    '소재지지번주소': '경기도 부천시 원종동 361-16',
#    '위도': '37.519271',
#    '경도': '126.8078608',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '꿈길유치원',
#    '소재지도로명주소': '경기도 부천시 옥길로 30번길 33',
#    '소재지지번주소': '경기도 부천시 옥길동 763번지',
#    '위도': '37.460376',
#    '경도': '126.817652',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '부천삼성어린이집',
#    '소재지도로명주소': '경기도 부천시 성오로 29',
#    '소재지지번주소': '경기도 부천시 여월동 10-39',
#    '위도': '37.5170389229',
#    '경도': '126.803271',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '5',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '큰나무어린이집',
#    '소재지도로명주소': '경기도 부천시 평천로696번길 21-2',
#    '소재지지번주소': '경기도 부천시 약대동 47-16',
#    '위도': '37.514014',
#    '경도': '126.768055',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '6',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '지원어린이집',
#    '소재지도로명주소': '경기도 부천시 상오정로7번길 44',
#    '소재지지번주소': '경기도 부천시 오정동 581-22',
#    '위도': '37.526209',
#    '경도': '126.7846063866',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '동화나라어린이집',
#    '소재지도로명주소': '경기도 부천시 원종로24번길 33',
#    '소재지지번주소': '경기도 부천시 원종2동 216-14',
#    '위도': '37.522499',
#    '경도': '126.802809',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '어린이집',
#    '대상시설명': '유진어린이집',
#    '소재지도로명주소': '경기도 부천시 성주로34번길 30-10',
#    '소재지지번주소': '경기도 부천시 송내동 423-9',
#    '위도': '37.4793030183',
#    '경도': '126.7612167208',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '부천서초등학교',
#    '소재지도로명주소': '경기도 부천시 부일로 330번길 30',
#    '소재지지번주소': '경기도 부천시 중동 807',
#    '위도': '37.4876507181',
#    '경도': '126.7656988491',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '11',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '부인초등학교',
#    '소재지도로명주소': '경기도 부천시 신상로 16',
#    '소재지지번주소': '경기도 부천시 상1동 398-1',
#    '위도': '37.4897917998',
#    '경도': '126.748754',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '10',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '버들초등학교',
#    '소재지도로명주소': '경기도 부천시 양지로 234-25',
#    '소재지지번주소': '경기도 부천시 옥길동 740-2',
#    '위도': '37.4642718499',
#    '경도': '126.8260095106',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '9',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '성주초등학교+샛별유치원',
#    '소재지도로명주소': '경기도 부천시 성주로 118',
#    '소재지지번주소': '경기도 부천시 송내2동 439',
#    '위도': '37.4784589881',
#    '경도': '126.7696294834',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '22',
#    '보호구역도로폭': '8',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '동원유치원',
#    '소재지도로명주소': '경기도 부천시 성곡로69번길 48',
#    '소재지지번주소': '경기도 부천시 도당동 129-1',
#    '위도': '37.518868',
#    '경도': '126.794836',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '미리내유치원',
#    '소재지도로명주소': '경기도 부천시 조마루로285번길 47',
#    '소재지지번주소': '경기도 부천시 중1동 1179',
#    '위도': '37.5003836963',
#    '경도': '126.7720408482',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '광서유치원',
#    '소재지도로명주소': '경기도 부천시 호수로 10-17',
#    '소재지지번주소': '경기도 부천시 상동 520-12',
#    '위도': '37.5135012091',
#    '경도': '126.752133',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '세화유치원',
#    '소재지도로명주소': '경기도 부천시 장말로 71',
#    '소재지지번주소': '경기도 부천시 상1동 392',
#    '위도': '37.49445401',
#    '경도': '126.7505945',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '사랑아트유치원+중동사랑아트유치원',
#    '소재지도로명주소': '경기도 부천시 석천로 110번길 61',
#    '소재지지번주소': '경기도 부천시 중동 595-8',
#    '위도': '37.496765',
#    '경도': '126.765065',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '오정유치원',
#    '소재지도로명주소': '경기도 부천시 원종로 9번길 44',
#    '소재지지번주소': '경기도 부천시 원종동 138-14',
#    '위도': '37.526006',
#    '경도': '126.801249',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '9',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '청심유치원',
#    '소재지도로명주소': '경기도 부천시 조마루로85번길 18',
#    '소재지지번주소': '경기도 부천시 상동 557-1',
#    '위도': '37.501031',
#    '경도': '126.7534948',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '상원초등학교+민영유치원',
#    '소재지도로명주소': '경기도 부천시 부흥로 93',
#    '소재지지번주소': '경기도 부천시 상동 570-7',
#    '위도': '37.4982717989',
#    '경도': '126.7532783715',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '9',
#    '보호구역도로폭': '22',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '상미초등학교',
#    '소재지도로명주소': '경기도 부천시 상이로 64',
#    '소재지지번주소': '경기도 부천시 상1동 585',
#    '위도': '37.4947273735',
#    '경도': '126.7445621843',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '9',
#    '보호구역도로폭': '16',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '중동초등학교',
#    '소재지도로명주소': '경기도 부천시 심중로75번길 37',
#    '소재지지번주소': '경기도 부천시 중동 776',
#    '위도': '37.4900271175',
#    '경도': '126.7693602367',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '8',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '창영초등학교',
#    '소재지도로명주소': '경기도 부천시 은성로 109-26',
#    '소재지지번주소': '경기도 부천시 괴안동 238-11',
#    '위도': '37.4751692942',
#    '경도': '126.804823',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '8',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '산들초등학교',
#    '소재지도로명주소': '경기도 부천시 옥길로 31',
#    '소재지지번주소': '경기도 부천시 옥길동 770',
#    '위도': '37.46254007',
#    '경도': '126.816457',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '16',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '범박초등학교',
#    '소재지도로명주소': '경기도 부천시 범박로 1',
#    '소재지지번주소': '경기도 부천시 범박동 47',
#    '위도': '37.4702753547',
#    '경도': '126.8113776763',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '10',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '부천남초등학교+소사유치원',
#    '소재지도로명주소': '경기도 부천시 성주로270번길 16-1',
#    '소재지지번주소': '경기도 부천시 심곡본동 674',
#    '위도': '37.4811762629',
#    '경도': '126.7829631331',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '9',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '소사초등학교+소새울유치원',
#    '소재지도로명주소': '경기도 부천시 은성로 58',
#    '소재지지번주소': '경기도 부천시 소사본3동 184-1',
#    '위도': '37.4736118677',
#    '경도': '126.7973297655',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '23',
#    '보호구역도로폭': '8',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '복사초등학교+대장유치원',
#    '소재지도로명주소': '경기도 부천시 소사로 96',
#    '소재지지번주소': '경기도 부천시 소사본3동 404',
#    '위도': '37.46711674',
#    '경도': '126.7991641909',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '8',
#    '보호구역도로폭': '12',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '부원초등학교',
#    '소재지도로명주소': '경기도 부천시 호현로447번길14',
#    '소재지지번주소': '경기도 부천시 소사본1동 143-6',
#    '위도': '37.4781891979',
#    '경도': '126.7913921104',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '9',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '도원초등학교+해아유치원',
#    '소재지도로명주소': '경기도 부천시 마니로 13',
#    '소재지지번주소': '경기도 부천시 심곡본1동 802',
#    '위도': '37.4770726441',
#    '경도': '126.7729532549',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '15',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '일신초등학교+멘사유치원',
#    '소재지도로명주소': '경기도 부천시 범안로96번길 26',
#    '소재지지번주소': '경기도 부천시 범박동 산16',
#    '위도': '37.4736237356',
#    '경도': '126.8070012476',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '13',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '솔안초등학교',
#    '소재지도로명주소': '경기도 부천시 경인로1185번길 27',
#    '소재지지번주소': '경기도 부천시 송내동 704-9',
#    '위도': '37.4857177049',
#    '경도': '126.7508603243',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '22',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '양지초등학교',
#    '소재지도로명주소': '경기도 부천시 안곡로 130',
#    '소재지지번주소': '경기도 부천시 괴안동 121',
#    '위도': '37.4805969227',
#    '경도': '126.8155270481',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '15',
#    '보호구역도로폭': '7',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '소안초등학교+하늘유치원',
#    '소재지도로명주소': '경기도 부천시 소사동로72번길 29',
#    '소재지지번주소': '경기도 부천시 소사본3동 산16',
#    '위도': '37.472374',
#    '경도': '126.804224',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천소사경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '20',
#    '보호구역도로폭': '9',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '역곡초등학교',
#    '소재지도로명주소': '경기도 부천시 역곡로65번길 12',
#    '소재지지번주소': '경기도 부천시 역곡1동 172-2',
#    '위도': '37.4908307090',
#    '경도': '126.8074876476',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천원미경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '13',
#    '보호구역도로폭': '8',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '고리울초등학교',
#    '소재지도로명주소': '경기도 부천시 고리울로 93',
#    '소재지지번주소': '경기도 부천시 고강동 325-4',
#    '위도': '37.5272738759',
#    '경도': '126.8271236757',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '17',
#    '보호구역도로폭': '6',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '대명초등학교+한사랑유치원',
#    '소재지도로명주소': '경기도 부천시 성오로 160',
#    '소재지지번주소': '경기도 부천시 원종동 127-8',
#    '위도': '37.5282567544',
#    '경도': '126.7973556711',
#    '관리기관명': '경기도 부천시청',
#    '관할경찰서명': '부천오정경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '17',
#    '보호구역도로폭': '15',
#    '데이터기준일자': '2022-04-08',
#    '제공기관코드': '3860000',
#    '제공기관명': '경기도 부천시'},
# ...
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '도지초교',
#    '소재지도로명주소': '경기도 이천시 백사면 청백리로 207',
#    '소재지지번주소': '경기도 이천시 백사면 도지리 410',
#    '위도': '37.3084025',
#    '경도': '127.4823129',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '마장초교',
#    '소재지도로명주소': '경기도 이천시 마장면 오천로 130',
#    '소재지지번주소': '경기도 이천시 마장면 오천리 71',
#    '위도': '37.24714546',
#    '경도': '127.3581646',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '백사초교',
#    '소재지도로명주소': '경기도 이천시 백사면 현방로 55',
#    '소재지지번주소': '경기도 이천시 백사면 현방리 87-8',
#    '위도': '37.33888982',
#    '경도': '127.4905347',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '부발초교',
#    '소재지도로명주소': '경기도 이천시 부발읍 무촌로 155',
#    '소재지지번주소': '경기도 이천시 부발읍 무촌리 195-5',
#    '위도': '37.28664819',
#    '경도': '127.4887298',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '설봉초교',
#    '소재지도로명주소': '경기도 이천시 향교로 129',
#    '소재지지번주소': '경기도 이천시 창전동 501',
#    '위도': '37.28477195',
#    '경도': '127.4524415',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '설성초교',
#    '소재지도로명주소': '경기도 이천시 설성면 진상미로264번길 21-165',
#    '소재지지번주소': '경기도 이천시 설성면 행죽리 78-1',
#    '위도': '37.11011014',
#    '경도': '127.5374462',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '송곡초교',
#    '소재지도로명주소': '경기도 이천시 모가면 진상미로 1054',
#    '소재지지번주소': '경기도 이천시 모가면 송곡리 295-2',
#    '위도': '37.15241874',
#    '경도': '127.4839411',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '신둔초교',
#    '소재지도로명주소': '경기도 이천시 신둔면 경충대로3150번길 82-3',
#    '소재지지번주소': '경기도 이천시 신둔면 수광리 262-1',
#    '위도': '37.31028911',
#    '경도': '127.4035246',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '신하초교',
#    '소재지도로명주소': '경기도 이천시 부발읍 경충대로2250번길 12',
#    '소재지지번주소': '경기도 이천시 부발읍 신하리 374-2',
#    '위도': '37.26109025',
#    '경도': '127.4792851',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '아미초교',
#    '소재지도로명주소': '경기도 이천시 부발읍 신아로92번길 32',
#    '소재지지번주소': '경기도 이천시 부발읍 아미리 761-6',
#    '위도': '37.25822718',
#    '경도': '127.4908672',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '안흥초교',
#    '소재지도로명주소': '경기도 이천시 영창로300번길 16 (안흥동)',
#    '소재지지번주소': '경기도 이천시 안흥동 344-1',
#    '위도': '37.28023162',
#    '경도': '127.4560737',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '율면초교',
#    '소재지도로명주소': '경기도 이천시 율면 고당로 48',
#    '소재지지번주소': '경기도 이천시 율면 고당리 545',
#    '위도': '37.08769894',
#    '경도': '127.5425098',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이천가산초교',
#    '소재지도로명주소': '경기도 이천시 부발읍 황무로2065번길 112',
#    '소재지지번주소': '경기도 이천시 부발읍 가산리 305-1',
#    '위도': '37.2416133',
#    '경도': '127.5178592',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이천남초교',
#    '소재지도로명주소': '경기도 이천시 경충대로2614번길 32 (중리동)',
#    '소재지지번주소': '경기도 이천시 중리동 455',
#    '위도': '37.27696329',
#    '경도': '127.443645',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '4',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이천단월초교',
#    '소재지도로명주소': '경기도 이천시 단월로 98 (단월동)',
#    '소재지지번주소': '경기도 이천시 단월동 182-3',
#    '위도': '37.22700348',
#    '경도': '127.4522059',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이천매곡초교',
#    '소재지도로명주소': '경기도 이천시 호법면 이섭대천로96번길 8',
#    '소재지지번주소': '경기도 이천시 호법면 매곡리 188-1',
#    '위도': '37.21483214',
#    '경도': '127.3944149',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이천사동초교',
#    '소재지도로명주소': '경기도 이천시 대월면 경충대로2003번길 124-87',
#    '소재지지번주소': '경기도 이천시 대월면 사동리 518',
#    '위도': '37.24158694',
#    '경도': '127.4874851',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이천송정초교',
#    '소재지도로명주소': '경기도 이천시 영창로45번길 165 (송정동)',
#    '소재지지번주소': '경기도 이천시 송정동 375-23',
#    '위도': '37.29418369',
#    '경도': '127.4333763',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이천초교',
#    '소재지도로명주소': '경기도 이천시 서희로81번길 20 (창전동)',
#    '소재지지번주소': '경기도 이천시 창전동 421-21',
#    '위도': '37.28401159',
#    '경도': '127.4422973',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '이황초교',
#    '소재지도로명주소': '경기도 이천시 장호원읍 경충대로 456-20',
#    '소재지지번주소': '경기도 이천시 장호원읍 이황리 159',
#    '위도': '37.14560869',
#    '경도': '127.5877192',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '장천초교',
#    '소재지도로명주소': '경기도 이천시 설성면 설성로 165-25',
#    '소재지지번주소': '경기도 이천시 설성면 장천리 360-1',
#    '위도': '37.14575495',
#    '경도': '127.5283315',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '장호원초교',
#    '소재지도로명주소': '경기도 이천시 장호원읍 장감로 46',
#    '소재지지번주소': '경기도 이천시 장호원읍 장호원리 104',
#    '위도': '37.11558427',
#    '경도': '127.6281309',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '3',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '증포초교',
#    '소재지도로명주소': '경기도 이천시 이섭대천로 1418',
#    '소재지지번주소': '경기도 이천시 증포동 477',
#    '위도': '37.2941947',
#    '경도': '127.4571713',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '진가초교',
#    '소재지도로명주소': '경기도 이천시 모가면 진상미로 1321-14',
#    '소재지지번주소': '경기도 이천시 모가면 진가리 156',
#    '위도': '37.17474613',
#    '경도': '127.4792165',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '표교초교',
#    '소재지도로명주소': '경기도 이천시 마장면 중부대로609번길 28-1',
#    '소재지지번주소': '경기도 이천시 마장면 목리 228',
#    '위도': '37.25672047',
#    '경도': '127.4058426',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '2',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '한내초교',
#    '소재지도로명주소': '경기도 이천시 갈산로 71 (증포동)',
#    '소재지지번주소': '경기도 이천시 증포동 70-5',
#    '위도': '37.29041031',
#    '경도': '127.4615308',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '1',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '초등학교',
#    '대상시설명': '호법초교',
#    '소재지도로명주소': '경기도 이천시 호법면 이섭대천로537번길 8',
#    '소재지지번주소': '경기도 이천시 호법면 후안리 295',
#    '위도': '37.22452827',
#    '경도': '127.4264713',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'Y',
#    'CCTV설치대수': '5',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '나래초병설',
#    '소재지도로명주소': '경기도 이천시 장호원읍 이풍로63번길 114',
#    '소재지지번주소': '경기도 이천시 장호원읍 나래리 293-1',
#    '위도': '37.16993358',
#    '경도': '127.5877245',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '대서초병설',
#    '소재지도로명주소': '경기도 이천시 장호원읍 서동대로8487번길 23-24',
#    '소재지지번주소': '경기도 이천시 장호원읍 대서리 14-1',
#    '위도': '37.11354416',
#    '경도': '127.5759988',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '대월초병설',
#    '소재지도로명주소': '경기도 이천시 대월면 대평로178번길 48',
#    '소재지지번주소': '경기도 이천시 대월면 초지리 426-1',
#    '위도': '37.22370097',
#    '경도': '127.4928014',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '도암초병설',
#    '소재지도로명주소': '경기도 이천시 신둔면 증신로 550',
#    '소재지지번주소': '경기도 이천시 신둔면 도암리 358',
#    '위도': '37.31859142',
#    '경도': '127.4427741',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '도지초병설',
#    '소재지도로명주소': '경기도 이천시 백사면 청백리로 207',
#    '소재지지번주소': '경기도 이천시 백사면 도지리 410',
#    '위도': '37.30848329',
#    '경도': '127.4823129',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '마장초병설',
#    '소재지도로명주소': '경기도 이천시 마장면 오천로 130',
#    '소재지지번주소': '경기도 이천시 마장면 오천리 71',
#    '위도': '37.24714546',
#    '경도': '127.3581646',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '백사초병설',
#    '소재지도로명주소': '경기도 이천시 백사면 현방로 55',
#    '소재지지번주소': '경기도 이천시 백사면 현방리 87-8',
#    '위도': '37.33888982',
#    '경도': '127.4905347',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '부발초병설',
#    '소재지도로명주소': '경기도 이천시 부발읍 무촌로 155',
#    '소재지지번주소': '경기도 이천시 부발읍 무촌리 195-5',
#    '위도': '37.28664819',
#    '경도': '127.4887298',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '설봉초병설',
#    '소재지도로명주소': '경기도 이천시 향교로 129',
#    '소재지지번주소': '경기도 이천시 창전동 501',
#    '위도': '37.28478087',
#    '경도': '127.4524641',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '송곡초병설',
#    '소재지도로명주소': '경기도 이천시 모가면 진상미로 1054',
#    '소재지지번주소': '경기도 이천시 모가면 송곡리 295-2',
#    '위도': '37.15241874',
#    '경도': '127.4839411',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '신둔초병설',
#    '소재지도로명주소': '경기도 이천시 신둔면 경충대로3150번길 82-3',
#    '소재지지번주소': '경기도 이천시 신둔면 수광리 262-1',
#    '위도': '37.31028911',
#    '경도': '127.4035246',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '신하초병설',
#    '소재지도로명주소': '경기도 이천시 부발읍 경충대로2250번길 12',
#    '소재지지번주소': '경기도 이천시 부발읍 신하리 374-2',
#    '위도': '37.26109025',
#    '경도': '127.4792851',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '아미초병설',
#    '소재지도로명주소': '경기도 이천시 부발읍 신아로92번길 32',
#    '소재지지번주소': '경기도 이천시 부발읍 아미리 761-6',
#    '위도': '37.25821817',
#    '경도': '127.4908672',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '안흥초병설',
#    '소재지도로명주소': '경기도 이천시 영창로300번길 16 (안흥동)',
#    '소재지지번주소': '경기도 이천시 안흥동 344-1',
#    '위도': '37.28023162',
#    '경도': '127.4560737',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '율면초병설',
#    '소재지도로명주소': '경기도 이천시 율면 고당로 48',
#    '소재지지번주소': '경기도 이천시 율면 고당리 545',
#    '위도': '37.08769894',
#    '경도': '127.5425098',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '이천가산초병설',
#    '소재지도로명주소': '경기도 이천시 부발읍 황무로2065번길 112',
#    '소재지지번주소': '경기도 이천시 부발읍 가산리 305-1',
#    '위도': '37.2416133',
#    '경도': '127.5178592',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '이천남초병설',
#    '소재지도로명주소': '경기도 이천시 경충대로2614번길 32 (중리동)',
#    '소재지지번주소': '경기도 이천시 중리동 455',
#    '위도': '37.27696329',
#    '경도': '127.443645',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '이천단월초병설',
#    '소재지도로명주소': '경기도 이천시 단월로 98 (단월동)',
#    '소재지지번주소': '경기도 이천시 단월동 182-3',
#    '위도': '37.22700348',
#    '경도': '127.4522059',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   {'시설종류': '유치원',
#    '대상시설명': '이천매곡초병설',
#    '소재지도로명주소': '경기도 이천시 호법면 이섭대천로96번길 8',
#    '소재지지번주소': '경기도 이천시 호법면 매곡리 188-1',
#    '위도': '37.21483214',
#    '경도': '127.3944149',
#    '관리기관명': '경기도 이천시청',
#    '관할경찰서명': '이천경찰서',
#    'CCTV설치여부': 'N',
#    'CCTV설치대수': '0',
#    '보호구역도로폭': '',
#    '데이터기준일자': '2022-09-28',
#    '제공기관코드': '4070000',
#    '제공기관명': '경기도 이천시'},
#   ...]}

# %%
column_list, all_data = get_df_info(children_json,'records')

# %%
df_children = pd.DataFrame(all_data, columns = column_list)

df_children.head()
# Out:
#    시설종류    대상시설명                 소재지도로명주소            소재지지번주소           위도  \
# 0  초등학교  동해중앙초등교     강원도 동해시 천곡로 35 (천곡동)    강원도 동해시 천곡동 793  37.52533371
# 1  초등학교   천곡초등학교     강원도 동해시 동굴로 33 (천곡동)    강원도 동해시 천곡동 320   37.5177521
# 2  초등학교   망상초등학교  강원도 동해시 동해대로 6251 (망상동)  강원도 동해시 망상동 360-2  37.59086742
# 3  초등학교   동호초등학교    강원도 동해시 발한로 123 (발한동)  강원도 동해시 발한동 570-1  37.54417872
# 4  초등학교   동해초등학교    강원도 동해시 봉오주택길 22(용정동)  강원도 동해시 용정동 475-3  37.51222384
#
#                경도    관리기관명 관할경찰서명 CCTV설치여부 CCTV설치대수 보호구역도로폭     데이터기준일자  \
# 0     129.1084972  강원도 동해시  동해경찰서        Y        6   11~30  2022-04-06
# 1     129.1078672  강원도 동해시  동해경찰서        Y        4      20  2022-04-06
# 2     129.0902466  강원도 동해시  동해경찰서        Y        3      21  2022-04-06
# 3     129.1001844  강원도 동해시  동해경찰서        Y        6   20~28  2022-04-06
# 4  129.1197999742  강원도 동해시  동해경찰서        Y        3    7~17  2022-04-06
#
#     제공기관코드    제공기관명
# 0  4210000  강원도 동해시
# 1  4210000  강원도 동해시
# 2  4210000  강원도 동해시
# 3  4210000  강원도 동해시
# 4  4210000  강원도 동해시

# %%
df_children = df_children[(df_children['소재지지번주소'].str.contains('서울')) & df_children['소재지도로명주소'].str.contains('서울')]
df_children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1238 entries, 28 to 13596
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시설종류      1238 non-null   object
#  1   대상시설명     1238 non-null   object
#  2   소재지도로명주소  1238 non-null   object
#  3   소재지지번주소   1238 non-null   object
#  4   위도        1238 non-null   object
#  5   경도        1238 non-null   object
#  6   관리기관명     1238 non-null   object
#  7   관할경찰서명    1238 non-null   object
#  8   CCTV설치여부  1238 non-null   object
#  9   CCTV설치대수  1238 non-null   object
#  10  보호구역도로폭   1238 non-null   object
#  11  데이터기준일자   1238 non-null   object
#  12  제공기관코드    1238 non-null   object
#  13  제공기관명     1238 non-null   object
# dtypes: object(14)
# memory usage: 145.1+ KB

# %%
df_children['위도'] = df_children['위도'].astype(float)
df_children['경도'] = df_children['경도'].astype(float)

df_children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1238 entries, 28 to 13596
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시설종류      1238 non-null   object
#  1   대상시설명     1238 non-null   object
#  2   소재지도로명주소  1238 non-null   object
#  3   소재지지번주소   1238 non-null   object
#  4   위도        1238 non-null   float64
#  5   경도        1238 non-null   float64
#  6   관리기관명     1238 non-null   object
#  7   관할경찰서명    1238 non-null   object
#  8   CCTV설치여부  1238 non-null   object
#  9   CCTV설치대수  1238 non-null   object
#  10  보호구역도로폭   1238 non-null   object
#  11  데이터기준일자   1238 non-null   object
#  12  제공기관코드    1238 non-null   object
#  13  제공기관명     1238 non-null   object
# dtypes: float64(2), object(12)
# memory usage: 145.1+ KB

# %%
df_children.isnull().sum()
# Out:
# 시설종류        0
# 대상시설명       0
# 소재지도로명주소    0
# 소재지지번주소     0
# 위도          0
# 경도          0
# 관리기관명       0
# 관할경찰서명      0
# CCTV설치여부    0
# CCTV설치대수    0
# 보호구역도로폭     0
# 데이터기준일자     0
# 제공기관코드      0
# 제공기관명       0
# dtype: int64

# %%
df_children[df_children['경도'] == ""]
# Out:
# Empty DataFrame
# Columns: [시설종류, 대상시설명, 소재지도로명주소, 소재지지번주소, 위도, 경도, 관리기관명, 관할경찰서명, CCTV설치여부, CCTV설치대수, 보호구역도로폭, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []

# %%
df_children[df_children['위도'] == ""]
# Out:
# Empty DataFrame
# Columns: [시설종류, 대상시설명, 소재지도로명주소, 소재지지번주소, 위도, 경도, 관리기관명, 관할경찰서명, CCTV설치여부, CCTV설치대수, 보호구역도로폭, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []

# %%
df_children[df_children['소재지도로명주소'] == ""]
# Out:
# Empty DataFrame
# Columns: [시설종류, 대상시설명, 소재지도로명주소, 소재지지번주소, 위도, 경도, 관리기관명, 관할경찰서명, CCTV설치여부, CCTV설치대수, 보호구역도로폭, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []

# %%
df_children[df_children['소재지지번주소'] == ""]
# Out:
# Empty DataFrame
# Columns: [시설종류, 대상시설명, 소재지도로명주소, 소재지지번주소, 위도, 경도, 관리기관명, 관할경찰서명, CCTV설치여부, CCTV설치대수, 보호구역도로폭, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []

# %%
df_children[df_children['CCTV설치여부'] == ""]
# Out:
# Empty DataFrame
# Columns: [시설종류, 대상시설명, 소재지도로명주소, 소재지지번주소, 위도, 경도, 관리기관명, 관할경찰서명, CCTV설치여부, CCTV설치대수, 보호구역도로폭, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []

# %%
df_children = df_children[['시설종류','대상시설명','소재지지번주소','위도','경도','CCTV설치여부']]
df_children
# Out:
#        시설종류    대상시설명                소재지지번주소         위도          경도 CCTV설치여부
# 28     어린이집   나래어린이집   서울특별시 중랑구 면목2동 133-3  37.591727  127.083712        Y
# 29     어린이집   이화어린이집   서울특별시 중랑구 면목4동 715-1  37.573952  127.080811        Y
# 30     어린이집   상봉어린이집   서울특별시 중랑구 상봉1동 287-1  37.602026  127.090151        Y
# 31     어린이집   삼성어린이집   서울특별시 중랑구 상봉2동 107-1  37.594150  127.086921        Y
# 32     어린이집  한내들어린이집  서울특별시 중랑구 중화2동 332-48  37.604148  127.074977        Y
# ...     ...      ...                    ...        ...         ...      ...
# 13590  특수학교   한국육영학교       서울특별시 송파구 장지동 45  37.482048  127.132505        Y
# 13591  초등학교  위례별초등학교      서울특별시 송파구 위례동 886  37.479086  127.145040        Y
# 13592  초등학교   잠신초등학교   서울특별시 송파구 잠실2동 22-10  37.514133  127.087919        Y
# 13593   유치원    티움유치원  서울특별시 송파구 송파2동 180-18  37.501103  127.115237        Y
# 13596  어린이집   예일어린이집     서울특별시 송파구 잠실본동 331  37.503428  127.085721        Y
#
# [1238 rows x 6 columns]

# %%
df_children_addr = df_children['소재지지번주소'].tolist()
df_children_addr
# Out:
# ['서울특별시 중랑구 면목2동 133-3',
#  '서울특별시 중랑구 면목4동 715-1',
#  '서울특별시 중랑구 상봉1동 287-1',
#  '서울특별시 중랑구 상봉2동 107-1',
#  '서울특별시 중랑구 중화2동 332-48',
#  '서울특별시 중랑구 상봉1동 63',
#  '서울특별시 중랑구 면목본동 547-4',
#  '서울특별시 중랑구 중화1동 282-12',
#  '서울특별시 중랑구 면목4동 380',
#  '서울특별시 중랑구 망우본동 216',
#  '서울특별시 중랑구 중화2동 316-30',
#  '서울특별시 중랑구 묵1동 162-1',
#  '서울특별시 중랑구 묵1동 11',
#  '서울특별시 중랑구 면목7동 665-2',
#  '서울특별시 중랑구 면목2동 183-120',
#  '서울특별시 중랑구 면목4동 1382',
#  '서울특별시 중랑구 신내2동 783',
#  '서울특별시 중랑구 망우동 342-60',
#  '서울특별시 중랑구 신내1동 241',
#  '서울특별시 중랑구 묵2동 242-55',
#  '서울특별시 중랑구 중화1동 119',
#  '서울특별시 중랑구 면목2동 180-5',
#  '서울특별시 중랑구 신내2동 663',
#  '서울특별시 중랑구 신내2동 655',
#  '서울특별시 중랑구 묵2동 242-55',
#  '서울특별시 중랑구 면목본동 221',
#  '서울특별시 중랑구 망우본동 216',
#  '서울특별시 중랑구 신내2동 651',
#  '서울특별시 중랑구 묵2동 246-12',
#  '서울특별시 중랑구 중화1동 277-1',
#  '서울특별시 중랑구 망우3동 440',
#  '서울특별시 중랑구 신내2동 531',
#  '서울특별시 중랑구 면목2동 192-1',
#  '서울특별시 중랑구 면목4동 380',
#  '서울특별시 중랑구 신내1동 444',
#  '서울특별시 중랑구 면목3.8동 491-1',
#  '서울특별시 중랑구 망우3동 119',
#  '서울특별시 중랑구 면목본동 551',
#  '서울특별시 중랑구 면목7동 583-15',
#  '서울특별시 중랑구 망우본동 153-1',
#  '서울특별시 중랑구 상봉1동 312-1',
#  '서울특별시 중랑구 중화2동 328-62',
#  '서울특별시 양천구 신정2동 281-1',
#  '서울특별시 양천구 신정1동 312-1',
#  '서울특별시 양천구 신정1동 543',
#  '서울특별시 양천구 신정4동 1001',
#  '서울특별시 양천구 목2동 4542',
#  '서울특별시 양천구 목5동 903-1',
#  '서울특별시 양천구 목5동 901-1',
#  '서울특별시 양천구 목4동 757',
#  '서울특별시 양천구 목5동 929',
#  '서울특별시 양천구 신월2동 448-5',
#  '서울특별시 양천구 신월6동 590-1',
#  '서울특별시 양천구 신정3동 1274',
#  '서울특별시 양천구 신정3동 1284',
#  '서울특별시 양천구 신정3동 1288-2',
#  '서울특별시 양천구 목1동 922',
#  '서울특별시 양천구 신정3동781-14',
#  '서울특별시 양천구 목5동 929',
#  '서울특별시 양천구 목3동 602-16',
#  '서울특별시 양천구 신정2동 1279',
#  '서울특별시 양천구 목3동 625-19',
#  '서울특별시 양천구 신월7동 987-1',
#  '서울특별시 양천구 신정7동 337-2',
#  '서울특별시 양천구 목5동 912',
#  '서울특별시 양천구 목1동 925',
#  '서울특별시 양천구 신정4동 915-4',
#  '서울특별시 양천구 신정6동 331',
#  '서울특별시 양천구 목2동 504-12',
#  '서울특별시 양천구 신월7동 953-6',
#  '서울특별시 양천구 목2동 131-3',
#  '서울특별시 양천구 목3동 713-23',
#  '서울특별시 양천구 신월3동 48-12',
#  '서울특별시 양천구 신월3동 149-6',
#  '서울특별시 양천구 신월1동 217-1',
#  '서울특별시 양천구 목5동 903-3',
#  '서울특별시 양천구 목4동 771-5',
#  '서울특별시 양천구 신월1동 226-7',
#  '서울특별시 양천구 목2동 231-50',
#  '서울특별시 양천구 신월7동 932-7',
#  '서울특별시 양천구 신정4동 957-16',
#  '서울특별시 양천구 신월2동 608-2',
#  '서울특별시 양천구 신정3동 1208-8',
#  '서울특별시 양천구 신정4동 911-6',
#  '서울특별시 양천구 신정4동 998-2',
#  '서울특별시 양천구 신정4동 913-5',
#  '서울특별시 양천구 신정3동 1316',
#  '서울특별시 양천구 신월4동 419-7',
#  '서울특별시 양천구 신월동 564-7',
#  '서울특별시 양천구 목동 531-17',
#  '서울특별시 양천구 신월동 911-3',
#  '서울특별시 양천구 신월7동 972-2',
#  '서울특별시 양천구 신정2동 296-93',
#  '서울특별시 양천구 신월1동 121-1',
#  '서울특별시 성북구 돈암동 593',
#  '서울특별시 성북구 길음동 1176',
#  '서울특별시 성북구 종암동 70-110',
#  '서울특별시 성북구 정릉동 239-2',
#  '서울특별시 성북구 정릉동 692-21',
#  '서울특별시 성북구 종암동 3-704',
#  '서울특별시 성북구 돈암동 595',
#  '서울특별시 성북구 장위동 233-333',
#  '서울특별시 성북구 하월곡동 77-214',
#  '서울특별시 성북구 안암동5가 산1-92',
#  '서울특별시 성북구 길음동 1281-7',
#  '서울특별시 성북구 장위동 258-18',
#  '서울특별시 성북구 석관동 300-18',
#  '서울특별시 성북구 길음동 1284-11',
#  '서울특별시 성북구 보문동6가 175-1',
#  '서울특별시 성북구 정릉동 307-4',
#  '서울특별시 성북구 석관동 410',
#  '서울특별시 성북구 성북동 226-220',
#  '서울특별시 성북구 정릉동 266-11',
#  '서울특별시 성북구 안암동2가 140-3',
#  '서울특별시 성북구 정릉동 873',
#  '서울특별시 성북구 정릉동 357',
#  '서울특별시 성북구 동소문동1가 1',
#  '서울특별시 성북구 길음동 877-255',
#  '서울특별시 성북구 정릉동 175-5',
#  '서울특별시 성북구 길음동 905',
#  '서울특별시 성북구 하월곡동 52-6',
#  '서울특별시 성북구 하월곡동 96-113',
#  '서울특별시 성북구 장위동 77-64',
#  '서울특별시 성북구 하월곡동 84-86',
#  '서울특별시 성북구 종암동 22-1',
#  '서울특별시 성북구 보문동2가 30',
#  '서울특별시 성북구 종암동 45-31',
#  '서울특별시 성북구 돈암동 609',
#  '서울특별시 성북구 석관동 248-5',
#  '서울특별시 성북구 장위동 316',
#  '서울특별시 성북구 동소문동7가 118-1',
#  '서울특별시 성북구 종암동 79-236',
#  '서울특별시 성북구 돈암동 609-1',
#  '서울특별시 성북구 정릉동 847',
#  '서울특별시 성북구 돈암동 173-1',
#  '서울특별시 성북구 길음동 1286',
#  '서울특별시 성북구 종암동 78-78',
#  '서울특별시 성북구 정릉동 266-441',
#  '서울특별시 성북구 하월곡동 222-7',
#  '서울특별시 성북구 성북동1가 117-1',
#  '서울특별시 성북구 동선동5가 70-35',
#  '서울특별시 성북구 동소문동6가 27-1',
#  '서울특별시 성북구 보문동 4가 4',
#  '서울특별시 성북구 보문동3가 228',
#  '서울특별시 성북구 돈암동 609-1',
#  '서울특별시 성북구 삼선동3가 30-4',
#  '서울특별시 성북구 동소문동1가 140-75',
#  '서울특별시 성북구 석관동 205',
#  '서울특별시 성북구 길음동 547-78',
#  '서울특별시 성북구 성북동 66-1',
#  '서울특별시 성북구 돈암동 413-79',
#  '서울특별시 성북구 정릉동 139-2',
#  '서울특별시 성북구 안암동3가 130-9',
#  '서울특별시 성북구 길음동 1280-7',
#  '서울특별시 성북구 정릉동 239-1',
#  '서울특별시 성북구 정릉동 771-3',
#  '서울특별시 성북구 길음동 1280-4',
#  '서울특별시 성북구 길음동 635-7',
#  '서울특별시 성북구 종암동 79-204',
#  '서울특별시 성북구 장위동 231-46',
#  '서울특별시 성북구 정릉동 181-22',
#  '서울특별시 성북구 길음동 1284-4',
#  '서울특별시 성북구 삼선동3가 30-4',
#  '서울특별시 성북구 석관동27-3',
#  '서울특별시 성북구 종암동 1-79',
#  '서울특별시 성북구 장위동 316',
#  '서울특별시 성북구 하월곡동 225-3',
#  '서울특별시 성북구 성북동 243-1',
#  '서울특별시 성북구 상월곡동 86-1',
#  '서울특별시 성북구 돈암동 609-1',
#  '서울특별시 성북구 종암동 99-10',
#  '서울특별시 성북구 돈암동 609-1',
#  '서울특별시 성북구 보문동3가 168-2',
#  '서울특별시 성북구 하월곡동 22',
#  '서울특별시 성북구 장위동 219-48',
#  '서울특별시 성북구 돈암동 15-3',
#  '서울특별시 성북구 길음동 1170',
#  '서울특별시 성북구 동소문동6가 27-1',
#  '서울특별시 성북구 정릉동 847',
#  '서울특별시 성북구 종암동 22-1',
#  '서울특별시 성북구 보문동3가 228',
#  '서울특별시 성북구 안암동2가 93',
#  '서울특별시 성북구 장위동 246-194',
#  '서울특별시 성북구 길음동 635-7',
#  '서울특별시 성북구 석관동 205',
#  '서울특별시 성북구 장위동 235',
#  '서울특별시 성북구 정릉동 798',
#  '서울특별시 성북구 정릉동 431-62',
#  '서울특별시 성북구 돈암동 2-8',
#  '서울특별시 성북구 길음동 1280-4',
#  '서울특별시 성북구 보문동7가 111',
#  '서울특별시 성북구 돈암동 45-88',
#  '서울특별시 성북구 길음동 1168',
#  '서울특별시 성북구 성북동 66-1',
#  '서울특별시 성북구 돈암동 산 11-269',
#  '서울특별시 성북구 하월곡동 84-86',
#  '서울특별시 성북구 정릉동 160-1',
#  '서울특별시 성북구 동소문동7가 118-1',
#  '서울특별시 성북구 장위동 68-8',
#  '서울특별시 성북구 장위동 128',
#  '서울특별시 동대문구 제기동 158-20',
#  '서울특별시 동대문구 답십리동 808-2',
#  '서울특별시 동대문구 장안동 336',
#  '서울특별시 동대문구 이문동 256-264',
#  '서울특별시 동대문구 휘경동 375',
#  '서울특별시 동대문구 장안동 439-2',
#  '서울특별시 동대문구 청량리동 61',
#  '서울특별시 동대문구 전농동 10',
#  '서울특별시 동대문구 답십리동557-1',
#  '서울특별시 동대문구 답십리동 477-9',
#  '서울특별시 동대문구 장안동 333-1',
#  '서울특별시 동대문구 장안동 444-7',
#  '서울특별시 동대문구 장안동 393-2',
#  '서울특별시 동대문구 제기동 220',
#  '서울특별시 동대문구 휘경동 308-196',
#  '서울특별시 동대문구 이문동 64-2',
#  '서울특별시 동대문구 이문동 115-46',
#  '서울특별시 동대문구 답십리동 990',
#  '서울특별시 동대문구 전농동 103-53',
#  '서울특별시 동대문구 장안동 94-61',
#  '서울특별시 동대문구 용두동 696-9',
#  '서울특별시 동대문구 장안동 388',
#  '서울특별시 동대문구 장안동 341-5',
#  '서울특별시 동대문구 이문동 217-1',
#  '서울특별시 동대문구 제기동 227-2',
#  '서울특별시 동대문구 회기동 58-1',
#  '서울특별시 동대문구 장안동 403-5',
#  '서울특별시 동대문구 제기동 681-2',
#  '서울특별시 동대문구 장안동 389-4',
#  '서울특별시 동대문구 답십리동 1000-1',
#  '서울특별시 동대문구 답십리동 52-5',
#  '서울특별시 동대문구 답십리동 50-35',
#  '서울특별시 동대문구 장안동 144-17',
#  '서울특별시 동대문구 용두동 29-3',
#  '서울특별시 동대문구 장안동 339-6',
#  '서울특별시 동대문구 장안동 289-31',
#  '서울특별시 동대문구 휘경동 343-4',
#  '서울특별시 동대문구 장안동 323',
#  '서울특별시 동대문구 장안동 323',
#  '서울특별시 동대문구 제기동 1157',
#  '서울특별시 동대문구 회기동 1-1',
#  '서울특별시 동대문구 청량리동 206-44',
#  '서울특별시 동대문구 전농동 3-111',
#  '서울특별시 동대문구 전농동 188',
#  '서울특별시 동대문구 전농동 298',
#  '서울특별시 동대문구 전농동 45-41',
#  '서울특별시 동대문구 전농동 45-41',
#  '서울특별시 동대문구 이문동 164-26',
#  '서울특별시 동대문구 이문동 164-26',
#  '서울특별시 동대문구 휘경동 302-2',
#  '서울특별시 동대문구 휘경동 302-2',
#  '서울특별시 동대문구 회기동 102-48',
#  '서울특별시 동대문구 장안동 328',
#  '서울특별시 동대문구 용두동 237-1',
#  '서울특별시 동대문구 제기동 678',
#  '서울특별시 동대문구 제기동 678',
#  '서울특별시 동대문구 휘경동 49-27',
#  '서울특별시 동대문구 휘경동 49-27',
#  '서울특별시 동대문구 답십리동 487-20',
#  '서울특별시 동대문구 휘경동 57-4',
#  '서울특별시 동대문구 장안동 354-1',
#  '서울특별시 동대문구 이문동 64',
#  '서울특별시 동대문구 제기동 252-1',
#  '서울특별시 동대문구 전농동 6',
#  '서울특별시 동대문구 이문동 321-31',
#  '서울특별시 동대문구 이문동 346-99',
#  '서울특별시 동대문구 전농동 643-36',
#  '서울특별시 동작구 사당동 169-8',
#  '서울특별시 동작구 상도3동 산77-1',
#  '서울특별시 동작구 상도동 511',
#  '서울특별시 동작구 대방동 386-2',
#  '서울특별시 동작구 사당5동 235-61',
#  '서울특별시 동작구 사당1동 1012-23',
#  '서울특별시 동작구 상도1동 159-403',
#  '서울특별시 동작구 사당1동 1011-1',
#  '서울특별시 동작구 상도3동 256-175',
#  '서울특별시 동작구 사당동 1131-4',
#  '서울특별시 동작구 흑석동 336-1',
#  '서울특별시 동작구 상도동 271',
#  '서울특별시 동작구 상도4동 212-128',
#  '서울특별시 동작구 상도동414',
#  '서울특별시 동작구 사당동316-56',
#  '서울특별시 동작구 흑석동 173-51',
#  '서울특별시 동작구 흑석동 257-9',
#  '서울특별시 동작구 사당동 260-14',
#  '서울특별시 동작구 사당동 300-3',
#  '서울특별시 동작구 사당동 120',
#  '서울특별시 동작구 사당동 300-2',
#  '서울특별시 동작구 대방동 381-48',
#  '서울특별시 동작구 상도동 264-60',
#  '서울특별시 동작구 사당동 41-42',
#  '서울특별시 동대문구 장안동 239-2',
#  '서울특별시 동대문구 장안동 239-2',
#  '서울특별시 동대문구 답십리동 274',
#  '서울특별시 동대문구 답십리동 274',
#  '서울특별시 동대문구 답십리동 2-24',
#  '서울특별시 동대문구 답십리동 463-13',
#  '서울특별시 동대문구 장안동 353-1',
#  '서울특별시 동작구 본동 133',
#  '서울특별시 동작구 사당3동 산18-34',
#  '서울특별시 동작구 상도4동 238-2',
#  '서울특별시 동작구 대방동 산28',
#  '서울특별시 동작구 사당5동 418-1',
#  '서울특별시 동작구 본동 441-11',
#  '서울특별시 동작구 대방동 44-3',
#  '서울특별시 동작구 흑석1동 245',
#  '서울특별시 동작구 흑석1동 233',
#  '서울특별시 동작구 사당5동 236-4',
#  '서울특별시 동작구 흑석동 7-1',
#  '서울특별시 동작구 상도동 134-600',
#  '서울특별시 동작구 상도4동 212-128',
#  '서울특별시 동작구 노량진동 325-1',
#  '서울특별시 동작구 흑석동 186',
#  '서울특별시 동작구 노량진1동 225-57',
#  '서울특별시 동작구 대방동 414-3',
#  '서울특별시 동작구 상도4동 211-1',
#  '서울특별시 동작구 상도4동 244-337',
#  '서울특별시 동작구 상도3동 256-175',
#  '서울특별시 동작구 신대방1동 607-32',
#  '서울특별시 동작구 대방동 503-1',
#  '서울특별시 동작구 신대방1동 707',
#  '서울특별시 동작구 흑석1동 211-32',
#  '서울특별시 동작구 상도1동 660-2',
#  '서울특별시 동작구 상도1동 415',
#  '서울특별시 동작구 상도동 산 65-225',
#  '서울특별시 동작구 사당5동 418-1',
#  '서울특별시 동작구 흑석1동 245',
#  '서울특별시 동작구 상도동 134-160',
#  '서울특별시 동작구 동작동 102-60',
#  '서울특별시 동작구 노량진동 323',
#  '서울특별시 중구 신당동 304-727',
#  '서울특별시 중구 신당동 432-24',
#  '서울특별시 중구 신당동 333-177',
#  '서울특별시 중구 신당동 67-29',
#  '서울특별시 중구 신당동 52-154',
#  '서울특별시 중구 서소문동 37',
#  '서울특별시 중구 황학동 1582',
#  '서울특별시 중구 신당동 366-76',
#  '서울특별시 중구 신당동 372-87',
#  '서울특별시 중구 신당동 372-468',
#  '서울특별시 중구 신당동 366-480',
#  '서울특별시 중구 중림동 149-2',
#  '서울특별시 중구 신당동 406-4',
#  '서울특별시 중구 신당동 844-1',
#  '서울특별시 중구 신당동 842-4',
#  '서울특별시 중구 신당동 842',
#  '서울특별시 중구 신당동 67-87',
#  '서울특별시 중구 황학동 755',
#  '서울특별시 중구 필동2가 113-1',
#  '서울특별시 중구 만리동1가 62-12',
#  '서울특별시 중구 장충동1가 26-6',
#  '서울특별시 중구 황학동 688',
#  '서울특별시 중구 신당동 424-2',
#  '서울특별시 동작구 상도2동 산65',
#  '서울특별시 동작구 상도1동 501',
#  '서울특별시 동작구 사당1동 1011-1',
#  '서울특별시 동작구 사당3동 산24',
#  '서울특별시 동작구 노량진1동 238',
#  '서울특별시 동작구 대방동391-62',
#  '서울특별시 동작구 동작동 산9-1',
#  '서울특별시 동작구 신대방1동 640',
#  '서울특별시 동작구 신대방1동 485-1',
#  '서울특별시 중구 신당동 330-2',
#  '서울특별시 중구 예장동 8-163',
#  '서울특별시 중구 정동 1-6',
#  '서울특별시 중구 신당동 254',
#  '서울특별시 중구 장충동2가 173-7',
#  '서울특별시 중구 만리동2가 2',
#  '서울특별시 중구 신당동 386-86',
#  '서울특별시 중구 남산동2가 2',
#  '서울특별시 중구 신당동 292-66',
#  '서울특별시 중구 신당동 161-2',
#  '서울특별시 중구 명동2가 83-8',
#  '서울특별시 중구 회현동1가 100-72',
#  '서울특별시 중구 남창동 202',
#  '서울특별시 강동구 둔촌2동 91-17',
#  '서울특별시 강동구 천호2동 306',
#  '서울특별시 강동구 고덕2동 158',
#  '서울특별시 강동구 명일2동 234',
#  '서울특별시 강동구 성내1동 531',
#  '서울특별시 강동구 천호1동 217-70',
#  '서울특별시 강동구 명일1동 296-1',
#  '서울특별시 강동구 성내1동 300-3',
#  '서울특별시 강동구 천호1동 230-9',
#  '서울특별시 강동구 고덕2동 222',
#  '서울특별시 강동구 길동 362',
#  '서울특별시 강동구 둔촌1동 176-2',
#  '서울특별시 강동구 길동 371-1',
#  '서울특별시 강동구 명일2동 39',
#  '서울특별시 강동구 암사1동 418-18',
#  '서울특별시 강동구 암사2동 517',
#  '서울특별시 강동구 둔촌2동 149',
#  '서울특별시 종로구 경운동 2, 운니동 114-7',
#  '서울특별시 종로구 누상동 54',
#  '서울특별시 종로구 숭인동 746',
#  '서울특별시 종로구 무악동 46-82',
#  '서울특별시 종로구 필운동 32',
#  '서울특별시 종로구 명륜1가 1-43',
#  '서울특별시 종로구 창신동 산1-1',
#  '서울특별시 종로구 궁정동 4-11',
#  '서울특별시 종로구 종로6가 210-1',
#  '서울특별시 종로구 신영동 105-10',
#  '서울특별시 종로구 행촌동 1-140',
#  '서울특별시 종로구 홍지동 56',
#  '서울특별시 종로구 평창동 186-18',
#  '서울특별시 종로구 종로구 신교동1-4',
#  '서울특별시 종로구 이화동 149',
#  '서울특별시 종로구 수송동 46-1',
#  '서울특별시 종로구 홍지동 94-9',
#  '서울특별시 종로구 신영동 219-4',
#  '서울특별시 종로구 필운동 278-4',
#  '서울특별시 종로구 사직동 262-57',
#  '서울특별시 종로구 창신동 산6-25',
#  '서울특별시 종로구 부암동 384-7',
#  '서울특별시 종로구 연지동 136-25',
#  '서울특별시 종로구 옥인동 18',
#  '서울특별시 종로구 창신동 23-330',
#  '서울특별시 광진구 군자동 99',
#  '서울특별시 광진구 능동 25',
#  '서울특별시 광진구 구의동 18',
#  '서울특별시 광진구 광장동 566',
#  '서울특별시 광진구 중곡동 220-22',
#  '서울특별시 광진구 광장동 472-1',
#  '서울특별시 광진구 구의동 240-25',
#  '서울특별시 광진구 구의동 590-3',
#  '서울특별시 광진구 능동 240-16',
#  '서울특별시 광진구 자양동 581-2',
#  '서울특별시 광진구 자양동 482-5',
#  '서울특별시 광진구 중곡동 587-8',
#  '서울특별시 광진구 중곡동 589-1',
#  '서울특별시 광진구 중곡동 191-60',
#  '서울특별시 광진구 중곡동 76-58',
#  '서울특별시 광진구 구의동 36-20',
#  '서울특별시 광진구 자양동 609-1',
#  '서울특별시 광진구 구의동 199-21',
#  '서울특별시 광진구 중곡동 134-25',
#  '서울특별시 광진구 중곡동 175-98',
#  '서울특별시 광진구 군자동 357-5',
#  '서울특별시 광진구 군자동 30-13',
#  '서울특별시 광진구 구의동 248-5',
#  '서울특별시 광진구 구의동 209-44',
#  '서울특별시 광진구 군자동 50',
#  '서울특별시 광진구 자양동 231-51',
#  '서울특별시 광진구 구의동 634-13',
#  '서울특별시 광진구 능동 249-4',
#  '서울특별시 광진구 구의동 619-30',
#  '서울특별시 광진구 광장동 401-17',
#  '서울특별시 광진구 구의동 587-52',
#  '서울특별시 광진구 구의3동 587-52',
#  '서울특별시 광진구 자양2동 662',
#  '서울특별시 광진구 군자동 111-3',
#  '서울특별시 광진구 자양3동 504',
#  '서울특별시 광진구 중곡4동 176-1',
#  '서울특별시 광진구 중곡3동 220-22',
#  '서울특별시 광진구 중곡3동 191-69',
#  '서울특별시 광진구 화양동 12',
#  '서울특별시 광진구 구의2동 60-44',
#  '서울특별시 광진구 광장동 414-1',
#  '서울특별시 광진구 광장동 484',
#  '서울특별시 광진구 자양동 694-1',
#  '서울특별시 광진구 능동 1811',
#  '서울특별시 광진구 자양동 658-1',
#  '서울특별시 광진구 구의동 31-18',
#  '서울특별시 광진구 자양동 579',
#  '서울특별시 광진구 자양동 843-11',
#  '서울특별시 광진구 군자동 127-1',
#  '서울특별시 광진구 자양동 225-85',
#  '서울특별시 광진구 자양동 553-339',
#  '서울특별시 광진구 구의동 631-1',
#  '서울특별시 광진구 광장동 218-1',
#  '서울특별시 광진구 자양동 516-3',
#  '서울특별시 광진구 구의동 208-15',
#  '서울특별시 광진구 광장동 272-2',
#  '서울특별시 광진구 중곡동 191-79',
#  '서울특별시 광진구 화양동 303-9',
#  '서울특별시 광진구 자양동 591',
#  '서울특별시 광진구 자양동 692',
#  '서울특별시 광진구 광장동 414-1',
#  '서울특별시 광진구 자양동 222',
#  '서울특별시 광진구 구의동 16-10',
#  '서울특별시 광진구 광장동 389-1',
#  '서울특별시 광진구 화양동 303-9',
#  '서울특별시 광진구 구의2동 4-5',
#  '서울특별시 광진구 자양3동 518-1',
#  '서울특별시 광진구 자양2동 591',
#  '서울특별시 광진구 자양1동 222',
#  '서울특별시 광진구 군자동 365-1',
#  '서울특별시 광진구 자양2동 692',
#  '서울특별시 광진구 중곡2동 135-1',
#  '서울특별시 광진구 자양2동 694-1',
#  '서울특별시 광진구 능동 25',
#  '서울특별시 광진구 광장동 554',
#  '서울특별시 마포구 아현동 267-3번지',
#  '서울특별시 마포구 아현동 386-1번지',
#  '서울특별시 마포구 공덕동 256-4번지',
#  '서울특별시 마포구 공덕동 256-4번지',
#  '서울특별시 마포구 도화동 224-9번지',
#  '서울특별시 마포구 도화동 224-9번지',
#  '서울특별시 마포구 도화동 550번지',
#  '서울특별시 마포구 대흥동 35-1번지',
#  '서울특별시 마포구 대흥동 35-1번지',
#  '서울특별시 마포구 상수동 1-1번지',
#  '서울특별시 마포구 성산동 산11-31번지',
#  '서울특별시 마포구 망원동 426-5번지',
#  '서울특별시 마포구 망원동 467-1번지',
#  '서울특별시 마포구 성산동 31-1번지',
#  '서울특별시 마포구 성산동 175-1번지',
#  '서울특별시 마포구 성산동 94-1번지',
#  '서울특별시 마포구 염리동 173-4번지',
#  '서울특별시 마포구 신수동 445-1번지',
#  '서울특별시 마포구 노고산동 33-1번지',
#  '서울특별시 마포구 노고산동 33-1번지',
#  '서울특별시 마포구 서교동 341번지',
#  '서울특별시 마포구 합정동 427-2번지',
#  '서울특별시 마포구 중동 42번지',
#  '서울특별시 마포구 염리동 24-140번지',
#  '서울특별시 마포구 상암동 1635번지',
#  '서울특별시 마포구 상암동 1635번지',
#  '서울특별시 마포구 상암동 1676번지',
#  '서울특별시 종로구 가회동 210',
#  '서울특별시 종로구 창신동 128-32',
#  '서울특별시 종로구 창신동 622-2',
#  '서울특별시 종로구 숭인동 48-2',
#  '서울특별시 종로구 청운동 6-3',
#  '서울특별시 종로구 청운동 123',
#  '서울특별시 종로구 구기동 151',
#  '서울특별시 종로구 숭인동 178-167',
#  '서울특별시 종로구 혜화동 109-2',
#  '서울특별시 종로구 혜화동 161-4',
#  '서울특별시 종로구 혜화동 13-1',
#  '서울특별시 종로구 효제동 255-4',
#  '서울특별시 영등포구 당산동 121-22',
#  '서울특별시 영등포구 여의도동 40-3',
#  '서울특별시 영등포구 문래동3가 77-7',
#  '서울특별시 영등포구 양평동3가 42',
#  '서울특별시 영등포구 당산동5가 5-3',
#  '서울특별시 영등포구 양평동4가 323',
#  '서울특별시 영등포구 신길1동 121',
#  '서울특별시 영등포구 대림동 652',
#  '서울특별시 영등포구 대림3동 608-1',
#  '서울특별시 영등포구 신길동 365',
#  '서울특별시 영등포구 신길동 170-7',
#  '서울특별시 영등포구 당산동3가 560',
#  '서울특별시 영등포구 신길동 281-24',
#  '서울특별시 영등포구 신길동 4903-20',
#  '서울특별시 영등포구 양평동1가 20',
#  '서울특별시 영등포구 신길동 890',
#  '서울특별시 영등포구 여의도동 53-19',
#  '서울특별시 영등포구 영등포동8가 84',
#  '서울특별시 영등포구 신길동 4916-15',
#  '서울특별시 영등포구 영등포동8가 69',
#  '서울특별시 영등포구 신길동 355-632',
#  '서울특별시 영등포구 양평동3가 91',
#  '서울특별시 영등포구 문래동6가 13',
#  '서울특별시 영등포구 영등포동 647-2',
#  '서울특별시 영등포구 신길동 210',
#  '서울특별시 영등포구 신길7동 1444',
#  '서울특별시 영등포구 대림동 968',
#  '서울특별시 영등포구 대림2동 993-16',
#  '서울특별시 영등포구 여의도동 38',
#  '서울특별시 영등포구 문래동1가 35-2',
#  '서울특별시 영등포구 대림3동 781',
#  '서울특별시 영등포구 대림3동 741-3',
#  '서울특별시 영등포구 신길동 285-1',
#  '서울특별시 영등포구 신길5동 341-1',
#  '서울특별시 영등포구 대림2동 702',
#  '서울특별시 영등포구 신길동 4482',
#  '서울특별시 영등포구 영등포동7가 53',
#  '서울특별시 영등포구 여의도동 16-3',
#  '서울특별시 영등포구 양평동3가 36',
#  '서울특별시 영등포구 신길동 3741-18',
#  '서울특별시 영등포구 신길4동 239-6',
#  '서울특별시 영등포구 신길동 232-20',
#  '서울특별시 영등포구 신길7동 869',
#  '서울특별시 영등포구 대림3동 777',
#  '서울특별시 영등포구 신길6동 4260',
#  '서울특별시 영등포구 양평동1가 211-1',
#  '서울특별시 영등포구 문래동5가 19-8',
#  '서울특별시 영등포구 당산동3가 474-2',
#  '서울특별시 영등포구 당산동 121-98',
#  '서울특별시 영등포구 여의도동 1',
#  '서울특별시 영등포구 신길동 440-53',
#  '서울특별시 영등포구 도림동 161',
#  '서울특별시 영등포구 양평동3가 8-2',
#  '서울특별시 영등포구 여의도동 38',
#  '서울특별시 영등포구 영등포동7가 53',
#  '서울특별시 영등포구 대림동 993-16',
#  '서울특별시 영등포구 문래동1가 35-2',
#  '서울특별시 영등포구 대림3동 741-3',
#  '서울특별시 영등포구 대림동 702',
#  '서울특별시 영등포구 양평동3가 42',
#  '서울특별시 영등포구 신길동 253-242',
#  '서울특별시 영등포구 양평동5가 76',
#  '서울특별시 영등포구 당산동5가 7-54',
#  '서울특별시 영등포구 대림동 912-46',
#  '서울특별시 영등포구 대림동 670-1',
#  '서울특별시 영등포구 당산동3가 79',
#  '서울특별시 마포구 상암동 1676번지',
#  '서울특별시 마포구 상암동 1737번지',
#  '서울특별시 마포구 상암동 1582번지',
#  '서울특별시 마포구 성산동 200-68번지',
#  '서울특별시 마포구 성산동 200-209번지',
#  '서울특별시 마포구 도화동 547번지',
#  '서울특별시 마포구 연남동 369-1번지',
#  '서울특별시 마포구 염리동 45-5번지',
#  '서울특별시 마포구 서교동 370-13번지',
#  '서울특별시 마포구 성산동 446번지',
#  '서울특별시 마포구 상암동 1639번지',
#  '서울특별시 마포구 성산동 13-15번지',
#  '서울특별시 마포구 연남동 493-6번지',
#  '서울특별시 마포구 상암동 1679번지',
#  '서울특별시 마포구 신수동 200-1번지',
#  '서울특별시 마포구 망원동 450-2번지',
#  '서울특별시 마포구 성산동 145-12번지',
#  '서울특별시 마포구 마포동 230번지',
#  '서울특별시 마포구 창전동 141-2번지',
#  '서울특별시 마포구 도화동 347-134번지',
#  '서울특별시 마포구 창전동 3-199번지',
#  '서울특별시 마포구 현석동 114-1번지',
#  '서울특별시 마포구 창전동 444번지',
#  '서울특별시 마포구 동교동 181-3번지',
#  '서울특별시 마포구 노고산동 33-20번지',
#  '서울특별시 강동구 상일동 125',
#  '서울특별시 강동구 고덕1동 487-15',
#  '서울특별시 강동구 고덕1동 498',
#  '서울특별시 강동구 상일동 328',
#  '서울특별시 강동구 길동 42',
#  '서울특별시 강동구 둔촌1동 170-2',
#  '서울특별시 강동구 암사2동 186-1',
#  '서울특별시 강동구 강일동 685',
#  '서울특별시 강동구 상일동 98',
#  '서울특별시 강동구 강일동 694',
#  '서울특별시 강동구 상일동 520-5',
#  '서울특별시 강동구 강일동 120-4',
#  '서울특별시 강동구 천호3동 56-34',
#  '서울특별시 강동구 천호3동 397-74',
#  '서울특별시 강동구 명일2동 237-1',
#  '서울특별시 강동구 명일2동 242-3',
#  '서울특별시 강동구 성내3동 430-6',
#  '서울특별시 강동구 명일2동 42',
#  '서울특별시 강동구 길동 79',
#  '서울특별시 강동구 천호2동 302-10',
#  '서울특별시 강동구 성내1동 590',
#  '서울특별시 강동구 고덕1동 177-8',
#  '서울특별시 강동구 암사2동 509',
#  '서울특별시 강동구 천호2동 363',
#  '서울특별시 강동구 둔촌2동 438',
#  '서울특별시 강동구 고덕1동 639-2',
#  '서울특별시 강동구 암사1동 418-18',
#  '서울특별시 강동구 고덕2동 222',
#  '서울특별시 강동구 명일1동 296-1',
#  '서울특별시 강동구 길동 362',
#  '서울특별시 강동구 둔촌2동 91-17',
#  '서울특별시 강동구 둔촌1동 176-2',
#  '서울특별시 강동구 상일동 126',
#  '서울특별시 강동구 상일동 495',
#  '서울특별시 강동구 강일동 685-2',
#  '서울특별시 강동구 상일동 166',
#  '서울특별시 강동구 상일동 514-1',
#  '서울특별시 강동구 상일동 179',
#  '서울특별시 강동구 고덕2동 297',
#  '서울특별시 강동구 암사2동 510-25',
#  '서울특별시 강동구 강일동 348-1',
#  '서울특별시 강동구 암사1동 437-1',
#  '서울특별시 강동구 암사동 474-8',
#  '서울특별시 강동구 천호2동 362-20',
#  '서울특별시 강동구 둔촌2동 81-4',
#  '서울특별시 강동구 길동 401-2',
#  '서울특별시 강동구 고덕1동 501-1',
#  '서울특별시 강동구 천호3동 186-7',
#  '서울특별시 강동구 성내3동 441-3',
#  '서울특별시 강동구 천호1동 49-33',
#  '서울특별시 강동구 성내1동 521-8',
#  '서울특별시 강동구 둔촌2동 452-2',
#  '서울특별시 강동구 천호3동 555',
#  '서울특별시 강동구 명일동 338-19',
#  '서울특별시 강동구 천호동 43-22',
#  '서울특별시 강동구 명일2동 248-4',
#  '서울특별시 강동구 암사동 490-39',
#  '서울특별시 강동구 고덕동 494-3',
#  '서울특별시 강동구 암사동 450-24',
#  '서울특별시 강동구 성내동 378-9',
#  '서울특별시 강동구 성내동 435-26',
#  '서울특별시 강동구 암사동 445-11',
#  '서울특별시 강동구 상일동 515',
#  '서울특별시 강동구 길동 123-2',
#  '서울특별시 강동구 천호동 331-31',
#  '서울특별시 강동구 길동 399-4',
#  '서울특별시 강동구 암사3동 442-1',
#  '서울특별시 관악구 신림동 300-7',
#  '서울특별시 관악구 신림동 1714-2',
#  '서울특별시 관악구 신림동 409-197',
#  '서울특별시 관악구 봉천동 196-80',
#  '서울특별시 관악구 신림동 611-142',
#  '서울특별시 관악구 신림동 95-53',
#  '서울특별시 관악구 신림동 763-68',
#  '서울특별시 관악구 신림동 727-10',
#  '서울특별시 관악구 신림동 606-1',
#  '서울특별시 관악구 신림동 611-4',
#  '서울특별시 관악구 신림동 614-18',
#  '서울특별시 관악구 신림동 725-24',
#  '서울특별시 관악구 봉천동 1634-17',
#  '서울특별시 관악구 신림동 673-85',
#  '서울특별시 관악구 봉천동 1718-2',
#  '서울특별시 관악구 봉천동 912-18',
#  '서울특별시 관악구 봉천동 1712-7',
#  '서울특별시 관악구 봉천동 1635-1',
#  '서울특별시 관악구 봉천동 1000',
#  '서울특별시 관악구 신림동 1704-3',
#  '서울특별시 관악구 봉천동 1712',
#  '서울특별시 관악구 남현동 1071-25',
#  '서울특별시 관악구 신림동 612-32',
#  '서울특별시 관악구 신림동 1694',
#  '서울특별시 관악구 신림동 1478-31',
#  '서울특별시 관악구 봉천동 1706',
#  '서울특별시 관악구 봉천동 1717-2',
#  '서울특별시 관악구 신림동 1735-9',
#  '서울특별시 관악구 신림동 315',
#  '서울특별시 관악구 봉천동 390-3',
#  '서울특별시 관악구 봉천동 491-5',
#  '서울특별시 관악구 봉천동 28-6',
#  '서울특별시 관악구 신림동 233-1',
#  '서울특별시 관악구 신림동 117-4',
#  '서울특별시 관악구 봉천동 1669-1',
#  '서울특별시 관악구 봉천동 622-1',
#  '서울특별시 관악구 봉천동 390-3',
#  '서울특별시 관악구 봉천동 722-19',
#  '서울특별시 관악구 신림동 673-82',
#  '서울특별시 관악구 봉천동 942-29',
#  '서울특별시 관악구 신림동 733',
#  '서울특별시 관악구 봉천동 1-85',
#  '서울특별시 관악구 신림동 501-30',
#  '서울특별시 관악구 신림동 538-16',
#  '서울특별시 관악구 신림동 1661-15',
#  '서울특별시 관악구 봉천동 390-3',
#  '서울특별시 관악구 봉천동 491-5',
#  '서울특별시 관악구 신림동 711-136',
#  '서울특별시 관악구 신림동 589-1',
#  '서울특별시 관악구 신림동 672',
#  '서울특별시 관악구 신림동 467',
#  '서울특별시 관악구 봉천동 692-8',
#  '서울특별시 관악구 신림동 768-21',
#  '서울특별시 관악구 남현동 1080-1',
#  '서울특별시 관악구 신림동 315',
#  '서울특별시 관악구 봉천동 1669-1',
#  '서울특별시 관악구 봉천동 212-3',
#  '서울특별시 관악구 봉천동 390-3',
#  '서울특별시 관악구 신림동 233-1',
#  '서울특별시 관악구 신림동 418-20',
#  '서울특별시 관악구 봉천동 458',
#  '서울특별시 관악구 봉천동 622-1',
#  '서울특별시 관악구 봉천동 28-6',
#  '서울특별시 관악구 신림동 117-4',
#  '서울특별시 관악구 봉천동 1704',
#  '서울특별시 관악구 신림동 336',
#  '서울특별시 관악구 신림동 548-2',
#  '서울특별시 관악구 봉천동 65-15',
#  '서울특별시 관악구 봉천동 935-2',
#  '서울특별시 성동구 송정동 72-8',
#  '서울특별시 성동구 행당동 317-18',
#  '서울특별시 성동구 행당동 320-60',
#  '서울특별시 성동구 성수동2가 277-32',
#  '서울특별시 성동구 응봉동 205-1',
#  '서울특별시 성동구 금호동1가 48-2',
#  '서울특별시 성동구 금호동4가 1254',
#  '서울특별시 성동구 용답동 29',
#  '서울특별시 성동구 성수동1가 656-32',
#  '서울특별시 성동구 금호동4가 440-12',
#  '서울특별시 성동구 마장동 556',
#  '서울특별시 성동구 성수동2가 268',
#  '서울특별시 성동구 사근동 291-5',
#  '서울특별시 성동구 마장동 766-49',
#  '서울특별시 성동구 성수동1가 19-1',
#  '서울특별시 성동구 옥수동 233-16',
#  '서울특별시 성동구 금호동2가 511',
#  '서울특별시 성동구 하왕십리동 950-1',
#  '서울특별시 성동구 송정동 72-8',
#  '서울특별시 노원구 상계9동 645',
#  '서울특별시 노원구 상계8동 621',
#  '서울특별시 노원구 상계8동 887-7',
#  '서울특별시 노원구 상계7동 755',
#  '서울특별시 노원구 중계3동 510-7',
#  '서울특별시 노원구 월계3동 223',
#  '서울특별시 노원구 월계3동 3-7',
#  '서울특별시 노원구 월계2동 806-3',
#  '서울특별시 노원구 하계2동 340',
#  '서울특별시 노원구 하계1동 152',
#  '서울특별시 노원구 상계4동 111',
#  '서울특별시 성동구 용답동 19-9',
#  '서울특별시 성동구 상왕십리동 813',
#  '서울특별시 성동구 용답동 223-5',
#  '서울특별시 성동구 마장동 527-14',
#  '서울특별시 성동구 금호동1가 622-1',
#  '서울특별시 성동구 옥수동 204-8',
#  '서울특별시 성동구 마장동 780',
#  '서울특별시 성동구 행당동 341-42',
#  '서울특별시 성동구 성수동1가 110',
#  '서울특별시 성동구 옥수동 250',
#  '서울특별시 성동구 옥수동 233-16',
#  '서울특별시 성동구 금호동4가 440-12',
#  '서울특별시 성동구 사근동 291-5',
#  '서울특별시 성동구 마장동 556',
#  '서울특별시 성동구 성수동2가 268',
#  '서울특별시 성동구 사근동 147',
#  '서울특별시 성동구 금호동4가 800',
#  '서울특별시 성동구 금호동3가 165-1',
#  '서울특별시 성동구 응봉동 100',
#  '서울특별시 성동구 홍익동 150',
#  '서울특별시 성동구 금호동1가 633',
#  '서울특별시 성동구 하왕십리동 258',
#  '서울특별시 성동구 성수동1가 19-1',
#  '서울특별시 성동구 하왕십리동 986-95',
#  '서울특별시 성동구 홍익동 236',
#  '서울특별시 성동구 마장동 785-2',
#  '서울특별시 성동구 행당동 349',
#  '서울특별시 성동구 사근동 110',
#  '서울특별시 성동구 하왕십리동 1068',
#  '서울특별시 성동구 옥수동 556-1',
#  '서울특별시 양천구 신정3동 653-5',
#  '서울특별시 양천구 신정4동 941',
#  '서울특별시 양천구 신월4동 441',
#  '서울특별시 양천구 신월5동 6-7',
#  '서울특별시 양천구 신월3동 204',
#  '서울특별시 양천구 신월2동 496',
#  '서울특별시 양천구 신월3동 40-1',
#  '서울특별시 양천구 신정7동 330-11',
#  '서울특별시 양천구 신월7동 987-3',
#  '서울특별시 양천구 목5동 911-4',
#  '서울특별시 양천구 신정7동 325-7',
#  '서울특별시 양천구 신정2동 86-2',
#  '서울특별시 양천구 목1동 927-5',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동423-40',
#  '서울특별시 노원구중계동423-40',
#  '서울특별시 노원구중계동423-40',
#  '서울특별시 노원구중계동423-40',
#  '서울특별시 노원구 상계3동 1200-74',
#  '서울특별시 노원구 중계본동 77',
#  '서울특별시 노원구 상계5동 447-1',
#  '서울특별시 노원구 상계9동 641',
#  '서울특별시 노원구 상계10동 678',
#  '서울특별시 노원구 상계9동 638',
#  '서울특별시 노원구 상계1동 1171-2',
#  '서울특별시 노원구 상계6동 768',
#  '서울특별시 노원구 상계6동 742',
#  '서울특별시 노원구 중계3동 515-1',
#  '서울특별시 노원구 중계3동 513-1',
#  '서울특별시 노원구 월계동 271',
#  '서울특별시 노원구 공릉3동 709',
#  '서울특별시 노원구 하계동 271',
#  '서울특별시 노원구 공릉2동 116',
#  '서울특별시 노원구 공릉2동 26-39',
#  '서울특별시 노원구 공릉2동 126',
#  '서울특별시 노원구 공릉동 610',
#  '서울특별시 노원구 중계2동 502',
#  '서울특별시 노원구 중계본동 357',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구중계동366-4',
#  '서울특별시 노원구 상계4동 111',
#  '서울특별시 노원구 중계본동 77',
#  '서울특별시 노원구 상계1동 1171-2',
#  '서울특별시 노원구 상계10동 678',
#  '서울특별시 노원구 상계8동 621',
#  '서울특별시 노원구 상계8동 887-7',
#  '서울특별시 노원구 공릉동 610',
#  '서울특별시 노원구 월계3동 322-1',
#  '서울특별시 노원구 공릉2동 81 태강@',
#  '서울특별시 노원구 월계동 582',
#  '서울특별시 노원구 월계동 781',
#  '서울특별시 노원구 상계1동 997 조흥한신@',
#  '서울특별시 노원구 공릉동 481-3',
#  '서울특별시 노원구 상계9동 641',
#  '서울특별시 노원구 월계2동 초안@단지',
#  '서울특별시 노원구 중계3동 512',
#  '서울특별시 노원구 상계3동 1285',
#  '서울특별시 노원구 중계4동 염광@내',
#  '서울특별시 노원구 하계2동 273',
#  '서울특별시 노원구 하계2동 354',
#  '서울특별시 노원구 하계동 256-5',
#  '서울특별시 노원구 공릉3동 714',
#  '서울특별시 노원구 하계1동 251',
#  '서울특별시 노원구 월계1동 435-5',
#  '서울특별시 노원구 상계10동 695',
#  '서울특별시 노원구 상계6동 737-2',
#  '서울특별시 노원구 중계동 505',
#  '서울특별시 노원구 중계3동 511-2',
#  '서울특별시 노원구 월계동 320-9',
#  '서울특별시 노원구 공릉3동 715',
#  '서울특별시 노원구 상계1동 1044',
#  '서울특별시 노원구 중계1동 산 72',
#  '서울특별시 노원구 중계본동 257-3',
#  '서울특별시 노원구 공릉1동 371',
#  '서울특별시 노원구 상계2동 402-1',
#  '서울특별시 노원구 상계1동 1014',
#  '서울특별시 노원구 상계10동 697',
#  '서울특별시 노원구 상계1동 1044',
#  '서울특별시 노원구 공릉2동 250',
#  '서울특별시 노원구 월계1동 470',
#  '서울특별시 노원구 중계4동 447-2',
#  '서울특별시 노원구 월계2동 602',
#  '서울특별시 노원구 하계동 78-14',
#  '서울특별시 노원구 하계1동 288-1',
#  '서울특별시 노원구 상계1동1019-83',
#  '서울특별시 노원구 상계4동 48-11',
#  '서울특별시 노원구 공릉2동 77',
#  '서울특별시 노원구 공릉1동 569-22',
#  '서울특별시 노원구 월계1동 411-46',
#  '서울특별시 노원구 하계1동 252-13',
#  '서울특별시 노원구 상계6.7동 205-1',
#  '서울특별시 노원구 상계2동 430-5',
#  '서울특별시 노원구 상계1동 1257',
#  '서울특별시 노원구 상계1동 1096-1',
#  '서울특별시 노원구 중계본동 364-5',
#  '서울특별시 노원구 중계동 43-12',
#  '서울특별시 노원구 하계동 135-7',
#  '서울특별시 노원구 상계8동 652-2',
#  '서울특별시 노원구 상계10동 673',
#  '서울특별시 노원구 중계4동 131-4',
#  '서울특별시 금천구 독산동 143-23',
#  '서울특별시 금천구 독산동 993-30',
#  '서울특별시 금천구 독산동 1153',
#  '서울특별시 금천구 시흥동 1013-1',
#  '서울특별시 강북구 수유동 466-52',
#  '서울특별시 강북구 미아동 438',
#  '서울특별시 강북구 미아동 1353-10',
#  '서울특별시 강북구 수유동 185-20',
#  '서울특별시 강북구 수유동 560-17',
#  '서울특별시 강북구 수유동 118-1',
#  '서울특별시 강북구 미아동 3-8',
#  '서울특별시 강북구 미아동 1354',
#  '서울특별시 강북구 번동 234-3',
#  '서울특별시 강북구 미아동 124-2',
#  '서울특별시 강북구 수유동 484-21',
#  '서울특별시 강북구 수유동 468-305',
#  '서울특별시 강북구 미아동 3-878',
#  '서울특별시 강북구 번동 520',
#  '서울특별시 강북구 수유동 542-6',
#  '서울특별시 강북구 미아동 791-469',
#  '서울특별시 강북구 수유동 472-236',
#  '서울특별시 강북구 미아동 791-2119',
#  '서울특별시 강북구 번동 430-66',
#  '서울특별시 강북구 번동 155-5',
#  '서울특별시 강북구 미아동 345-1',
#  '서울특별시 강북구 우이동 100-36',
#  '서울특별시 강북구 번동 177-2',
#  '서울특별시 강북구 수유동 246-3',
#  '서울특별시 강북구 우이동 124-46',
#  '서울특별시 강북구 번동 456',
#  '서울특별시 강북구 수유동 551-19',
#  '서울특별시 강북구 미아동 127-2',
#  '서울특별시 강북구 미아동 837-687',
#  '서울특별시 강북구 미아동 791-1932',
#  '서울특별시 강북구 미아동 94-1',
#  '서울특별시 강북구 수유동 55-5',
#  '서울특별시 강북구 수유동 409-6',
#  '서울특별시 강북구 번동 236',
#  '서울특별시 강북구 번동 248',
#  '서울특별시 강북구 미아동 471-2',
#  '서울특별시 금천구 시흥동 812-38',
#  '서울특별시 금천구 시흥동 919-15',
#  '서울특별시 금천구 시흥동 841-19',
#  '서울특별시 금천구 독산동 1090',
#  '서울특별시 금천구 독산동 906-28',
#  '서울특별시 금천구 독산동 1067-9',
#  '서울특별시 금천구 시흥동 420-11',
#  '서울특별시 금천구 독산동 938-5',
#  '서울특별시 금천구 독산동 182-44',
#  '서울특별시 금천구 시흥동 230',
#  '서울특별시 금천구 독산동 1062-10',
#  '서울특별시 금천구 시흥동 653-27',
#  '서울특별시 금천구 시흥동 881-25',
#  '서울특별시 금천구 시흥동 216',
#  '서울특별시 금천구 독산동 964-46',
#  '서울특별시 금천구 독산동 1051-20',
#  '서울특별시 금천구 독산동 1034',
#  '서울특별시 금천구 시흥동 산 100-4',
#  '서울특별시 금천구 시흥동 564-5',
#  '서울특별시 금천구 독산동 982',
#  '서울특별시 금천구 시흥동 438-5',
#  '서울특별시 금천구 시흥동 957-11',
#  '서울특별시 금천구 가산동 769',
#  '서울특별시 강서구 가양동 1477',
#  '서울특별시 은평구 통일로78길 10',
#  '서울특별시 은평구 응암로 376',
#  '서울특별시 은평구 녹번로 29-2',
#  '서울특별시 은평구 백련산로 36',
#  '서울특별시 은평구 갈현로33가길 24-1',
#  ...]

# %%
addr_list = []
for addr in df_children_addr: 
    addr_list.append(addr.split()[1])

# %%
df_children['행정구별'] = addr_list

df_children.head()
# Out:
#     시설종류    대상시설명                소재지지번주소         위도          경도 CCTV설치여부 행정구별
# 28  어린이집   나래어린이집   서울특별시 중랑구 면목2동 133-3  37.591727  127.083712        Y  중랑구
# 29  어린이집   이화어린이집   서울특별시 중랑구 면목4동 715-1  37.573952  127.080811        Y  중랑구
# 30  어린이집   상봉어린이집   서울특별시 중랑구 상봉1동 287-1  37.602026  127.090151        Y  중랑구
# 31  어린이집   삼성어린이집   서울특별시 중랑구 상봉2동 107-1  37.594150  127.086921        Y  중랑구
# 32  어린이집  한내들어린이집  서울특별시 중랑구 중화2동 332-48  37.604148  127.074977        Y  중랑구

# %%
df_children = df_children[['시설종류','대상시설명','행정구별','위도','경도','CCTV설치여부']]

df_children.head()
# Out:
#     시설종류    대상시설명 행정구별         위도          경도 CCTV설치여부
# 28  어린이집   나래어린이집  중랑구  37.591727  127.083712        Y
# 29  어린이집   이화어린이집  중랑구  37.573952  127.080811        Y
# 30  어린이집   상봉어린이집  중랑구  37.602026  127.090151        Y
# 31  어린이집   삼성어린이집  중랑구  37.594150  127.086921        Y
# 32  어린이집  한내들어린이집  중랑구  37.604148  127.074977        Y

# %% [markdown]
# #### => 필요한 열 재정렬

# %%
gwanak_map = folium.Map(location=[37.47826562816726,126.95148164982307],
               zoom_start=15, 
               width=750, 
               height=650
              )
gwanak_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73277cd6ebe7b79c6e0d1b19ea2f4795 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 650.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73277cd6ebe7b79c6e0d1b19ea2f4795&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73277cd6ebe7b79c6e0d1b19ea2f4795 = L.map(
#                 &quot;map_73277cd6ebe7b79c6e0d1b19ea2f4795&quot;,
#                 {
#                     center: [37.47826562816726, 126.95148164982307],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cca2e609f516383fd0e0621ecf736a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73277cd6ebe7b79c6e0d1b19ea2f4795);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geumcheon_map = folium.Map(location=[ 37.456649804679,126.89508519654187],
               zoom_start=15, 
               width=750, 
               height=650
              )
geumcheon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_187f30302290b407c7335d1ac9347a92 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 650.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_187f30302290b407c7335d1ac9347a92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_187f30302290b407c7335d1ac9347a92 = L.map(
#                 &quot;map_187f30302290b407c7335d1ac9347a92&quot;,
#                 {
#                     center: [37.456649804679, 126.89508519654187],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c54d21b974fd362f9c7b456acf6d505d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_187f30302290b407c7335d1ac9347a92);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_children_gwanak = df_children[(df_children['행정구별'] == '관악구')]
childpark_gwanak = childpark[(childpark['행정구별'] == '관악구')]

# %%
df_children_geumcheon = df_children[(df_children['행정구별'] == '금천구')]
childpark_geumcheon = childpark[(childpark['행정구별'] == '금천구')]

# %% [markdown]
# ### => 관악구와 금천구의 데이터만 보기 위해 전처리 해주었다

# %%
for name, lat, lng, m_num  in zip(childpark_gwanak['공원명'],childpark_gwanak['위도'],childpark_gwanak['경도'],childpark_gwanak['공원보유시설(유희시설)']):

    Marker(location =[lat,lng],
           popup=m_num,
           tooltip=name,
           icon=folium.Icon(color='orange',icon='bookmark')
           ).add_to(gwanak_map)
    
    folium.CircleMarker([lat, lng],
      radius= 30,
      color='tomato').add_to(gwanak_map)

# %%
for name, lat, lng, m_num  in zip(df_children_gwanak['시설종류'],df_children_gwanak['위도'],df_children_gwanak['경도'],df_children_gwanak['대상시설명']):

    Marker(location =[lat,lng],
           popup=m_num,
           tooltip=m_num,
           icon=folium.Icon(color='green',icon='star')
           ).add_to(gwanak_map)
gwanak_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73277cd6ebe7b79c6e0d1b19ea2f4795 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 650.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73277cd6ebe7b79c6e0d1b19ea2f4795&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73277cd6ebe7b79c6e0d1b19ea2f4795 = L.map(
#                 &quot;map_73277cd6ebe7b79c6e0d1b19ea2f4795&quot;,
#                 {
#                     center: [37.47826562816726, 126.95148164982307],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cca2e609f516383fd0e0621ecf736a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73277cd6ebe7b79c6e0d1b19ea2f4795);
#
#
#             var marker_996edda7dcd034adb8f5756a29f68a4b = L.marker(
#                 [37.465079, 126.927068],
#                 {}
#             ).addTo(map_73277cd6ebe7b79c6e0d1b19ea2f4795);
#
#
#             var icon_60bdb7b1e2c5edd42adf1b72290fd8b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_996edda7dcd034adb8f5756a29f68a4b.setIcon(icon_60bdb7b1e2c5edd42adf1b72290fd8b9);
#
#
#         var popup_b434756e1d50314bad9a96ff08d2a900 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d2df7aabd2b6836f4cccff68585c117 = $(`&lt;div id=&quot;html_8d2df7aabd2b6836f4cccff68585c117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;그네+흔들말+조합놀이대&lt;/div&gt;`)[0];
#                 popup_b434756e1d50314bad9a96ff08d2a900.setContent(html_8d2df7aabd2b6836f4cccff68585c117);
#
#
#
#         marker_996edda7dcd034adb8f5756a29f68a4b.bindPopup(popup_b434756e1d50314bad9a96ff08d2a900)
#         ;
#
#
#
#
#             marker_996edda7dcd034adb8f5756a29f68a4b.bindTooltip(
#                 `&lt;div&gt;
#                      합실
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c14a3f49fcfe1fa1693a7230aeb931e2 = L.circleMarker(
#                 [37.465079, 126.927068],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;tomato&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;tomato&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_73277cd6ebe7b79c6e0d1b19ea2f4795);
#
#
#             var marker_32604a5202ac9a62ab07f63bc414be6b = L.marker(
#                 [37.469221, 126.964465],
#                 {}
#             ).addTo(map_73277cd6ebe7b79c6e0d1b19ea2f4795);
#
#
#             var icon_6fd15a8c62fb7331b20bff485259bc89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_32604a5202ac9a62ab07f63bc414be6b.setIcon(icon_6fd15a8c62fb7331b20bff485259bc89);
#
#
#         var popup_b75790bfba8e114636f0df70b260a30c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_92735f4f17af3e159ce538e7f33718cf = $(`&lt;div id=&quot;html_92735f4f17af3e159ce538e7f33718cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;그네+흔들말+조합놀이대&lt;/div&gt;`)[0];
#                 popup_b75790bfba8e114636f0df70b260a30c.setContent(html_92735f4f17af3e159ce538e7f33718cf);
#
#
#
#         marker_32604a5202ac9a62ab07f63bc414be6b.bindPopup(popup_b75790bfba8e114636f0df70b260a30c)
#         ;
#
#
#
#
#             marker_32604a5202ac9a62ab07f63bc414be6b.bindTooltip(
#                 `&lt;div&gt;
#                      봉천
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_d0cfab8332b479128572a40d357e2b65 = L.circleMarker(
#                 [37.469221, 126.964465],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;tomato&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;tomato&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quo

# %%
for name, lat, lng, m_num  in zip(childpark_geumcheon['공원명'],childpark_geumcheon['위도'],childpark_geumcheon['경도'],childpark_geumcheon['공원보유시설(유희시설)']):

    Marker(location =[lat,lng],
           popup=m_num,
           tooltip=name,
           icon=folium.Icon(color='orange',icon='bookmark')
           ).add_to(geumcheon_map)
    folium.CircleMarker([lat, lng],
      radius= 30,
      color='tomato').add_to(geumcheon_map)

# %%
for name, lat, lng, m_num  in zip(df_children_geumcheon['시설종류'],df_children_geumcheon['위도'],df_children_geumcheon['경도'],df_children_geumcheon['대상시설명']):

    Marker(location =[lat,lng],
           popup=m_num,
           tooltip=m_num,
           icon=folium.Icon(color='green',icon='star')
           ).add_to(geumcheon_map)
geumcheon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_187f30302290b407c7335d1ac9347a92 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 650.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_187f30302290b407c7335d1ac9347a92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_187f30302290b407c7335d1ac9347a92 = L.map(
#                 &quot;map_187f30302290b407c7335d1ac9347a92&quot;,
#                 {
#                     center: [37.456649804679, 126.89508519654187],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c54d21b974fd362f9c7b456acf6d505d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_187f30302290b407c7335d1ac9347a92);
#
#
#             var marker_ee04d60bceb8470e8706e3e31b39fd41 = L.marker(
#                 [37.448147, 126.908596],
#                 {}
#             ).addTo(map_187f30302290b407c7335d1ac9347a92);
#
#
#             var icon_75fbf1a5a9ce3befa9052f392eae8095 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ee04d60bceb8470e8706e3e31b39fd41.setIcon(icon_75fbf1a5a9ce3befa9052f392eae8095);
#
#
#         var popup_58e8a7a40aa615c451c5d16020e6bd8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ef6cf5a78bee79893eca82546bd0228 = $(`&lt;div id=&quot;html_2ef6cf5a78bee79893eca82546bd0228&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;조합놀이대+그네+흔들놀이+시소+모래테이블+회전의자&lt;/div&gt;`)[0];
#                 popup_58e8a7a40aa615c451c5d16020e6bd8f.setContent(html_2ef6cf5a78bee79893eca82546bd0228);
#
#
#
#         marker_ee04d60bceb8470e8706e3e31b39fd41.bindPopup(popup_58e8a7a40aa615c451c5d16020e6bd8f)
#         ;
#
#
#
#
#             marker_ee04d60bceb8470e8706e3e31b39fd41.bindTooltip(
#                 `&lt;div&gt;
#                      별장길
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_70ae7d9b82d29ad3cd3db1eb6f1f3d92 = L.circleMarker(
#                 [37.448147, 126.908596],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;tomato&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;tomato&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_187f30302290b407c7335d1ac9347a92);
#
#
#             var marker_b4caa3835ca18ca5f60f662933dd5205 = L.marker(
#                 [37.477455, 126.907262],
#                 {}
#             ).addTo(map_187f30302290b407c7335d1ac9347a92);
#
#
#             var icon_a7cbd1ebc604fd3e3374db13086f81bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b4caa3835ca18ca5f60f662933dd5205.setIcon(icon_a7cbd1ebc604fd3e3374db13086f81bd);
#
#
#         var popup_737cf55375e24d8cb1a7052a7ec0a8e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_782bb953733bf3b523aed142c09713f9 = $(`&lt;div id=&quot;html_782bb953733bf3b523aed142c09713f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;조합놀이대+흔들놀이+그네+시소&lt;/div&gt;`)[0];
#                 popup_737cf55375e24d8cb1a7052a7ec0a8e7.setContent(html_782bb953733bf3b523aed142c09713f9);
#
#
#
#         marker_b4caa3835ca18ca5f60f662933dd5205.bindPopup(popup_737cf55375e24d8cb1a7052a7ec0a8e7)
#         ;
#
#
#
#
#             marker_b4caa3835ca18ca5f60f662933dd5205.bindTooltip(
#                 `&lt;div&gt;
#                      목화
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_31e17e8ab4504a86d119b9fd1f748646 = L.circleMarker(
#                 [37.477455, 126.907262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;tomato&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;tomato&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;,

# %% [markdown]
# ### => 주황색은 공원을 나타내고 초록색은 어린이보호구역을 나타낸다
# ### => 금천구 관악구의 어린이공원 반경 200m 안에 어린이구역이 포함되는 곳이 많지 않다.
