# %%
import pandas as pd
import csv

input_file = 'supplier_data_unnecessary_header_footer.csv'
output_file = 'output_files/11output_basic_pandas.csv'

data = pd.read_csv(input_file)

data
# Out:
#      I don't care about this row      Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 0    I don't care about this row             NaN          NaN        NaN
# 1    I don't care about this row             NaN          NaN        NaN
# 2                  Supplier Name  Invoice Number  Part Number       Cost
# 3                     Supplier X        001-1001         2341   $500.00
# 4                     Supplier X        001-1001         2341   $500.00
# 5                     Supplier X        001-1001         5467   $750.00
# 6                     Supplier X        001-1001         5467   $750.00
# 7                     Supplier Y         50-9501         7009   $250.00
# 8                     Supplier Y         50-9501         7009   $250.00
# 9                     Supplier Y         50-9505         6650   $125.00
# 10                    Supplier Y         50-9505         6650   $125.00
# 11                    Supplier Z        920-4803         3321   $615.00
# 12                    Supplier Z        920-4804         3321   $615.00
# 13                    Supplier Z        920-4805         3321   $615.00
# 14                    Supplier Z        920-4806         3321   $615.00
# 15  I don't want this row either             NaN          NaN        NaN
# 16  I don't want this row either             NaN          NaN        NaN
# 17  I don't want this row either             NaN          NaN        NaN
#
#        Unnamed: 4
# 0             NaN
# 1             NaN
# 2   Purchase Date
# 3       1/20/2014
# 4       1/20/2014
# 5       1/20/2014
# 6       1/20/2014
# 7       1/30/2014
# 8       1/30/2014
# 9        2/3/2014
# 10       2/3/2014
# 11       2/3/2014
# 12      2/10/2014
# 13      2/17/2014
# 14      2/24/2014
# 15            NaN
# 16            NaN
# 17            NaN

# %%
data = data.drop([0,1,15,16,17], axis = 0)
data = data.reindex()

data
# Out:
#    I don't care about this row      Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 2                Supplier Name  Invoice Number  Part Number       Cost
# 3                   Supplier X        001-1001         2341   $500.00
# 4                   Supplier X        001-1001         2341   $500.00
# 5                   Supplier X        001-1001         5467   $750.00
# 6                   Supplier X        001-1001         5467   $750.00
# 7                   Supplier Y         50-9501         7009   $250.00
# 8                   Supplier Y         50-9501         7009   $250.00
# 9                   Supplier Y         50-9505         6650   $125.00
# 10                  Supplier Y         50-9505         6650   $125.00
# 11                  Supplier Z        920-4803         3321   $615.00
# 12                  Supplier Z        920-4804         3321   $615.00
# 13                  Supplier Z        920-4805         3321   $615.00
# 14                  Supplier Z        920-4806         3321   $615.00
#
#        Unnamed: 4
# 2   Purchase Date
# 3       1/20/2014
# 4       1/20/2014
# 5       1/20/2014
# 6       1/20/2014
# 7       1/30/2014
# 8       1/30/2014
# 9        2/3/2014
# 10       2/3/2014
# 11       2/3/2014
# 12      2/10/2014
# 13      2/17/2014
# 14      2/24/2014

# %%
new_header = data.iloc[0] 
data = data[1:]
data.columns = new_header

data
# Out:
# 2  Supplier Name Invoice Number Part Number      Cost Purchase Date
# 3     Supplier X       001-1001        2341  $500.00      1/20/2014
# 4     Supplier X       001-1001        2341  $500.00      1/20/2014
# 5     Supplier X       001-1001        5467  $750.00      1/20/2014
# 6     Supplier X       001-1001        5467  $750.00      1/20/2014
# 7     Supplier Y        50-9501        7009  $250.00      1/30/2014
# 8     Supplier Y        50-9501        7009  $250.00      1/30/2014
# 9     Supplier Y        50-9505        6650  $125.00       2/3/2014
# 10    Supplier Y        50-9505        6650  $125.00       2/3/2014
# 11    Supplier Z       920-4803        3321  $615.00       2/3/2014
# 12    Supplier Z       920-4804        3321  $615.00      2/10/2014
# 13    Supplier Z       920-4805        3321  $615.00      2/17/2014
# 14    Supplier Z       920-4806        3321  $615.00      2/24/2014

# %%
data.to_csv(output_file, index = False)
