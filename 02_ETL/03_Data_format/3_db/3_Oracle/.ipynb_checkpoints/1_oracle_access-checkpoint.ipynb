# %%
import cx_Oracle

# %%
conn = cx_Oracle.connect('open_source/1111@localhost:1521/xe')
cur = conn.cursor()

# %%
cur.execute('select * from museum')
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to open_source@localhost:1521/xe>>

# %%
for record in cur:
    print(record)
# Out:
# ('추사박물관', '공립', '경기도 과천시 추사로 78(주암동)', 37.45300477, 127.0287251, '추사박물관', None, 2000, 1000, 500, '3970000')
# ('선바위미술관', '사립', '경기도 과천시 무네미길 34', 37.45177261, 126.9993028, '김옥분(개인)', None, 4000, 3000, 2000, '3970000')
# ('아해한국전통문화어린이박물관', '사립', '경기도 과천시 추사로 133', 37.45762016, 127.0299792, '문미옥(개인)', None, 5000, 5000, 5000, '3970000')
# ('한국카메라박물관', '사립', '경기도 과천시 대공원광장로 8', 37.43505342, 127.005667, '김종세(개인)', None, 5000, 5000, 5000, '3970000')
# ('말박물관', '사립', '경기도 과천시 경마공원대로 107', 37.4412003569, 127.0161266089, '한국마사회', None, 0, 0, 0, '3970000')
# ('금산역사문화박물관', '공립', '충청남도 금산군 금산읍 금산로 1575', 36.1141664, 127.4918544, '충청남도 금산군청', None, 0, 0, 0, '4550000')
# ('금산인삼관', '공립', '충청남도 금산군 금산읍 인삼광장로30', 36.1000256, 127.5007304, '충청남도 금산군청', None, 0, 0, 0, '4550000')
# ('태영민속박물관', '사립', '충청남도 금산군 남이면 하금평촌길 26', 36.05144078, 127.4368352, '태영민속박물관', None, 0, 0, 0, '4550000')
# ...
