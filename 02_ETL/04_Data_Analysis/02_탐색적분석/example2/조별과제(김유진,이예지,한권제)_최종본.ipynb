# %% [markdown]
# ###### => 최종목표: 현재까지 활동하고 있는 가수들의 장르를 분석하고, 이를 기존 장르데이터에 비교해본 뒤, 현재 음악 트랜드를 알아본다

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
file_path = '../data/best_selling_artists.csv'
artist = pd.read_csv(file_path) # read_csv 함수로 데이터를 Dataframe 형태로 불러옵니다.

# %% [markdown]
# ## 데이터 원본분석

# %%
artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         121 non-null    object
#  1   Country        121 non-null    object
#  2   period_active  121 non-null    object
#  3   Year           121 non-null    int64
#  4   Genre          121 non-null    object
#  5   TCU            121 non-null    object
#  6   Sales          121 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 6.7+ KB

# %%
artist.columns
# Out:
# Index(['Artist', 'Country', 'period_active', 'Year', 'Genre', 'TCU', 'Sales'], dtype='object')

# %% [markdown]
# * Artist          : 아티스트 이름
# * Country         : 아티스트가 출신 국가
# * period_active   : 아티스트가 음악을 만든 시간
# * Year            : 음반차트 첫 진입년도
# * Genre           : 아티스트의 음악 장르
# * TCU             : 인증받은 판매량
# * Sales           : 알려진 판매량

# %%
artist.shape
# Out:
# (121, 7)

# %%
artist.head(10)
# Out:
#             Artist         Country               period_active  Year  \
# 0      The Beatles  United Kingdom                   1960–1970  1962
# 1    Elvis Presley   United States                   1954–1977  1956
# 2  Michael Jackson   United States                   1964–2009  1971
# 3       Elton John  United Kingdom                1964–present  1970
# 4            Queen  United Kingdom                1971–present  1973
# 5          Madonna   United States                1979–present  1983
# 6     Led Zeppelin  United Kingdom                   1968–1980  1969
# 7          Rihanna        Barbados                2005–present  2005
# 8       Pink Floyd  United Kingdom  1965–1996, 2005, 2012–2014  1967
# 9           Eminem   United States                1996–present  1999
#
#                                  Genre            TCU                   Sales
# 0                           Rock / pop  290.4 million  600 million500 million
# 1        Rock and roll / pop / country  231.2 million             500 million
# 2      Pop / rock / dance / soul / R&B  277.3 million             400 million
# 3                           Pop / rock    208 million  300 million250 million
# 4                                 Rock    184 million  300 million250 million
# 5            Pop / dance / electronica  181.7 million  300 million250 million
# 6   Hard rock / blues rock / folk rock  142.4 million  300 million200 million
# 7          R&B / pop / dance / hip-hop  335.3 million  250 million230 million
# 8  Progressive rock / psychedelic rock  123.8 million  250 million200 million
# 9                              Hip-hop  325.7 million             220 million

# %%
artist.tail(10)
# Out:
#               Artist         Country       period_active  Year  \
# 111          Kenny G   United States        1982–present  1984
# 112        Green Day   United States        1987–present  1994
# 113             Enya         Ireland        1982–present  1987
# 114      Bryan Adams          Canada        1979–present  1979
# 115       Bob Marley         Jamaica           1962–1981  1975
# 116       The Police  United Kingdom  1977–19862007–2008  1978
# 117   Gloria Estefan   United States        1975–present  1984
# 118    Barry Manilow   United States        1973–present  1973
# 119             Kiss   United States        1972–present  1974
# 120  Aretha Franklin   United States           1956–2018  1961
#
#                                        Genre           TCU       Sales
# 111                              Smooth jazz  53.9 million  75 million
# 112  Punk rock / pop punk / alternative rock    53 million  75 million
# 113                         New-age / Celtic  51.9 million  75 million
# 114                                     Rock  49.9 million  75 million
# 115                                   Reggae  46.3 million  75 million
# 116                               Pop / rock  42.2 million  75 million
# 117                    Latin pop / dance pop  37.6 million  75 million
# 118                          Pop / soft rock  36.7 million  75 million
# 119                  Hard rock / heavy metal  28.7 million  75 million
# 120                Soul / jazz / blues / R&B  26.6 million  75 million

# %% [markdown]
# #### => 'sales'는 인증되지않은판매량이므로 인증된 수치인 'TCU'만 사용

# %%
artist = artist.drop(['Sales'], axis = 1)

# %%
artist
# Out:
#               Artist         Country       period_active  Year  \
# 0        The Beatles  United Kingdom           1960–1970  1962
# 1      Elvis Presley   United States           1954–1977  1956
# 2    Michael Jackson   United States           1964–2009  1971
# 3         Elton John  United Kingdom        1964–present  1970
# 4              Queen  United Kingdom        1971–present  1973
# ..               ...             ...                 ...   ...
# 116       The Police  United Kingdom  1977–19862007–2008  1978
# 117   Gloria Estefan   United States        1975–present  1984
# 118    Barry Manilow   United States        1973–present  1973
# 119             Kiss   United States        1972–present  1974
# 120  Aretha Franklin   United States           1956–2018  1961
#
#                                Genre            TCU
# 0                         Rock / pop  290.4 million
# 1      Rock and roll / pop / country  231.2 million
# 2    Pop / rock / dance / soul / R&B  277.3 million
# 3                         Pop / rock    208 million
# 4                               Rock    184 million
# ..                               ...            ...
# 116                       Pop / rock   42.2 million
# 117            Latin pop / dance pop   37.6 million
# 118                  Pop / soft rock   36.7 million
# 119          Hard rock / heavy metal   28.7 million
# 120        Soul / jazz / blues / R&B   26.6 million
#
# [121 rows x 6 columns]

# %% [markdown]
# ## 결측치, 이상치 점검

# %%
artist['TCU'] = artist.TCU.str.split(' ').str[0].astype('float64')

# %%
artist['TCU'] = artist['TCU']*1000000

# %%
artist['TCU']
# Out:
# 0      290400000.0
# 1      231200000.0
# 2      277300000.0
# 3      208000000.0
# 4      184000000.0
#           ...
# 116     42200000.0
# 117     37600000.0
# 118     36700000.0
# 119     28700000.0
# 120     26600000.0
# Name: TCU, Length: 121, dtype: float64

# %%
artist.isnull().sum()
# Out:
# Artist           0
# Country          0
# period_active    0
# Year             0
# Genre            0
# TCU              0
# dtype: int64

# %%
artist[artist['Country'].map(len) < 3]
# Out:
# Empty DataFrame
# Columns: [Artist, Country, period_active, Year, Genre, TCU]
# Index: []

# %%
#artist['Debut']=artist.period_active.str.split('–').str[0].astype('int64') #데뷔년도

# %%
#artist['Year']=artist['Year'].astype('int64')

# %%
#artist['Cart_In_period']=artist['Year']-artist['Debut'] #차트인하기까지 걸린 시간

# %%
# sort_by_cartin=artist[['Artist','Cart_In_period']]
# sort_by_cartin=sort_by_cartin.sort_values('Cart_In_period',ascending=0)
# sort_by_cartin.head()

# %%
# cartin_avg=sort_by_cartin['Cart_In_period'].mean()

# %%
# plt.title('차트인을 늦게 한 가수들')
# plt.xticks(rotation = -45)
# sns.barplot(x='Artist',y='Cart_In_period',data=sort_by_cartin.head(10))
# plt.plot([0,10], [cartin_avg, cartin_avg], "k--")
# plt.show()

# %% [markdown]
# ## 탐색적 데이터 분석

# %% [markdown]
# ### 현재까지 활동하고 있는 가수 중 가장 사랑받는 장르는 무엇일까? 그리고 년도별 사랑받는 장르는 무엇일까?

# %% [markdown]
# ### 년도별 인기있는 장르 분석
# => 1960, 70, 80, 90, 2000년대 이후

# %%
artist_year_1960 = artist.loc[(artist['Year'] >= 1960) & (artist['Year'] <= 1969)]

artist_year_1960.head()
# Out:
#                 Artist         Country               period_active  Year  \
# 0          The Beatles  United Kingdom                   1960–1970  1962
# 6         Led Zeppelin  United Kingdom                   1968–1980  1969
# 8           Pink Floyd  United Kingdom  1965–1996, 2005, 2012–2014  1967
# 17  The Rolling Stones  United Kingdom                1962–present  1963
# 29    Barbra Streisand   United States                1960–present  1963
#
#                                   Genre          TCU  Debut  Cart_In_period
# 0                            Rock / pop  290400000.0   1960               2
# 6    Hard rock / blues rock / folk rock  142400000.0   1968               1
# 8   Progressive rock / psychedelic rock  123800000.0   1965               2
# 17                    Rock / blues rock  102700000.0   1962               1
# 29             Pop / adult contemporary   98400000.0   1960               3

# %%
df=pd.DataFrame(index=['count'])

# %%
Genre=artist['Genre'].str.split("/")

# %%
genre_list=[]
for genres in Genre:
    for genre in genres:
        if genre.strip().lower() not in genre_list:
            genre_list.append(genre.strip().lower())
genre_list
# Out:
# ['rock',
#  'pop',
#  'rock and roll',
#  'country',
#  'dance',
#  'soul',
#  'r&b',
#  'electronica',
#  'hard rock',
#  'blues rock',
#  'folk rock',
#  'hip-hop',
#  'progressive rock',
#  'psychedelic rock',
#  'folk',
#  'alternative',
#  'gospel',
#  'electronic',
#  'teen pop',
#  'dance pop',
#  'folk pop',
#  'pop rock',
#  'adult contemporary',
#  'disco',
#  'swing',
#  'easy listening',
#  'heavy metal',
#  'thrash metal',
#  'funk rock',
#  'dance-pop',
#  'alternative rock',
#  'glam metal',
#  'nu metal',
#  'rap rock',
#  'country pop',
#  'blues',
#  'funk',
#  'soft rock',
#  'latin',
#  'art rock',
#  'glam rock',
#  'surf rock',
#  'neo soul',
#  'hip house',
#  'edm',
#  'latin pop',
#  'j-pop',
#  'electropop',
#  'grunge',
#  'smooth jazz',
#  'punk rock',
#  'pop punk',
#  'new-age',
#  'celtic',
#  'reggae',
#  'jazz']

# %%
for genre in genre_list:
     df[genre]= artist_year_1960.loc[artist_year_1960['Genre'].str.contains(genre,case=0),'TCU'].count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5552\1685550945.py in <module>
#       1 for genre in genre_list:
# ----> 2      df[genre]= artist_year_1960.loc[artist_year_1960['Genre'].str.contains(genre,case=0),'TCU'].count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
#     179         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     229
#     230         if inferred_dtype not in allowed_types:
# --> 231             raise AttributeError("Can only use .str accessor with string values!")
#     232         return inferred_dtype
#     233
#
# AttributeError: Can only use .str accessor with string values!

# %%
df.T.reset_index(inplace=True)

# %%
artist_year_1960 =  df.T.sort_values(by='count',ascending=0)
artist_year_1960
# Out:
# Empty DataFrame
# Columns: [count]
# Index: []

# %%
artist_year_1960.reset_index(inplace=True)

# %%
artist_year_1960
# Out:
# Empty DataFrame
# Columns: [index, count]
# Index: []

# %%
artist_year_1960.columns = ['Genre','count']

artist_year_1960
# Out:
# Empty DataFrame
# Columns: [Genre, count]
# Index: []

# %%
plt.xticks(rotation = -80)
sns.barplot(x='Genre',y='count',data=artist_year_1960)
plt.show()

# %% [markdown]
# => 60년대에 가장 인기있었던 장르는 Rock / pop , pop 순이다

# %% [markdown]
# 1970년대

# %%
artist_year_1970 = artist.loc[(artist['Year'] >= 1970) & (artist['Year'] <= 1979)]

artist_year_1970.head()
# Out:
#              Artist         Country            period_active  Year  \
# 2   Michael Jackson   United States                1964–2009  1971
# 3        Elton John  United Kingdom             1964–present  1970
# 4             Queen  United Kingdom             1971–present  1973
# 14           Eagles   United States  1971–1980, 1994–present  1972
# 16            AC/DC       Australia             1973–present  1975
#
#                                      Genre          TCU  Debut  Cart_In_period
# 2          Pop / rock / dance / soul / R&B  277300000.0   1964               7
# 3                               Pop / rock  208000000.0   1964               6
# 4                                     Rock  184000000.0   1971               2
# 14                                    Rock  152200000.0   1971               1
# 16  Hard rock / blues rock / rock and roll  130200000.0   1973               2

# %%
artist_year_1970 = pd.DataFrame(artist_year_1970['Genre'].value_counts())

artist_year_1970
# Out:
#                                         Genre
# Rock                                        7
# Hard rock / heavy metal                     3
# Pop / rock                                  3
# Rock / hard rock                            2
# Pop / rock / dance / soul / R&B             1
# Reggae                                      1
# Pop / disco / R&B                           1
# Rock / pop                                  1
# Funk / R&B / soul                           1
# Rock / soft rock                            1
# Country / pop                               1
# Funk / R&B / pop / soul / rock              1
# Rock / blues                                1
# Pop / disco                                 1
# Hard rock                                   1
# Hard rock / blues rock / rock and roll      1
# Pop / soft rock                             1

# %%
artist_year_1970.reset_index(inplace=True)

# %%
artist_year_1970
# Out:
#                                      index  Genre
# 0                                     Rock      7
# 1                  Hard rock / heavy metal      3
# 2                               Pop / rock      3
# 3                         Rock / hard rock      2
# 4          Pop / rock / dance / soul / R&B      1
# 5                                   Reggae      1
# 6                        Pop / disco / R&B      1
# 7                               Rock / pop      1
# 8                        Funk / R&B / soul      1
# 9                         Rock / soft rock      1
# 10                           Country / pop      1
# 11          Funk / R&B / pop / soul / rock      1
# 12                            Rock / blues      1
# 13                             Pop / disco      1
# 14                               Hard rock      1
# 15  Hard rock / blues rock / rock and roll      1
# 16                         Pop / soft rock      1

# %%
artist_year_1970.columns = ['Genre','count']

artist_year_1970
# Out:
#                                      Genre  count
# 0                                     Rock      7
# 1                  Hard rock / heavy metal      3
# 2                               Pop / rock      3
# 3                         Rock / hard rock      2
# 4          Pop / rock / dance / soul / R&B      1
# 5                                   Reggae      1
# 6                        Pop / disco / R&B      1
# 7                               Rock / pop      1
# 8                        Funk / R&B / soul      1
# 9                         Rock / soft rock      1
# 10                           Country / pop      1
# 11          Funk / R&B / pop / soul / rock      1
# 12                            Rock / blues      1
# 13                             Pop / disco      1
# 14                               Hard rock      1
# 15  Hard rock / blues rock / rock and roll      1
# 16                         Pop / soft rock      1

# %%
plt.xticks(rotation = -70)
sns.barplot(x='Genre',y='count',data=artist_year_1970)
plt.show()

# %% [markdown]
# => 70년대 가장 인기있었던 장르는 Rock, Hard rock / heavy metal 순이다

# %%
artist_year_1980 = artist.loc[(artist['Year'] >= 1980) & (artist['Year'] <= 1989)]

artist_year_1980.head()
# Out:
#              Artist        Country period_active  Year  \
# 5           Madonna  United States  1979–present  1983
# 13  Whitney Houston  United States     1977–2012  1984
# 15      Celine Dion         Canada  1981–present  1981
# 19     Garth Brooks  United States  1989–present  1989
# 26               U2        Ireland  1976–present  1980
#
#                         Genre          TCU  Debut  Cart_In_period
# 5   Pop / dance / electronica  181700000.0   1979               4
# 13  R&B / soul / pop / gospel  155300000.0   1977               7
# 15                 Pop / Rock  143000000.0   1981               0
# 19                    Country  165300000.0   1989               0
# 26                       Rock  114600000.0   1976               4

# %%
artist_year_1980 = pd.DataFrame(artist_year_1980['Genre'].value_counts())

artist_year_1980
# Out:
#                                               Genre
# Country                                           2
# Pop / dance / electronica                         1
# Hard rock / heavy metal                           1
# New-age / Celtic                                  1
# Smooth jazz                                       1
# Country / pop rock                                1
# Alternative rock                                  1
# Pop / R&B                                         1
# Pop                                               1
# R&B / pop                                         1
# Rock / pop rock / hard rock                       1
# R&B / soul / pop / gospel                         1
# Hard rock / glam metal                            1
# Funk rock / alternative rock                      1
# Heavy metal / thrash metal                        1
# Rock / progressive rock / adult contemporary      1
# Rock                                              1
# Pop / Rock                                        1
# Latin pop / dance pop                             1

# %%
artist_year_1980.reset_index(inplace=True)

# %%
artist_year_1980
# Out:
#                                            index  Genre
# 0                                        Country      2
# 1                      Pop / dance / electronica      1
# 2                        Hard rock / heavy metal      1
# 3                               New-age / Celtic      1
# 4                                    Smooth jazz      1
# 5                             Country / pop rock      1
# 6                               Alternative rock      1
# 7                                      Pop / R&B      1
# 8                                            Pop      1
# 9                                      R&B / pop      1
# 10                   Rock / pop rock / hard rock      1
# 11                     R&B / soul / pop / gospel      1
# 12                        Hard rock / glam metal      1
# 13                  Funk rock / alternative rock      1
# 14                    Heavy metal / thrash metal      1
# 15  Rock / progressive rock / adult contemporary      1
# 16                                          Rock      1
# 17                                    Pop / Rock      1
# 18                         Latin pop / dance pop      1

# %%
artist_year_1980.columns = ['Genre','count']

# %%
plt.xticks(rotation = -70)
sns.barplot(x='Genre',y='count',data=artist_year_1980)
plt.show()

# %% [markdown]
# => 80년대는 Country가 가장 인기있는 장르지만,
# 가장 많은 데이터와 편차가 심하지않고 다른 데이터가 골고루 분산되서 많은 장르가 사랑받은것으로 보임.

# %% [markdown]
# 1990년대

# %%
artist_year_1990 = artist.loc[(artist['Year'] >= 1990) & (artist['Year'] <= 1999)]

artist_year_1990.head()
# Out:
#           Artist         Country period_active  Year  \
# 9         Eminem   United States  1996–present  1999
# 10  Mariah Carey   United States  1988–present  1990
# 34         Jay-Z   United States  1996–present  1996
# 37     Lil Wayne   United States  1996–present  1999
# 46      Coldplay  United Kingdom  1996–present  1999
#
#                                 Genre          TCU  Debut  Cart_In_period
# 9                             Hip-hop  325700000.0   1996               3
# 10         R&B / pop / soul / hip-hop  205800000.0   1988               2
# 34                            Hip-hop  136400000.0   1996               0
# 37                            Hip-hop  188700000.0   1996               3
# 46  Alternative rock / pop rock / pop  109400000.0   1996               3

# %%
artist_year_1990 = pd.DataFrame(artist_year_1990['Genre'].value_counts())

artist_year_1990
# Out:
#                                          Genre
# Hip-hop                                      4
# R&B / pop / soul / hip-hop                   1
# Alternative rock / pop rock / pop            1
# Pop / dance / dance-pop                      1
# Country pop                                  1
# Pop                                          1
# R&B / pop / rock                             1
# R&B / pop                                    1
# Latin pop / pop / pop rock                   1
# Country                                      1
# Hip-hop / R&B / dance                        1
# J-pop / pop / dance / electronic             1
# R&B / soul / hip-hop                         1
# Grunge / alternative rock                    1
# Pop rock                                     1
# Punk rock / pop punk / alternative rock      1

# %%
artist_year_1990.reset_index(inplace=True)

# %%
artist_year_1990
# Out:
#                                       index  Genre
# 0                                   Hip-hop      4
# 1                R&B / pop / soul / hip-hop      1
# 2         Alternative rock / pop rock / pop      1
# 3                   Pop / dance / dance-pop      1
# 4                               Country pop      1
# 5                                       Pop      1
# 6                          R&B / pop / rock      1
# 7                                 R&B / pop      1
# 8                Latin pop / pop / pop rock      1
# 9                                   Country      1
# 10                    Hip-hop / R&B / dance      1
# 11         J-pop / pop / dance / electronic      1
# 12                     R&B / soul / hip-hop      1
# 13                Grunge / alternative rock      1
# 14                                 Pop rock      1
# 15  Punk rock / pop punk / alternative rock      1

# %%
artist_year_1990.columns = ['Genre','count']

# %%
artist_year_1990
# Out:
#                                       Genre  count
# 0                                   Hip-hop      4
# 1                R&B / pop / soul / hip-hop      1
# 2         Alternative rock / pop rock / pop      1
# 3                   Pop / dance / dance-pop      1
# 4                               Country pop      1
# 5                                       Pop      1
# 6                          R&B / pop / rock      1
# 7                                 R&B / pop      1
# 8                Latin pop / pop / pop rock      1
# 9                                   Country      1
# 10                    Hip-hop / R&B / dance      1
# 11         J-pop / pop / dance / electronic      1
# 12                     R&B / soul / hip-hop      1
# 13                Grunge / alternative rock      1
# 14                                 Pop rock      1
# 15  Punk rock / pop punk / alternative rock      1

# %%
plt.xticks(rotation = -70)
sns.barplot(x='Genre',y='count',data=artist_year_1990)
plt.show()

# %% [markdown]
# => 1990년대에 가장 인기있었던 장르는 Hip-hop이다

# %% [markdown]
# 2000년 이후

# %%
artist_year_2000 = artist.loc[(artist['Year'] >= 2000)]

artist_year_2000.head()
# Out:
#           Artist        Country period_active  Year  \
# 7        Rihanna       Barbados  2005–present  2005
# 11  Taylor Swift  United States  2006–present  2006
# 12       Beyoncé  United States  1997–present  2002
# 18         Drake         Canada  2001–present  2009
# 20    Kanye West  United States  1996–present  2003
#
#                                         Genre          TCU  Debut  \
# 7                 R&B / pop / dance / hip-hop  335300000.0   2005
# 11  Pop / country / rock / folk / alternative  250400000.0   2006
# 12                                  R&B / pop  226500000.0   1997
# 18                        Hip-hop / R&B / pop  413060000.0   2001
# 20                 Hip-hop / electronic / pop  258300000.0   1996
#
#     Cart_In_period
# 7                0
# 11               0
# 12               5
# 18               8
# 20               7

# %%
artist_year_2000 = pd.DataFrame(artist_year_2000['Genre'].value_counts())

artist_year_2000
# Out:
#                                            Genre
# Hip-hop / R&B / pop                            2
# Pop / R&B                                      2
# Pop / R&B / hip-hop                            2
# R&B / pop / dance / hip-hop                    1
# Pop / soul                                     1
# Pop rock / electropop / pop                    1
# Hip-hop / hip house /EDM                       1
# Pop / R&B / neo soul                           1
# Pop / pop rock / R&B                           1
# Alternative rock / nu metal / rap rock         1
# Hip-hop / pop                                  1
# Pop / dance / electronic                       1
# Pop rock / funk rock / dance-pop               1
# Pop / country / rock / folk / alternative      1
# Pop                                            1
# Pop rock / R&B                                 1
# Pop / folk pop                                 1
# Pop / teen pop / dance pop                     1
# Hip-hop / electronic / pop                     1
# R&B / pop                                      1
# Country / country pop                          1

# %%
artist_year_2000.reset_index(inplace=True)

# %%
artist_year_2000
# Out:
#                                         index  Genre
# 0                         Hip-hop / R&B / pop      2
# 1                                   Pop / R&B      2
# 2                         Pop / R&B / hip-hop      2
# 3                 R&B / pop / dance / hip-hop      1
# 4                                  Pop / soul      1
# 5                 Pop rock / electropop / pop      1
# 6                    Hip-hop / hip house /EDM      1
# 7                        Pop / R&B / neo soul      1
# 8                        Pop / pop rock / R&B      1
# 9      Alternative rock / nu metal / rap rock      1
# 10                              Hip-hop / pop      1
# 11                   Pop / dance / electronic      1
# 12           Pop rock / funk rock / dance-pop      1
# 13  Pop / country / rock / folk / alternative      1
# 14                                        Pop      1
# 15                             Pop rock / R&B      1
# 16                             Pop / folk pop      1
# 17                 Pop / teen pop / dance pop      1
# 18                 Hip-hop / electronic / pop      1
# 19                                  R&B / pop      1
# 20                      Country / country pop      1

# %%
artist_year_2000.columns = ['Genre','count']

artist_year_2000
# Out:
#                                         Genre  count
# 0                         Hip-hop / R&B / pop      2
# 1                                   Pop / R&B      2
# 2                         Pop / R&B / hip-hop      2
# 3                 R&B / pop / dance / hip-hop      1
# 4                                  Pop / soul      1
# 5                 Pop rock / electropop / pop      1
# 6                    Hip-hop / hip house /EDM      1
# 7                        Pop / R&B / neo soul      1
# 8                        Pop / pop rock / R&B      1
# 9      Alternative rock / nu metal / rap rock      1
# 10                              Hip-hop / pop      1
# 11                   Pop / dance / electronic      1
# 12           Pop rock / funk rock / dance-pop      1
# 13  Pop / country / rock / folk / alternative      1
# 14                                        Pop      1
# 15                             Pop rock / R&B      1
# 16                             Pop / folk pop      1
# 17                 Pop / teen pop / dance pop      1
# 18                 Hip-hop / electronic / pop      1
# 19                                  R&B / pop      1
# 20                      Country / country pop      1

# %%
plt.xticks(rotation = -70)
sns.barplot(x='Genre',y='count',data=artist_year_1990)
plt.show()

# %% [markdown]
# => 2000년대 이후는 Hip-hop / R&B / pop , Pop / R&B ...
# 힙합과 알앤비 장르가 인기있는 장르이다.

# %%
artist.loc[artist['Country']=='United Kingdom United States','Country']='United Kingdom'

# %%
country_aritst=pd.DataFrame(artist.groupby('Country')['Artist'].count())
country_aritst.sort_values('Artist',ascending=0)
# Out:
#                                     Artist
# Country
# United States                           79
# United Kingdom                          21
# Canada                                   5
# Australia                                2
# Ireland                                  2
# Japan                                    2
# Barbados                                 1
# CanadaUnited States                      1
# Colombia                                 1
# France                                   1
# Jamaica                                  1
# Spain                                    1
# Sweden                                   1
# Trinidad and Tobago                      1
# United Kingdom Australia[238][239]       1
# United StatesUnited Kingdom              1

# %%
artist.loc[artist['Country']=='CanadaUnited States','Country']='Canada'

# %%
artist.loc[artist['Country']=='United StatesUnited Kingdom','Country']='United States'

# %%
artist.loc[artist['Country']=='United Kingdom Australia[238][239]','Country']='Australia'

# %%
artist['Country'].unique()
# Out:
# array(['United Kingdom', 'United States', 'Barbados', 'Canada',
#        'Australia', 'Ireland', 'Sweden', 'Trinidad and Tobago', 'Japan',
#        'Spain', 'Colombia', 'France', 'Jamaica'], dtype=object)

# %% [markdown]
# #### => 2인이상 가수는 'country'가 멤버별 국적이 기재되므로 그룹이 만들어진 나라로 'country'를 하나로 통합하였다

# %% [markdown]
# ### 2020년 현재까지 노래를 낸 아티스트 추출하고 장르 분석

# %%
artist['Until']=artist.period_active.str.split('–').str[-1]

# %%
# if artist.Until.str.contains('-'):
#     artist['Until']=artist.period_active.str.split('-').str[-1]

# %%
artist['Until']=artist['Until'].str.replace('present','2022')

# %%
artist['Until'].head()
# Out:
# 0    1970
# 1    1977
# 2    2009
# 3    2022
# 4    2022
# Name: Until, dtype: object

# %%
present_artist=artist[artist['Until']=='2022']
present_artist['Genre'].value_counts()
# Out:
# Rock                                 7
# Rock / pop                           4
# Pop / rock                           3
# R&B / pop                            3
# Pop                                  3
#                                     ..
# Hard rock / glam metal               1
# Hip-hop / pop                        1
# Alternative rock / pop rock / pop    1
# Pop / pop rock / R&B                 1
# Pop / soft rock                      1
# Name: Genre, Length: 64, dtype: int64

# %%
#artist.groupby('Country')['Artist','Genre'].count()

# %%
Genre=artist['Genre'].str.split("/")

# %%
genre_list=[]
for genres in Genre:
    for genre in genres:
        if genre.strip().lower() not in genre_list:
            genre_list.append(genre.strip().lower())
genre_list
# Out:
# ['rock',
#  'pop',
#  'rock and roll',
#  'country',
#  'dance',
#  'soul',
#  'r&b',
#  'electronica',
#  'hard rock',
#  'blues rock',
#  'folk rock',
#  'hip-hop',
#  'progressive rock',
#  'psychedelic rock',
#  'folk',
#  'alternative',
#  'gospel',
#  'electronic',
#  'teen pop',
#  'dance pop',
#  'folk pop',
#  'pop rock',
#  'adult contemporary',
#  'disco',
#  'swing',
#  'easy listening',
#  'heavy metal',
#  'thrash metal',
#  'funk rock',
#  'dance-pop',
#  'alternative rock',
#  'glam metal',
#  'nu metal',
#  'rap rock',
#  'country pop',
#  'blues',
#  'funk',
#  'soft rock',
#  'latin',
#  'art rock',
#  'glam rock',
#  'surf rock',
#  'neo soul',
#  'hip house',
#  'edm',
#  'latin pop',
#  'j-pop',
#  'electropop',
#  'grunge',
#  'smooth jazz',
#  'punk rock',
#  'pop punk',
#  'new-age',
#  'celtic',
#  'reggae',
#  'jazz']

# %%
present_artist.head(11)
# Out:
#           Artist         Country            period_active  Year  \
# 3     Elton John  United Kingdom             1964–present  1970
# 4          Queen  United Kingdom             1971–present  1973
# 5        Madonna   United States             1979–present  1983
# 7        Rihanna        Barbados             2005–present  2005
# 9         Eminem   United States             1996–present  1999
# 10  Mariah Carey   United States             1988–present  1990
# 11  Taylor Swift   United States             2006–present  2006
# 12       Beyoncé   United States             1997–present  2002
# 14        Eagles   United States  1971–1980, 1994–present  1972
# 15   Celine Dion          Canada             1981–present  1981
# 16         AC/DC       Australia             1973–present  1975
#
#                                         Genre          TCU  Debut  \
# 3                                  Pop / rock  208000000.0   1964
# 4                                        Rock  184000000.0   1971
# 5                   Pop / dance / electronica  181700000.0   1979
# 7                 R&B / pop / dance / hip-hop  335300000.0   2005
# 9                                     Hip-hop  325700000.0   1996
# 10                 R&B / pop / soul / hip-hop  205800000.0   1988
# 11  Pop / country / rock / folk / alternative  250400000.0   2006
# 12                                  R&B / pop  226500000.0   1997
# 14                                       Rock  152200000.0   1971
# 15                                 Pop / Rock  143000000.0   1981
# 16     Hard rock / blues rock / rock and roll  130200000.0   1973
#
#     Cart_In_period Until
# 3                6  2022
# 4                2  2022
# 5                4  2022
# 7                0  2022
# 9                3  2022
# 10               2  2022
# 11               0  2022
# 12               5  2022
# 14               1  2022
# 15               0  2022
# 16               2  2022

# %% [markdown]
# ### 장르별 'TCU' 평균을 구하여 인기있는 장르를 분석

# %%
df=pd.DataFrame(index=['mean'])
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [mean]

# %%
for genre in genre_list:
     df[genre]= present_artist.loc[present_artist['Genre'].str.contains(genre,case=0),'TCU'].mean()

# %%
favorite_genre = df.T.sort_values(by='mean',ascending=0).head(5)

favorite_genre
# Out:
#                      mean
# teen pop     2.779000e+08
# folk pop     2.467000e+08
# hip-hop      2.051508e+08
# electronica  1.817000e+08
# electronic   1.658750e+08

# %%
favorite_genre.reset_index(inplace = True)

# %%
favorite_genre
# Out:
#          index          mean
# 0     teen pop  2.779000e+08
# 1     folk pop  2.467000e+08
# 2      hip-hop  2.051508e+08
# 3  electronica  1.817000e+08
# 4   electronic  1.658750e+08

# %%
favorite_genre.columns = ['Genre','mean']

# %%
favorite_genre
# Out:
#          Genre          mean
# 0     teen pop  2.779000e+08
# 1     folk pop  2.467000e+08
# 2      hip-hop  2.051508e+08
# 3  electronica  1.817000e+08
# 4   electronic  1.658750e+08

# %%
sns.barplot(data = favorite_genre, x = 'Genre', y = 'mean')

plt.show()

# %% [markdown]
# #### => 현재까지 활동하고 있는 가수 중 사랑받는 장르는 teen pop, folk pop순이다
