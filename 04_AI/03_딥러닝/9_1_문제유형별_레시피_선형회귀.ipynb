# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='adam', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 1ms/step - loss: 1.3725
# Epoch 2/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6829
# Epoch 3/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1759
# Epoch 4/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0471
# Epoch 5/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0401
# Epoch 6/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0324
# Epoch 7/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 8/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0221
# Epoch 9/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 10/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0149
# Epoch 11/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0128
# Epoch 12/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0113
# Epoch 13/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0104
# Epoch 14/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0099
# Epoch 15/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 16/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 17/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 18/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 19/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 20/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 21/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 22/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 23/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 24/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 25/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 26/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 27/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 28/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 29/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 30/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 31/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 32/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 33/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 34/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 35/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 36/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 37/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 38/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 39/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 40/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 41/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 42/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 43/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 44/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 45/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 46/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 47/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 48/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 49/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 50/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0101
# loss : 0.010110396891832352
