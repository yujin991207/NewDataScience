# %%
# pip install selenium
# pip install webdriver_manager

# %% [markdown]
# ### 크롬 브라우저 드라이버 설치

# %% [markdown]
# https://sites.google.com/a/chromium.org/chromedriver/downloads

# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from bs4 import BeautifulSoup
import os

# %%
url = 'https://finance.daum.net/domestic'

# %%
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver = webdriver.Chrome(service=Service('D:\\util\\chromedriver.exe'))
# driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# driver => 가상의 크롬 브라우저 시뮬레이터
driver.maximize_window()
# 3초간 대기 (가상의 크롬브라우저 로딩 시간)
driver.implicitly_wait(3) 

    # URL 접근
driver.get(url)
# 페이지 로딩 시간을 고려하여 3초로 설정
driver.implicitly_wait(3) 
# request에 대한 html 응답을 스트링으로 반환
html = driver.page_source

print(html)
# 가상의 크롬 브라우저를 종료
driver.close()
# Out:
# <html lang="ko"><head><script id="adfitScript" src="//t1.daumcdn.net/kas/static/ba.min.js"></script>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta property="og:site_name" content="다음금융">
# <meta property="og:image" content="https://t1.daumcdn.net/media/finance_og.png">
# <link rel="shortcut icon" href="//finance.daum.net/favicon.ico" type="image/x-icon">
#
# <title>국내증시 | 다음 금융 </title>
#
# <link rel="stylesheet" type="text/css" href="/dist/common.css?v=1668997547">
# <link rel="stylesheet" type="text/css" href="/dist/custom.ui.css?v=1668997547">
#
# <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script>
#     window.REQUEST_URI = '/domestic';
#     window.CURRENT_URL = encodeURIComponent(
#         "".concat(
#             window.location.protocol,
#             "//",
#             window.location.host,
#             window.location.pathname,
#             window.location.search
#         )
#     );
#     window.FINANCE = {};
#     window.FINANCE.BASE_URL = '/dist';
#     window.FINANCE.VERSION = '1668997547';
#     window.FINANCE.API_URL = '';
#     window.FINANCE.HOST = '//finance.daum.net';
#     window._REALTIME_HOST = 'wss://realtime.finance.daum.net/websocket';
#     window._WISE_FN_HOST = '//wisefn.finance.daum.net/v1';
#     window._PERIOD = '';
# </script>
#
# <script type="text/javascript" src="/dist/requirejs/require.js?v=1668997547"></script>
# <script type="text/javascript" src="/dist/@sentry/browser/build/bundle.min.js?v=1668997547"></script>
# <script>
#     Sentry.init({ dsn: 'https://ae642cd9f70641159b266094f9cbc4ca@aem-collector.daumkakao.io/2536' });
# </script>
#
# <script type="text/javascript" src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>
#
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-128578811-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-128578811-1');
# </script>
#
# <!--[if lt IE 9]> <script type="text/javascript" src="/dist/html5.js?v=1668997547"></script> <![endif]-->
#
# <script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="/dist/daum/app/config.js?v=1668997547" src="/dist/daum/app/config.js?v=1668997547"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="app/common/mini_daum" src="/dist/daum/./app/common/mini_daum.js?v=1668997547"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="app/common/search" src="/dist/daum/./app/common/search.js?v=1668997547"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="app/domestic/index" src="/dist/daum/./app/domestic/index.js?v=1668997547"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="app/common/tiara" src="/dist/daum/./app/common/tiara.js?v=1668997547"></script><script type="text/javascript" async="" src="//go.daum.net/minidaum_pc.daum"></script><script type="text/javascript" charset="utf-8" async="" src="https://t1.daumcdn.net/daumtop_deco/scripts/minidaum/pc/minidaum_pc-0cf3325.min.js"></script><style type="text/css">.adfit__tag-button{-webkit-tap-highlight-color:transparent;-webkit-box-direction:normal;-webkit-font-feature-settings:"tnum";font-feature-settings:"tnum";border:1px solid transparent;border-radius:2px;-webkit-box-sizing:border-box;box-sizing:border-box;color:#fff;display:inline-block;font-family:sans-serif;font-size:10px;font-variant:tabular-nums;height:auto;letter-spacing:0;line-height:18px;list-style:none;margin:4px 4px 0 0;opacity:.9;padding:0 7px;white-space:nowrap}.adfit__tag-button,.adfit__tag-button--yellow{background-color:#fa8c16}.adfit__tag-button--purple{background-color:#722ed1}.adfit__tag-button--blue{background-color:#108ee9}.adfit__tag-button--orange{background-color:#f50}.adfit__tag-button--green{background-color:#8bc34a}</style><style type="text/css">.adfit__debug-toolbar{position:absolute;z-index:9999999}.adfit__debug-toolbar--top{right:0;top:0}.adfit__debug-toolbar--bottom{bottom:4px;right:0}</style><style type="text/css">.adfit__border{position:absolute}.adfit__border--left{height:100%;left:0;top:0;width:1px}.adfit__border--right{height:100%;right:0;top:0;width:1px}.adfit__border--top{height:1px;left:0;top:0;width:100%}.adfit__border--bottom{bottom:0;height:1px;left:0;width:100%}</style><style type="text/css">.adfit__swipeable{height:100%;left:0;position:absolute;top:0;width:100%;z-index:999999}</style><style type="text/css">.adfit__a11y-layer{pointer-events:none}.adfit__a11y-layer__hint{background-image:url("data:image/png;base64,...");background-position:50%;background-repeat:no-repeat;background-size:158px 58px;height:100%;left:0;position:absolute;top:0;width:100%}</style><style type="text/css">.adfit__html-banner{max-height:inherit;overflow:hidden;position:relative}.adfit__html-banner__inner{border:0;display:block;margin:0 auto;overflow:hidden}.adfit__html-banner--responsive>.adfit__html-banner__inner{height:0}.adfit__html-banner--responsive>.adfit__html-banner__inner iframe{height:100%;left:0;max-height:inherit;position:absolute;top:0;width:100%}</style><style>/* minidaum common */
# #wrapMinidaum{z-index:999999;height:40px;font-size:12px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,'돋움',dotum,sans-serif;color:#222;text-align:left}
# #minidaum ol, #minidaum ul, #minidaum li{list-style:none}
# #minidaum img, #minidaum fieldset{border:0;padding:0}
# #minidaum img{vertical-align:top}
# #minidaum p{margin:0;padding:0}
# #minidaum a{font-family:AppleSDGothicNeo-Regular,'돋움',dotum,sans-serif;color:#222;text-decoration:none}
# #minidaum a:active, #minidaum a:hover{text-decoration:underline}
# #minidaum em{font-style:normal}
# #wrapMinidaum .screen_out{display:block;overflow:hidden;position:absolute;left:-9999px;width:1px;height:1px;font-size:0;line-height:0;text-indent:-9999px}
# #wrapMinidaum .hide{display:none}
# #minidaum{position:absolute;top:0;left:0;width:100%;height:40px;letter-spacing:-1px}
# #minidaum .img_minidaum{display:block;overflow:hidden;font-size:0;line-height:0;background:url(https://t1.daumcdn.net/daumtop_deco/images/common/minidaum/minidaum_v5.png) no-repeat;text-indent:-9999px}
# #minidaum .minidaum_gnb{float:right;margin-right:-3px;padding-top:8px}
# #minidaum .minidaum_logo{display:inline;float:left;margin:11px 12px 0 0}
# #minidaum .minidaum_logo .img_logo{display:block;overflow:hidden;width:42px;height:17px;background:url(https://t1.daumcdn.net/daumtop_deco/images/common/minidaum/minidaum_v5.png) no-repeat;text-indent:-9999px}
# .minidaum_rank_list{background:url(https://t1.daumcdn.net/daumtop_deco/images/common/minidaum/minidaum_v5.png) no-repeat 0 -200px}
# .minidaum_rank_list .minidaum_word{float:left;white-space:nowrap}
# .minidaum_rank_list .minidaum_num{font-size:12px;line-height:14px;color:#666;letter-spacing:0}
# .minidaum_rank_list .minidaum_status{float:left;overflow:hidden;width:8px;height:10px;font-size:0;background:url(https://t1.daumcdn.net/daumtop_deco/images/common/minidaum/minidaum_v5.png) no-repeat -100% 0;text-indent:-3000px}
# .minidaum_rank_list .minidaum_up{margin-top:3px;background-position:0 -80px}
# .minidaum_rank_list .minidaum_down{margin-top:2px;background-position:-10px -80px}
# .minidaum_rank_list .minidaum_keep{height:1px;margin-top:5px;background-position:-20px -80px}
# .minidaum_rank_list .minidaum_new{width:25px;margin-top:2px;background-position:-30px -80px}
# .minidaum_rank_list .minidaum_dummy{background:url(https://t1.daumcdn.net/daumtop_deco/images/common/minidaum/minidaum_v5.png) no-repeat 0 -490px}
# #minidaumRank{float:left;position:relative;margin-top:13px;height:19px}
# #minidaumRank .minidaum_rankroll{overflow:hidden;width:191px;height:19px;font-size:12px;line-height:14px;letter-spacing:-1px}
# #minidaumRank .minidaum_rank_list{float:left;width:191px;background-position:0 -490px}
# #minidaumRank .minidaum_rank_list li{height:23px}
# #minidaumRank .minidaum_rank_list .minidaum_word{padding:1px 6px 0 18px}
# #minidaumRank .minidaum_rank_list .minidaum_num{display:inline;float:left;margin:1px 0 0 2px}
# #minidaumRank .minidaum_rank_list .minidaum_up{margin-top:2px}
# #minidaumRank .minidaum_rank_list .minidaum_down{margin-top:1px}
# #minidaumRank .minidaum_rank_list .minidaum_keep{margin-top:6px}
# #minidaumUser{float:left}
# #minidaumUser .minidaum_profile{display:block;overflow:hidden}
# #minidaumUser .minidaum_login{display:block;width:50px;height:22px;border:1px solid #E4E4E4;font-size:12px;line-height:24px;color:#666;text-align:center}
# #minidaumUser .minidaum_login:hover{text-decoration:none}
# #minidaumUser .minidaum_nick{display:block}
# #minidaumUser .minidaum_nick .minidaum_profile{position:relative;width:24px;height:24px}
# #minidaumService{float:left}
# #minidaumService .dsvc_util{display:inline;float:left;margin-left:24px}
# #minidaumService .minidaum_mail{display:block;position:relative;width:24px;height:24px}
# #minidaumService .minidaum_mail .ico_dsvc_mail{width:24px;height:24px;background-position:0 -20px}
# #minidaumService .minidaum_mail:hover .ico_dsvc_mail{background-position:-60px -20px}
# #minidaumService .ico_dsvc_alarm{position:absolute;top:-1px;right:-3px;width:10px;height:10px;background-position:-90px -80px;pointer-events:none}
# #minidaumService .minidaum_count{display:none;position:absolute;top:-3px;left:12px}
# #minidaumService #minidaumMailCnt{display:block;min-width:15px;width:auto;height:auto;padding:3px 2px 1px 1px;border-radius:8px;font-style:normal;font-weight:600;font-size:11px;line-height:10px;color:#fff;background-color:#118EFF;text-align:center;letter-spacing:0;text-decoration:none}
# #minidaumService #minidaumMailCnt.mailcnt2{min-width:21px;padding-right:1px;padding-left:2px}
# #minidaumService #minidaumMailCnt:empty{display:none}
# #minidaumService .minidaum_sitemap{display:block;width:24px;height:24px}
# #minidaumService .ico_dsvc_sitemap{width:24px;height:24px;background-position:-30px -20px}
# #minidaumService .minidaum_sitemap:hover .ico_dsvc_sitemap:hover{background-position:-90px -20px}
#
# #minidaum .minidaum_layer{display:none;position:absolute;top:34px;padding-top:5px}
# #minidaum .minidaum_layer .ico_arrow{position:absolute;top:0;width:10px;height:6px;background-position:-60px -80px}
# #minidaum .inner_minidaum_layer{overflow:hidden;border:1px solid #CDCDCD;border-radius:1px;background-color:#fff}
# #minidaum .minidaumlayer_open{display:block}
# #minidaumRankLayer{left:0;width:222px}
# #minidaumRankLayer .ico_arrow{left:57px}
# #minidaumRankLayer .inner_minidaum_layer{height:342px;padding:0 20px 0 19px}
# #minidaumRankLayer .minidaum_rank_tit{display:block;height:30px;margin:20px 0 0 2px;font-weight:bold;font-size:14px}
# #minidaumRankLayer li{overflow:hidden;height:23px;margin-top:5px;font-size:13px;line-height:14px}
# #minidaumRankLayer .minidaum_word{width:133px;padding:1px 0 0 18px}
# #minidaumRankLayer .minidaum_dummy{display:none}
# #minidaumRankLayer .minidaum_num{float:right;width:21px;margin-top:2px;text-align:right}
# #minidaumRankLayer .minidaum_select .minidaum_word{font-weight:bold;letter-spacing:-1px}
# #minidaumRankLayer .minidaum_keep{display:inline;float:right;margin:8px 1px 0 0}
# #minidaumRankLayer .minidaum_new{float:right;margin-top:2px}
# #minidaumMoreLayer{right:0;width:312px}
# #minidaumMoreLayer .ico_arrow{right:4px}
# #minidaumMoreLayer .minidaum_idx{display:none}
# #minidaumMoreLayer .minidaum_list_dsvc{overflow:hidden;padding:23px 0 0 2px}
# #minidaumMoreLayer .minidaum_list_dsvc li{float:left;width:74px;height:74px;margin-right:1px;text-align:center}
# #minidaumMoreLayer .minidaum_list_dsvc a{display:block}
# #minidaumMoreLayer .minidaum_list_dsvc img{vertical-align:top}
# #minidaumMoreLayer .dsvc_thumb{display:block;overflow:hidden;width:36px;height:36px;margin:0 auto}
# #minidaumMoreLayer .dsvc_txt{display:block;margin-top:6px;font-weight:bold;font-size:13px}
# #minidaumMoreLayer .minidaum_listbox{display:table;overflow:hidden;position:relative;width:100%;padding:18px 0 58px;border-top:1px solid #F2F2F2}
# #minidaumMoreLayer .minidaum_list_group{display:table-cell;width:72px;border-left:1px solid #F2F2F2}
# #minidaumMoreLayer .minidaum_list_group li{margin-bottom:-2px;padding:13px 0 0 10px;font-size:13px;line-height:15px}
# #minidaumMoreLayer .minidaum_list_group li:first-child{padding-top:0}
# #minidaumMoreLayer .minidaum_list_group .minidaum_all{position:absolute;left:0;bottom:0;width:100%;margin:0;padding:14px 0 11px;border-top:1px solid #F2F2F2;font-size:12px;line-height:14px;color:#222;background-color:#FBFBFB;text-align:center;text-decoration:none}
# #minidaumMoreLayer .minidaum_list_group1{width:69px;padding-left:12px;border-left:0 none}
# #minidaumMoreLayer .minidaum_list_group4{width:auto}
# #minidaumMailLayer{right:0;width:312px}
# #minidaumMailLayer .ico_arrow{right:52px}
# #minidaumMailLayer .inner_minidaum_layer{height:238px;text-align:center}
# #minidaumMailLayer .ico_dsvc_notify{width:70px;height:64px;margin:37px auto 0;padding-left:10px;background-position:10px -130px}
# #minidaumMailLayer .minidaum_notify{margin:11px 0 17px;font-size:13px;line-height:22px;color:#666}
# #minidaumMailLayer .minidaum_notify em{font-size:14px;color:#222}
# #minidaumMailLayer .minidaum_account{display:block;width:138px;margin:0 auto;padding:10px 0 8px;border:1px solid #CDCDCD;border-radius:2px;line-height:1;color:#666;text-align:center;text-decoration:none}
# #minidaumUserLayer{right:0}
# #minidaumUserLayer .ico_arrow{right:100px}
# #minidaumUserLayer .inner_minidaum_layer{width:310px;height:138px}
# #minidaumUserLayer .minidaum_mysvc{overflow:hidden;border-top:1px solid #eee;background-color:#FBFBFB}
# #minidaumUserLayer .minidaum_mysvc li{float:left;width:33.3333%;padding:12px 0 11px;line-height:13px;text-align:center}
# #minidaumUserLayer .minidaum_mysvc li:before{float:left;width:1px;height:13px;margin-left:-1px;background-color:#eee;content:''}
# #minidaumUserLayer .minidaum_logout{position:absolute;top:73px;left:103px;color:#888;text-decoration:underline;letter-spacing:-1px}
# #minidaumUserLayer .minidaum_myinfo{height:84px;padding:17px 0 0 20px}
# #minidaumUserLayer .minidaum_myprof{float:left;position:relative;max-width:190px;margin-top:3px;padding-left:82px;vertical-align:top}
# #minidaumUserLayer .minidaum_ssoing .minidaum_myprof{max-width:122px}
# #minidaumUserLayer .minidaum_profile{position:absolute;top:-1px;left:1px;width:66px;height:66px}
# #minidaumUserLayer .minidaum_user{display:block;overflow:hidden;padding-right:1px;font-weight:bold;font-size:15px;line-height:19px;letter-spacing:-1px;white-space:nowrap;text-overflow:ellipsis}
# #minidaumUserLayer .minidaum_account{overflow:hidden;position:absolute;top:25px;left:82px;max-width:204px;font-size:13px;line-height:15px;color:#666;letter-spacing:0;white-space:nowrap;text-overflow:ellipsis}
# #minidaumUserLayer .minidaum_sso{display:inline-block;width:70px;height:22px;margin-left:5px;background-position:0 -100px;vertical-align:top}
# #minidaumUserLayer .minidaum_kakaoid{position:absolute;top:44px;left:46px;width:24px;height:24px;background-position:-80px -100px}
#
# /* 플래시가 미니다음 레이어들을 가릴 때 */
# #minidaum .minidaum_shield{position:absolute;top:0;left:0;z-index:-1}
# #minidaum .minidaumlayer_open .minidaum_shield{border:1px solid #fff}
#
# /* 레티나 대응 이미지 */
# @media
# only screen and (-webkit-min-device-pixel-ratio: 1.5),
# only screen and (min-device-pixel-ratio: 1.5),
# only screen and (min-resolution: 144dpi),
# only screen and (min-resolution: 1.5dppx){
#     #minidaum .img_minidaum,#minidaum .minidaum_logo .img_logo,.minidaum_rank_list,.minidaum_rank_list .minidaum_dummy,.minidaum_rank_list .minidaum_status{background-image:url(https://t1.daumcdn.net/daumtop_deco/images/common/minidaum/rtn/minidaum_v5.png);background-size:120px 960px}
# }</style></head>
# <body class="finance">
#     <div id="wrap">
#         <div id="kakaoWrap">
#     <div id="wrapMinidaum"><div id="minidaum"><strong class="minidaum_logo"><a href="https://www.daum.net/?nil_profile=mini&amp;nil_src=daum" target="_top" class="img_logo minidaum_tiara_click" data-tiara-layer="minidaum logo" data-tiara-action-name="미니다음_로고">Daum</a></strong><div class="minidaum_gnb"><h2 class="screen_out">서비스 바로가기</h2><div id="minidaumUser"><a href="https://logins.daum.net/accounts/loginform.do?url=https%3A%2F%2Ffinance.daum.net%2Fdomestic" target="_top" id="btnMinidaumLogin" class="minidaum_login minidaum_tiara_click" data-tiara-layer="minidaum login" data-tiara-action-name="미니다음_로고">로그인</a></div><div id="minidaumService"><div class="dsvc_util"><a href="https://mail.daum.net/?nil_profile=mini&amp;nil_src=mail" id="minidaumMail" class="minidaum_mail minidaum_tiara_click" data-tiara-layer="minidaum mail" data-tiara-action-name="미니다음_메일"><span class="img_minidaum ico_dsvc_mail">메일</span><em class="minidaum_count" id="minidaumMailCntWrapper"><span class="screen_out">받은메일수</span><span id="minidaumMailCnt"></span></em></a><div id="minidaumMailLayer" class="minidaum_layer"><span class="img_minidaum ico_arrow"></span><div class="inner_minidaum_layer"><span class="img_minidaum ico_dsvc_notify"></span><p class="minidaum_notify"><em>메일함이 없습니다</em><br>메일함 생성을 위해선 Daum아이디가 필요합니다</p><a href="https://accounts.daum.net/mail/create" class="minidaum_account">Daum아이디 만들기</a></div></div></div><div class="dsvc_util"><a href="http://www.daum.net/doc/sitemap/?nil_profile=mini&amp;nil_src=sitemap" target="_top" class="minidaum_sitemap" role="button" aria-expanded="false" id="minidaumMore"><span class="img_minidaum ico_dsvc_sitemap">Daum 미니 사이트맵</span></a><div id="minidaumMoreLayer" class="minidaum_layer"><span class="img_minidaum ico_arrow"></span><div class="inner_minidaum_layer"><strong class="screen_out">주요서비스 바로가기</strong><ul class="minidaum_list_dsvc"><li><a href="https://cafe.daum.net/?nil_profile=mini&amp;nil_src=cafe" target="_top" class="minidaum_tiara_click" data-tiara-layer="minidaum site_layer cafe" data-tiara-action-name="미니다음_서비스 보기 레이어_서비스명 클릭"><span class="dsvc_thumb"><img src="//t1.daumcdn.net/daumtop_deco/images/common/minidaum/rtn/ic_cafe.png" width="36" height="36" alt=""></span><span class="dsvc_txt">카페</span></a></li><li><a href="https://news.daum.net/?nil_profile=mini&amp;nil_src=news" target="_top" class="minidaum_tiara_click" data-tiara-layer="minidaum site_layer news" data-tiara-action-name="미니다음_서비스 보기 레이어_서비스명 클릭"><img src="//t1.daumcdn.net/daumtop_deco/images/common/minidaum/rtn/ic_news.png" width="36" height="36" alt=""><span class="dsvc_txt">뉴스</span></a></li><li><a href="https://map.kakao.com/?nil_profile=mini&amp;nil_src=map" class="minidaum_tiara_click" data-tiara-layer="minidaum site_layer map" data-tiara-action-name="미니다음_서비스 보기 레이어_서비스명 클릭"><span class="dsvc_thumb"><img src="//t1.daumcdn.net/daumtop_deco/images/common/minidaum/rtn/ic_map.png" width="36" height="36" alt=""></span><span class="dsvc_txt">지도</span></a></li><li><a href="https://shoppinghow.kakao.com/top?nil_profile=mini&amp;nil_src=shophow" class="minidaum_tiara_click" data-tiara-layer="minidaum site_layer shopping" data-tiara-action-name="미니다음_서비스 보기 레이어_서비스명 클릭"><span class="dsvc_thumb"><img src="//t1.daumcdn.net/daumtop_deco/images/common/minidaum/rtn/ic_shopping.png" width="36" height="36" alt=""></span><span class="dsvc_txt">쇼핑</span></a></li></ul><div class="minidaum_listbox"><strong class="screen_out">서비스 바로가기</strong><strong class="minidaum_idx minidaum_idx1">더보기 1열</strong><ul class="minidaum_list_group minidaum_list_group1"><li><a href="https://blog.daum.net/?nil_profile=mini&amp;nil_src=blog" target="_top" data-tiara-layer="minidaum site_layer blog" data-tiara-action-name="미니다음_서비스 보기 레이어_서비스명 클릭">블로그</a></li><li><a href="https://www.tistory.com/?nil_profile=mini&amp;nil_src=tistory" target="_top" data-tiara-layer="minidaum site_layer tistory" data-tiara-action-name="미니다음_서비스 보기 레이어_서비스명 클릭">티스토리</a></li><li><a href="http ...
# </div>
#
# <script>
#     requirejs(["/dist/daum/app/config.js?v=1668997547"], function (common) {
#         require(["app/common/mini_daum"]);
#     });
# </script>
#
#
#         <div class="header">
#     <div class="head_media f_clear">
#         <h1><a href="//finance.daum.net" id="kakaoServiceLogo" class="#gnb #default #service_finance"><span class="ir_wa">금융</span></a></h1>
#         <strong class="screen_out">관련서비스</strong>
#         <ul class="kakaoRelServices">
#             <li><a href="http://realestate.daum.net"><span class="ir_wa">부동산</span></a></li>
#         </ul>
#         <h2 class="screen_out">검색</h2>
#         <div class="search_news" id="boxSearch"><form action="/quotes">
#     <fieldset>
#         <legend class="screen_out">검색어 입력폼</legend>
#         <div class="box_searchbar" id="boxSearchbar">
#             <label class="lab_search" for="">종목명, 종목코드를 입력해주세요</label>
#             <input type="text" class="tf_keyword" id="inpSearchStock" value="" maxlength="30" autocomplete="off">
#             <button class="btn_search" id="btnSearchStock"><span class="ir_wa">검색</span></button><span style="display: none" class="layerB"></span>
#
#             <!-- NOTE: 검색 제안창이 addon 됩니다. -->
#             <!-- <span class="layerB" id="boxAutoComplete" ></span> -->
#
#         </div>
#     </fieldset>
# </form>
# </div>
#
#
# <script>
#     requirejs(["/dist/daum/app/config.js?v=1668997547"], function (common) {
#         require(["app/common/search"]);
#     });
# </script>
#
#
#     </div>
#     <div id="kakaoGnb" role="navigation">
#         <div class="inner_gnb">
#             <h2 class="screen_out">금융 메인메뉴</h2>
#             <ul class="gnb_comm">
#                 <li class="">
#                     <a href="/" class="link_gnb link_gnb1">
#                         <span class="screen_out">선택됨</span>
#                         <span class="ir_wa">홈</span>
#                         <span class="bar_gnb"><span class="inner_bar"></span></span>
#                     </a>
#                 </li>
#                 <li class="on">
#                     <a href="/domestic" class="link_gnb link_gnb2">
#                         <span class="ir_wa">국내</span>
#                         <span class="bar_gnb"><span class="inner_bar"></span></span>
#                     </a>
#                 </li>
#                 <li class="">
#                     <a href="/global" class="link_gnb link_gnb3">
#                         <span class="ir_wa">해외</span>
#                         <span class="bar_gnb"><span class="inner_bar"></span></span>
#                     </a>
#                 </li>
#                 <li class="">
#                     <a href="/news" class="link_gnb link_gnb4">
#                         <span class="ir_wa">뉴스</span>
#                         <span class="bar_gnb"><span class="inner_bar"></span></span>
#                     </a>
#                 </li>
#                 <li class="">
#                     <a href="/investment" class="link_gnb link_gnb5">
#                         <span class="ir_wa">투자정보</span>
#                         <span class="bar_gnb"><span class="inner_bar"></span></span>
#                     </a>
#                 </li>
#                 <li class="">
#                     <a href="/talks" class="link_gnb link_gnb6">
#                         <span class="ir_wa">종목토론</span>
#                         <span class="bar_gnb"><span class="inner_bar"></span></span>
#                     </a>
#                 </li>
#                 <li class="">
#                     <a href="/my" class="link_gnb link_gnb8">
#                         <span class="ir_wa">MY</span>
#                         <span class="bar_gnb"><span class="inner_bar"></span></span>
#                     </a>
#                 </li>
#             </ul>
#             <div class="gnb_etc">
#                 <ul class="gnb_with">
#                     <li class="">
#                         <a href="/exchanges" class="link_gnb link_gnb1">
#                             <span class="ir_wa">환율</span>
#                             <span class="bar_gnb"><span class="inner_bar"></span></span>
#                         </a>
#                     </li>
#                 </ul>
#                 <div class="gnb_banner">
#                     <a href="https://ustockplus.onelink.me/FwJh/92a66d9b" target="_blank" class="btnKakaoStockBanner"><span class="ir_wa">IPO 전 종목을 찾고 있다면? 증권플러스 비상장</span></a>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
# <div id="notice"></div>
#
#
#
#         <div class="contents">
#             <div class="SNB" id="boxSidebar"><h3><a href="/domestic" title="국내증시">국내증시</a></h3>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="주요시세정보">주요시세정보</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/kospi" class="" title="코스피">코스피</a>
#
#             <a href="/domestic/kosdaq" class="" title="코스닥">코스닥</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/kospi200" class="" title="코스피200">코스피200</a>
#
#             <a href="/domestic/etf" class="" title="ETF">ETF</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/futures" class="" title="선물">선물</a>
#
#             <a href="/domestic/options" class="" title="옵션">옵션</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="업종별 시세">업종별 시세</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/wics" class="" title="WICS">WICS</a>
#
#             <a href="/domestic/krx100" class="" title="KRX100">KRX100</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/sectors" class="" title="전체 업종 시세">전체 업종 시세</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="종목랭킹 검색">종목랭킹 검색</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/market_cap" class="" title="시가총액별">시가총액별</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/volume" class="" title="거래량별">거래량별</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/rise_stocks" class="" title="상승률">상승률</a>
#
#             <a href="/domestic/fall_stocks" class="" title="하락률">하락률</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/after_hours" class="" title="시간외 단일가">시간외 단일가</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="거래원별 종목랭킹">거래원별 종목랭킹</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/influential_investors" class="" title="외국인/기관매매">외국인/기관매매</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/foreign_shares" class="" title="외국인 보유율 상위">외국인 보유율 상위</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/investors" class="" title="투자주체별 동향">투자주체별 동향</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/arounds" class="" title="증시주변자금동향">증시주변자금동향</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="시장감시">시장감시</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/managements" class="" title="관리종목">관리종목</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/trading_halts" class="" title="거래정지">거래정지</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/investment_alerts" class="" title="시장경보">시장경보</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="이슈/테마">이슈/테마</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/themes" class="" title="테마별 대장주">테마별 대장주</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/calendar" class="" title="증시 캘린더">증시 캘린더</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/new_listings" class="" title="신규상장">신규상장</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="기타">기타</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/unlisted" class="" title="비상장/IPO기업">비상장/IPO기업</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/exchange" class="" title="환율/원자재/금리">환율/원자재/금리</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <span>
#     <h4><a href="javascript:void(0)" class="nolink" title="한번에 보기">한번에 보기</a></h4>
#     <ul>
#
#         <li>
#
#             <a href="/domestic/all_stocks" class="" title="전종목 시세">전종목 시세</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/chart" class="" title="종합 차트 검색">종합 차트 검색</a>
#
#         </li>
#
#         <li>
#
#             <a href="/domestic/chart_slides" class="" title="차트 슬라이드">차트 슬라이드</a>
#
#         </li>
#
#     </ul>
# </span>
#
# <div class="sponsor">
#     <a href="https://ustockplus.onelink.me/FwJh/79b9e728" target="_blank" class="btnKakaoStockBanner"><img src="/images/sponsor_110_110.png" alt="유망주부터 유니콘까지 증권플러스 비상장"></a>
# </div>
# </div>
#
#
#             <div class="inner" id="boxApp">
#     <div class="topBox" id="boxDashboard"><ul class="tab box_tabs"><li class="down"><a href="javascript:void(0)" class="on ">
#     <h4>코스피 지수</h4>
#     <span>
#         <strong>2,236.40</strong>
#         <p><i>▼</i>44.05</p>
#         <p>-1.93%</p>
#     </span>
# </a>
# </li><li class="down"><a href="javascript:void(0)" class=" off">
#     <h4>코스닥 지수</h4>
#     <span>
#         <strong>679.29</strong>
#         <p><i>▼</i>13.08</p>
#         <p>-1.89%</p>
#     </span>
# </a>
# </li><li class="down"><a href="javascript:void(0)" class=" ">
#     <h4>코스피200 지수</h4>
#     <span>
#         <strong>291.10</strong>
#         <p><i>▼</i>5.99</p>
#         <p>-2.02%</p>
#     </span>
# </a>
# </li></ul>
# <div class="box box_contents"><div style="display: block;"><div class="box">
#     <div class="graphB">
#         <div class="f_clear">
#             <dl>
#                 <dt>연초</dt>
#                 <dd>2,988.77</dd>
#                 <dt>지난주</dt>
#                 <dd>2,313.69</dd>
#             </dl>
#             <p class="time"></p>
#         </div>
#         <div class="graph">
#             <a href="/domestic/kospi"><img src="https://t1.daumcdn.net/finance/chart/kr/daumcomplexindex/d/D0011001.png?t=202212301530" alt="530x160"></a>
#         </div>
#     </div>
#     <div class="txtB">
#         <dl>
#             <dt>등락종목</dt>
#             <dd class="ty01 mr"><a href="/domestic/rise_stocks?market=KOSPI&amp;change=UPPER_LIMIT">상한가<p class="up"><i>↑</i>1</p></a></dd>
#             <dd class="ty01"><a href="/domestic/fall_stocks?market=KOSPI&amp;change=LOWER_LIMIT">하한가<p class="down"><i>↓</i>0</p></a></dd>
#             <dd class="ty02 mr"><a href="/domestic/rise_stocks?market=KOSPI">상승<p class="up"><i>▲</i>111</p></a></dd>
#             <dd class="ty02"><a href="/domestic/fall_stocks?market=KOSPI">하락<p class="down"><i>▼</i>791</p></a></dd>
#         </dl>
#         <dl>
#             <dt>투자자별 매매동향</dt>
#             <dd class="mr"><a href="/domestic/investors/KOSPI">외국인<p class="down">-1,437<em>억</em></p></a></dd>
#             <dd><a href="/domestic/investors/KOSPI">개인<p class="up">+6,710<em>억</em></p></a></dd>
#             <dd class="mr"><a href="/domestic/investors/KOSPI">기관<p class="down">-5,763<em>억</em></p></a></dd>
#             <dd><a href="javascript:void(0)" class="nolink">프로그램<p class="down">-1,959<em>억</em></p></a></dd>
#         </dl>
#     </div>
# </div>
# </div><div style="display: none;"><div class="box">
#     <div class="graphB">
#         <div class="f_clear">
#             <dl>
#                 <dt>연초</dt>
#                 <dd>1,037.83</dd>
#                 <dt>지난주</dt>
#                 <dd>691.25</dd>
#             </dl>
#             <p class="time"></p>
#         </div>
#         <div class="graph">
#             <a href="/domestic/kosdaq"><img src="https://t1.daumcdn.net/finance/chart/kr/daumcomplexindex/d/E4012001.png?t=202212301530" alt="530x160"></a>
#         </div>
#     </div>
#     <div class="txtB">
#         <dl>
#             <dt>등락종목</dt>
#             <dd class="ty01 mr"><a href="/domestic/rise_stocks?market=KOSDAQ&amp;change=UPPER_LIMIT">상한가<p class="up"><i>↑</i>2</p></a></dd>
#             <dd class="ty01"><a href="/domestic/fall_stocks?market=KOSDAQ&amp;change=LOWER_LIMIT">하한가<p class="down"><i>↓</i>0</p></a></dd>
#             <dd class="ty02 mr"><a href="/domestic/rise_stocks?market=KOSDAQ">상승<p class="up"><i>▲</i>226</p></a></dd>
#             <dd class="ty02"><a href="/domestic/fall_stocks?market=KOSDAQ">하락<p class="down"><i>▼</i>1,261</p></a></dd>
#         </dl>
#         <dl>
#             <dt>투자자별 매매동향</dt>
#             <dd class="mr"><a href="/domestic/investors/KOSDAQ">외국인<p class="down">-1,387<em>억</em></p></a></dd>
#             <dd><a href="/domestic/investors/KOSDAQ">개인<p class="up">+2,009<em>억</em></p></a></dd>
#             <dd class="mr"><a href="/domestic/investors/KOSDAQ">기관<p class="down">-637<em>억</em></p></a></dd>
#             <dd><a href="javascript:void(0)" class="nolink">프로그램<p class="down">-1,679<em>억</em></p></a></dd>
#         </dl>
#     </div>
# </div>
# </div><div style="display: none;"><div class="box">
#     <div class="graphB">
#         <div class="f_clear">
#             <dl>
#                 <dt>연초</dt>
#                 <dd>395.51</dd>
#                 <dt>지난주</dt>
#                 <dd>302.07</dd>
#             </dl>
#             <p class="time"></p>
#         </div>
#         <div class="graph">
#             <a href="/domestic/kospi200"><img src="https://t1.daumcdn.net/finance/chart/kr/daumcomplexindex/d/D2011029.png?t=202212301530" alt="530x160"></a>
#         </div>
#     </div>
#     <div class="txtB">
#         <dl>
#             <dt>등락종목</dt>
#             <dd class="ty01 mr"><a href="/domestic/rise_stocks?market=KOSPI&amp;change=UPPER_LIMIT">상한가<p class="up"><i>↑</i>0</p></a></dd>
#             <dd class="ty01"><a href="/domestic/fall_stocks?market=KOSPI&amp;change=LOWER_LIMIT">하한가<p class="down"><i>↓</i>0</p></a></dd>
#             <dd class="ty02 mr"><a href="/domestic/rise_stocks?market=KOSPI">상승<p class="up"><i>▲</i>18</p></a></dd>
#             <dd class="ty02"><a href="/domestic/fall_stocks?market=KOSPI">하락<p class="down"><i>▼</i>180</p></a></dd>
#         </dl>
#         <dl>
#             <dt>투자자별 매매동향</dt>
#             <dd class="mr"><a href="/domestic/investors/KOSPI">외국인<p class="">0<em>억</em></p></a></dd>
#             <dd><a href="/domestic/investors/KOSPI">개인<p class="">0<em>억</em></p></a></dd>
#             <dd class="mr"><a href="/domestic/investors/KOSPI">기관<p class="">0<em>억</em></p></a></dd>
#             <dd><a href="javascript:void(0)" class="nolink">프로그램<p class="">0<em>억</em></p></a></dd>
#         </dl>
#     </div>
# </div>
# </div></div>
# </div>
#     <div class="leftW">
#         <div class="tableB half mr" id="boxSectorsPriceChange"><div class="tab">
#     <ul class="box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="등락률 상위업종">등락률 상위업종</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="등락률 하위업종">등락률 하위업종</a>
# </li></ul>
#
#         <a href="/domestic/sectors" class="btnMore" title="더보기">더보기</a>
#
# </div>
# <div class="box_contents"><div style="display: none;"></div><div style="display: none;"></div></div>
# </div>
#         <div class="tableB half" id="boxUpDownItems"><div class="tab">
#     <ul class="box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="상승종목">상승종목</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="하락종목">하락종목</a>
# </li></ul>
#
#         <a href="/domestic/rise_stocks" class="btnMore" title="더보기">더보기</a>
#
# </div>
# <div class="box_contents"><div style="display: block;"><table>
#     <colgroup>
#         <col width="*">
#         <col width="70">
#         <col width="*">
#         <col width="70">
#     </colgroup>
#     <thead>
#         <tr>
#             <th colspan="2">코스피</th>
#             <th colspan="2">코스닥</th>
#         </tr>
#     </thead>
#     <tbody>
#
#
#         <tr class="first">
#
#
#                 <th><a href="/quotes/A152550" class="txt">한국ANKOR유전</a></th>
#                 <td class="pR rt-KR7152550000-change-ratio"><span class="num up1">+29.91%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A363250" class="txt">진시스템</a></th>
#                 <td class="rt-KR7363250002-change-ratio"><span class="num up1">+29.97%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A251270" class="txt">넷마블</a></th>
#                 <td class="pR rt-KR7251270005-change-ratio"><span class="num up">+17.74%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A162300" class="txt">신스틸</a></th>
#                 <td class="rt-KR7162300008-change-ratio"><span class="num up1">+29.91%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A002620" class="txt">제일파마홀딩스</a></th>
#                 <td class="pR rt-KR7002620003-change-ratio"><span class="num up">+13.65%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A123010" class="txt">아이윈플러스</a></th>
#                 <td class="rt-KR7123010001-change-ratio"><span class="num up">+18.52%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A293480" class="txt">하나제약</a></th>
#                 <td class="pR rt-KR7293480000-change-ratio"><span class="num up">+7.99%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A114450" class="txt">KPX생명과학</a></th>
#                 <td class="rt-KR7114450000-change-ratio"><span class="num up">+13.38%</span></td>
#
#         </tr>
#
#         <tr class="last">
#
#
#                 <th><a href="/quotes/A006110" class="txt">삼아알미늄</a></th>
#                 <td class="pR rt-KR7006110001-change-ratio"><span class="num up">+7.81%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A053950" class="txt">경남제약</a></th>
#                 <td class="rt-KR7053950002-change-ratio"><span class="num up">+12.84%</span></td>
#
#         </tr>
#
#     </tbody>
# </table>
# </div><div style="display: none;"></div></div>
# </div>
#         <div class="tableB half mr mb" id="boxForeignNetFlow"><div class="tab">
#     <ul class="box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="외국인 순매수">외국인 순매수</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="외국인 순매도">외국인 순매도</a>
# </li></ul>
#
#         <a href="/domestic/influential_investors" class="btnMore" title="더보기">더보기</a>
#
# </div>
# <div class="box_contents"><div style="display: block;"><table>
#     <colgroup>
#         <col width="*">
#         <col width="70">
#         <col width="*">
#         <col width="70">
#     </colgroup>
#     <thead>
#         <tr>
#             <th colspan="2">코스피</th>
#             <th colspan="2">코스닥</th>
#         </tr>
#     </thead>
#     <tbody>
#
#
#         <tr class="first">
#
#
#                 <th><a href="/quotes/A252670" class="txt">KODEX 200선물인버스2X</a></th>
#                 <td class="pR rt-KR7252670005-change-ratio"><span class="num up">+3.45%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A066970" class="txt">엘앤에프</a></th>
#                 <td class="rt-KR7066970005-change-ratio"><span class="num up">+1.23%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A051910" class="txt">LG화학</a></th>
#                 <td class="pR rt-KR7051910008-change-ratio"><span class="num down">-0.33%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A247540" class="txt">에코프로비엠</a></th>
#                 <td class="rt-KR7247540008-change-ratio"><span class="num down">-0.11%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A009830" class="txt">한화솔루션</a></th>
#                 <td class="pR rt-KR7009830001-change-ratio"><span class="num down">-2.71%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A278280" class="txt">천보</a></th>
#                 <td class="rt-KR7278280003-change-ratio"><span class="num up">+1.53%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A068270" class="txt">셀트리온</a></th>
#                 <td class="pR rt-KR7068270008-change-ratio"><span class="num down">-3.02%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A035900" class="txt">JYP Ent.</a></th>
#                 <td class="rt-KR7035900000-change-ratio"><span class="num up">+1.35%</span></td>
#
#         </tr>
#
#         <tr class="last">
#
#
#                 <th><a href="/quotes/A011200" class="txt">HMM</a></th>
#                 <td class="pR rt-KR7011200003-change-ratio"><span class="num down">-2.74%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A086520" class="txt">에코프로</a></th>
#                 <td class="rt-KR7086520004-change-ratio"><span class="num down">-2.46%</span></td>
#
#         </tr>
#
#     </tbody>
# </table>
# </div><div style="display: none;"></div></div>
# </div>
#         <div class="tableB half mb" id="boxInstitutionNetFlow"><div class="tab">
#     <ul class="box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="기관 순매수">기관 순매수</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="기관 순매도">기관 순매도</a>
# </li></ul>
#
#         <a href="/domestic/influential_investors?investorType=institution" class="btnMore" title="더보기">더보기</a>
#
# </div>
# <div class="box_contents"><div style="display: block;"><table>
#     <colgroup>
#         <col width="*">
#         <col width="70">
#         <col width="*">
#         <col width="70">
#     </colgroup>
#     <thead>
#         <tr>
#             <th colspan="2">코스피</th>
#             <th colspan="2">코스닥</th>
#         </tr>
#     </thead>
#     <tbody>
#
#
#         <tr class="first">
#
#
#                 <th><a href="/quotes/A252670" class="txt">KODEX 200선물인버스2X</a></th>
#                 <td class="pR rt-KR7252670005-change-ratio"><span class="num up">+3.45%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A194480" class="txt">데브시스터즈</a></th>
#                 <td class="rt-KR7194480000-change-ratio"><span class="num up">+10.04%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A114800" class="txt">KODEX 인버스</a></th>
#                 <td class="pR rt-KR7114800006-change-ratio"><span class="num up">+1.86%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A066970" class="txt">엘앤에프</a></th>
#                 <td class="rt-KR7066970005-change-ratio"><span class="num up">+1.23%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A251340" class="txt">KODEX 코스닥150선물인버스</a></th>
#                 <td class="pR rt-KR7251340006-change-ratio"><span class="num up">+1.83%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A035760" class="txt">CJ ENM</a></th>
#                 <td class="rt-KR7035760008-change-ratio"><span class="num up">+2.65%</span></td>
#
#         </tr>
#
#         <tr class="">
#
#
#                 <th><a href="/quotes/A012450" class="txt">한화에어로스페이스</a></th>
#                 <td class="pR rt-KR7012450003-change-ratio"><span class="num up">+0.96%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A293490" class="txt">카카오게임즈</a></th>
#                 <td class="rt-KR7293490009-change-ratio"><span class="num up">+5.81%</span></td>
#
#         </tr>
#
#         <tr class="last">
#
#
#                 <th><a href="/quotes/A042670" class="txt">현대두산인프라코어</a></th>
#                 <td class="pR rt-KR7042670000-change-ratio"><span class="num down">-3.26%</span></td>
#
#
#
#
#                 <th class="pL"><a href="/quotes/A041510" class="txt">에스엠</a></th>
#                 <td class="rt-KR7041510009-change-ratio"><span class="num up">+0.92%</span></td>
#
#         </tr>
#
#     </tbody>
# </table>
# </div><div style="display: none;"></div></div>
# </div>
#         <div class="AdvertB borderB mb40" id="boxSponsor"><ins class="kakao_ad_area" style="display:none;width:100%;" data-ad-unit="DAN-1jig3px8vbvw1" data-ad-width="655" data-ad-height="120" id="kakao_ad_UFuLt2"></ins>
# </div>
#         <div class="tableB" id="boxMarketTrend"><div class="titB">
#
#         <h4>실시간 마켓 트렌드</h4>
#
#
#
#
#
#         <p id="labDiscription">12.29 장종료</p>
#
# </div>
# <div class="tab max">
#     <ul class="box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="상승률 상위">상승률 상위</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="하락률 상위">하락률 상위</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="외국인 순매수">외국인 순매수</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="기관 순매수">기관 순매수</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="투자주체별">투자주체별</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="지수동향">지수동향</a>
# </li></ul>
# </div>
# <div class="box_contents"><div style="display: block;"><table>
#     <colgroup>
#         <col width="*">
#         <col width="64">
#         <col width="62">
#         <col width="70">
#         <col width="130">
#         <col width="64">
#         <col width="62">
#         <col width="60">
#     </colgroup>
#     <thead>
#         <tr>
#             <th colspan="4">코스피</th>
#             <th colspan="4">코스닥</th>
#         </tr>
#         <tr>
#             <th class="lAlign first">종목명</th>
#             <th class="rAlign">현재가</th>
#             <th class="rAlign">전일비</th>
#             <th class="rAlign last">등락률</th>
#             <th class="lAlign">종목명</th>
#             <th class="rAlign">현재가</th>
#             <th class="rAlign">전일비</th>
#             <th class="rAlign">등락률</th>
#         </tr>
#     </thead>
#     <tbody>
#
#
#             <tr class="first">
#
#                     <th>
#                         <a href="/quotes/A152550" class="txt">
#                             한국ANKOR유전
#                         </a>
#                     </th>
#                     <td class="rt-KR7152550000-price">
#                         <span class="num">278</span>
#                     </td>
#                     <td class="rt-KR7152550000-change-price">
#                         <span class="num up1"><i>↑</i>64</span>
#                     </td>
#                     <td class="pR rt-KR7152550000-change-ratio">
#                         <span class="num up1">+29.91%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A363250" class="txt">진시스템</a>
#                     </th>
#                     <td class="rt-KR7363250002-price">
#                         <span class="num">8,370</span>
#                     </td>
#                     <td class="rt-KR7363250002-change-price">
#                         <span class="num up1"><i>↑</i>1,930</span>
#                     </td>
#                     <td class="rt-KR7363250002-change-ratio">
#                         <span class="num up1">+29.97%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="">
#
#                     <th>
# ...
#                         <span class="num">55,900</span>
#                     </td>
#                     <td class="rt-KR7194480000-change-price">
#                         <span class="num up"><i>▲</i>5,100</span>
#                     </td>
#                     <td class="rt-KR7194480000-change-ratio">
#                         <span class="num up">+10.04%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="">
#
#                     <th>
#                         <a href="/quotes/Q530102" class="txt">
#                             삼성 인버스 2X 천연가스 선물 ETN C
#                         </a>
#                     </th>
#                     <td class="rt-KRG530001020-price">
#                         <span class="num">24,610</span>
#                     </td>
#                     <td class="rt-KRG530001020-change-price">
#                         <span class="num up"><i>▲</i>1,465</span>
#                     </td>
#                     <td class="pR rt-KRG530001020-change-ratio">
#                         <span class="num up">+6.33%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A408920" class="txt">에스케이증권7호스팩</a>
#                     </th>
#                     <td class="rt-KR7408920007-price">
#                         <span class="num">3,995</span>
#                     </td>
#                     <td class="rt-KR7408920007-change-price">
#                         <span class="num up"><i>▲</i>335</span>
#                     </td>
#                     <td class="rt-KR7408920007-change-ratio">
#                         <span class="num up">+9.15%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="">
#
#                     <th>
#                         <a href="/quotes/Q500074" class="txt">
#                             신한 블룸버그 -2X 천연가스 선물 ETN(H)
#                         </a>
#                     </th>
#                     <td class="rt-KRG500000747-price">
#                         <span class="num">25,765</span>
#                     </td>
#                     <td class="rt-KRG500000747-change-price">
#                         <span class="num up"><i>▲</i>1,515</span>
#                     </td>
#                     <td class="pR rt-KRG500000747-change-ratio">
#                         <span class="num up">+6.25%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A224060" class="txt">더코디</a>
#                     </th>
#                     <td class="rt-KR7224060004-price">
#                         <span class="num">9,470</span>
#                     </td>
#                     <td class="rt-KR7224060004-change-price">
#                         <span class="num up"><i>▲</i>790</span>
#                     </td>
#                     <td class="rt-KR7224060004-change-ratio">
#                         <span class="num up">+9.10%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="last">
#
#                     <th>
#                         <a href="/quotes/Q580046" class="txt">
#                             KB 블룸버그 인버스2X 천연가스선물 ETN(H)
#                         </a>
#                     </th>
#                     <td class="rt-KRG580000468-price">
#                         <span class="num">25,765</span>
#                     </td>
#                     <td class="rt-KRG580000468-change-price">
#                         <span class="num up"><i>▲</i>1,510</span>
#                     </td>
#                     <td class="pR rt-KRG580000468-change-ratio">
#                         <span class="num up">+6.23%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A015710" class="txt">코콤</a>
#                     </th>
#                     <td class="rt-KR7015710007-price">
#                         <span class="num">6,550</span>
#                     </td>
#                     <td class="rt-KR7015710007-change-price">
#                         <span class="num up"><i>▲</i>440</span>
#                     </td>
#                     <td class="rt-KR7015710007-change-ratio">
#                         <span class="num up">+7.20%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="line">
#
#                     <th>
#                         <a href="/quotes/Q520059" class="txt">
#                             미래에셋 S&amp;P -2X 천연가스 선물 ETN(H)
#                         </a>
#                     </th>
#                     <td class="rt-KRG520000594-price">
#                         <span class="num">25,840</span>
#                     </td>
#                     <td class="rt-KRG520000594-change-price">
#                         <span class="num up"><i>▲</i>1,485</span>
#                     </td>
#                     <td class="pR rt-KRG520000594-change-ratio">
#                         <span class="num up">+6.10%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A115180" class="txt">큐리언트</a>
#                     </th>
#                     <td class="rt-KR7115180002-price">
#                         <span class="num">10,600</span>
#                     </td>
#                     <td class="rt-KR7115180002-change-price">
#                         <span class="num up"><i>▲</i>670</span>
#                     </td>
#                     <td class="rt-KR7115180002-change-ratio">
#                         <span class="num up">+6.75%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="">
#
#                     <th>
#                         <a href="/quotes/Q700020" class="txt">
#                             하나 블룸버그 -2X 천연가스 선물 ETN(H)
#                         </a>
#                     </th>
#                     <td class="rt-KRG700000208-price">
#                         <span class="num">25,745</span>
#                     </td>
#                     <td class="rt-KRG700000208-change-price">
#                         <span class="num up"><i>▲</i>1,470</span>
#                     </td>
#                     <td class="pR rt-KRG700000208-change-ratio">
#                         <span class="num up">+6.06%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A227610" class="txt">아우딘퓨쳐스</a>
#                     </th>
#                     <td class="rt-KR7227610003-price">
#                         <span class="num">4,510</span>
#                     </td>
#                     <td class="rt-KR7227610003-change-price">
#                         <span class="num up"><i>▲</i>280</span>
#                     </td>
#                     <td class="rt-KR7227610003-change-ratio">
#                         <span class="num up">+6.62%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="">
#
#                     <th>
#                         <a href="/quotes/A011300" class="txt">
#                             성안
#                         </a>
#                     </th>
#                     <td class="rt-KR7011300001-price">
#                         <span class="num">890</span>
#                     </td>
#                     <td class="rt-KR7011300001-change-price">
#                         <span class="num up"><i>▲</i>50</span>
#                     </td>
#                     <td class="pR rt-KR7011300001-change-ratio">
#                         <span class="num up">+5.95%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A255220" class="txt">SG</a>
#                     </th>
#                     <td class="rt-KR7255220006-price">
#                         <span class="num">1,175</span>
#                     </td>
#                     <td class="rt-KR7255220006-change-price">
#                         <span class="num up"><i>▲</i>65</span>
#                     </td>
#                     <td class="rt-KR7255220006-change-ratio">
#                         <span class="num up">+5.86%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="">
#
#                     <th>
#                         <a href="/quotes/Q570084" class="txt">
#                             TRUE 블룸버그 인버스 2X 천연가스선물 ETN
#                         </a>
#                     </th>
#                     <td class="rt-KRG570000841-price">
#                         <span class="num">22,790</span>
#                     </td>
#                     <td class="rt-KRG570000841-change-price">
#                         <span class="num up"><i>▲</i>1,280</span>
#                     </td>
#                     <td class="pR rt-KRG570000841-change-ratio">
#                         <span class="num up">+5.95%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A175140" class="txt">인포마크</a>
#                     </th>
#                     <td class="rt-KR7175140003-price">
#                         <span class="num">5,630</span>
#                     </td>
#                     <td class="rt-KR7175140003-change-price">
#                         <span class="num up"><i>▲</i>310</span>
#                     </td>
#                     <td class="rt-KR7175140003-change-ratio">
#                         <span class="num up">+5.83%</span>
#                     </td>
#
#             </tr>
#
#             <tr class="last">
#
#                     <th>
#                         <a href="/quotes/Q570046" class="txt">
#                             TRUE 인버스 2X 천연가스 선물 ETN(H)
#                         </a>
#                     </th>
#                     <td class="rt-KRG570000460-price">
#                         <span class="num">565</span>
#                     </td>
#                     <td class="rt-KRG570000460-change-price">
#                         <span class="num up"><i>▲</i>30</span>
#                     </td>
#                     <td class="pR rt-KRG570000460-change-ratio">
#                         <span class="num up">+5.61%</span>
#                     </td>
#
#
#
#                     <th class="pL">
#                         <a href="/quotes/A293490" class="txt">카카오게임즈</a>
#                     </th>
#                     <td class="rt-KR7293490009-price">
#                         <span class="num">44,650</span>
#                     </td>
#                     <td class="rt-KR7293490009-change-price">
#                         <span class="num up"><i>▲</i>2,450</span>
#                     </td>
#                     <td class="rt-KR7293490009-change-ratio">
#                         <span class="num up">+5.81%</span>
#                     </td>
#
#             </tr>
#
#     </tbody>
# </table>
# </div><div style="display: none;"></div><div style="display: none;"></div><div style="display: none;"></div><div style="display: none;"></div><div style="display: none;"></div></div>
# </div>
#     </div>
#     <div class="rightW" id="boxRightSidebar"><div class="myB"><ul class="tab box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="나의 관심">나의 관심</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="최근 검색">최근 검색</a>
# </li></ul>
# <div class="box_contents"><div style="">
# <div class="box">
#     <span>
#         <p>로그인 하시면,<br>나의 관심 리스트를<br>볼 수 있습니다.</p>
#         <a href="https://logins.daum.net/accounts/loginform.do?&amp;url=https%3A%2F%2Ffinance.daum.net%2Fdomestic" title="로그인">로그인</a>
#     </span>
# </div>
#
# </div><div style="display: none;"></div></div>
# </div><div class="newsB"><ul class="tab box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="많이본 뉴스">많이본 뉴스</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="베스트칼럼">베스트칼럼</a>
# </li></ul>
# <div class="box_contents"><div style=""><ul class="list">
#
#         <li><a href="https://v.daum.net/v/20221230114701860">전기요금 '역대급'으로 오른다…가구당 月 4000원 인상 [종합]</a></li>
#
#         <li><a href="https://v.daum.net/v/20221230082555441">'본사 마진율 48%' 메가커피는 누굴 위해 손흥민 세웠나</a></li>
#
#         <li><a href="https://v.daum.net/v/20221230093901250">내년 6월부터 만 나이 쓴다…“우리 이제 오빠 동생으로 지내자”</a></li>
#
#         <li><a href="https://v.daum.net/v/20221230050026514">5%짜리 파킹통장 나왔다.. 하루만 맡겨도 은행예금보다 더 받아</a></li>
#
#         <li><a href="https://v.daum.net/v/20221229134801870">'배달료 0원' 파격 실험 통했다…음식 주문 건수 26배 폭등</a></li>
#
#         <li><a href="https://v.daum.net/v/20221230070105089">공인중개사도 놀란 집값 추락…"그래도 집 살 생각 없어요"</a></li>
#
#         <li><a href="https://v.daum.net/v/20221230091602573">아파트 미분양 6만가구 육박 “곧 위험선 도달”… 규제 더 푸나</a></li>
#
#         <li><a href="https://v.daum.net/v/20221229201200991">“없어서 못 먹는다”…6개·4만원에 진열 즉시 ‘완판’ 희귀과일 뭐길래?</a></li>
#
#         <li><a href="https://v.daum.net/v/20221229181048505">"배달로 380만원 버는데 공장서 왜 일해요”···늙어가는 韓 조선업</a></li>
#
#         <li><a href="https://v.daum.net/v/20221230092447849">'인근 헬리오가 15억원인데'…코앞 닥친 둔촌주공 계약자 '속탄다'</a></li>
#
# </ul>
# </div><div style="display: none;"></div></div>
# </div><div class="rankingB"><ul class="tab box_tabs"><li>
# <a href="javascript:void(0)" class="on" title="조회급등">조회급등</a>
# </li><li>
# <a href="javascript:void(0)" class="" title="인기토론">인기토론</a>
# </li></ul>
# <div class="box_contents"><div style=""><ul class="list">
#     <!-- TODO: 구현을 해주세요. -->
# <li>
# <a href="/quotes/A035720">
#     <em class="ty01">1</em>
#     카카오
# </a>
# <p class=""><i>-</i></p>
# </li><li>
# <a href="/quotes/A005930">
#     <em class="ty02">2</em>
#     삼성전자
# </a>
# <p class=""><i>-</i></p>
# </li><li>
# <a href="/quotes/A009830">
#     <em class="ty03">3</em>
#     한화솔루션
# </a>
# <p class=""><i>-</i></p>
# </li><li>
# <a href="/quotes/A152550">
#     <em class="ty04">4</em>
#     한국ANKOR유전
# </a>
# <p class=""><i>-</i></p>
# </li><li>
# <a href="/quotes/A251270">
#     <em class="ty05">5</em>
#     넷마블
# </a>
# <p class="up"><i>↑</i>2</p>
# </li><li>
# <a href="/quotes/A035420">
#     <em class="ty06">6</em>
#     NAVER
# </a>
# <p class="down"><i>↓</i>1</p>
# </li><li>
# <a href="/quotes/A373220">
#     <em class="ty07">7</em>
#     LG에너지솔루션
# </a>
# <p class="down"><i>↓</i>1</p>
# </li><li>
# <a href="/quotes/A047050">
#     <em class="ty08">8</em>
#     포스코인터내셔널
# </a>
# <p class="up"><i>↑</i>2</p>
# </li><li>
# <a href="/quotes/A000660">
#     <em class="ty09">9</em>
#     SK하이닉스
# </a>
# <p class=""><i>-</i></p>
# </li><li>
# <a href="/quotes/A015760">
#     <em class="ty10">10</em>
#     한국전력
# </a>
# <p class="down"><i>↓</i>2</p>
# </li></ul>
# </div><div style="display: none;"></div></div>
# </div></div>
# </div>
#
# <script>
#     requirejs(["/dist/daum/app/config.js?v=1668997547"], function (common) {
#         require(["app/domestic/index"]);
#     });
# </script>
#
#
#         </div>
#
#         <div class="footer">
#     <span>
#         <div class="fl">
#             <ul>
#                 <li><a target="_blank" href="http://policy.daum.net/info/info" title="서비스 약관/정책">서비스 약관/정책</a></li>
#                 <li><a target="_blank" href="http://cs.daum.net/faq/19.html" title="금융 고객센터">금융 고객센터</a></li>
#                 <li><a target="_blank" href="https://cs.daum.net/question/19.html" title="금융 문의하기">금융 문의하기</a></li>
#             </ul>
#             <p>카카오가 제공하는 증권정보는 단순히 정보의 제공을 목적으로 하고 있으며, 사이트에서 제공되는 정보는 오류 및 지연이<br>발생될 수 있습니다. 제공된 정보이용에 따르는 책임은 이용자 본인에게 있으며, 카카오는 이용자의 투자결과에 따른<br>법적 책임을 지지 않습니다.</p>
#         </div>
#         <div class="fr">
#             <p>위 내용에 대한 저작권 및 법적 책임은 자료제공사 또는<br>글쓴이에 있으며 카카오의 입장과 다를 수 있습니다.</p>
#             <p>Copyright (C) Kakao Corp. All rights reserved.</p>
#         </div>
#     </span>
# </div>
# <script>
#     window._TIARA_OPTIONS = {
#         section: '국내',
#         page: '국내'
#     }
# </script>
#
#
# <script>
#     requirejs(["/dist/daum/app/config.js?v=1668997547"], function (common) {
#         require(["app/common/tiara"]);
#     });
# </script>
#
#     </div>
#
#
# </body></html>

# %%
soup = BeautifulSoup(html,'html.parser')
print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5964\1748295084.py in <module>
# ----> 1 soup = BeautifulSoup(html,'html.parser')
#       2 print(soup)
#
# NameError: name 'html' is not defined
